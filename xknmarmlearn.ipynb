# %% [markdown]
# # 用Python对 码垛机器人运动学建模

# %% [markdown]
# ## 机器人照片如下

# %% [markdown]
# ![](marm.jpg)

# %% [markdown]
# # 先用OpenCV在图上标出各个零部件的尺寸，以像素为单位

# %% [markdown]
# ## 为此，先学习一下如何画倾斜的矩形，利用OpenCV中的画轮廓

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")
center=(200,100)
width=200
height=100
angle=10
rect=(center, (width, height), angle)
box = cv2.boxPoints(rect).astype(np.int0)
print(box)
cv2.drawContours(img,[box],0,(255,0,0),3)
cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()
type(box[2])

# %% [markdown]
# # 画一个以左端为基准点同样角度的矩形

# %%
import cv2
import numpy as np
import math as m
img=cv2.imread("marm.jpg")
leftbuttom=(92,131)
width=200
height=100
angle=10
print(m.sin(angle))
print(m.cos(angle))

x=int(m.sin(angle/180*m.pi)*width/2)
y=int(m.cos(angle/188*m.pi)*width/2)
center=leftbuttom+np.array([y,x])
rect=(center, (width, height), angle)
box = cv2.boxPoints(rect).astype(np.int0)
print(box)
cv2.drawContours(img,[box],0,(255,0,0),3)
cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 封装成函数

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#中心点，长度，角度
def drawlever(center,width,angle):
    height=100
    rect=(center, (width, height), angle)
    box = cv2.boxPoints(rect).astype(np.int0)
    cv2.drawContours(img,[box],0,(255,0,0),3)
    cv2.imshow("marm",img)

drawlever((630,250),800,3)    
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 封装成对象

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

# 臂模型
class mlever():
    def __init__(self,center,width,angle):
        self.center=center
        self.width=width
        self.angle=angle

    def drawlever(self):
        center=self.center
        width=self.width
        angle=self.angle
        height=100
        rect=(center, (width, height), angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
        
    def setlever(self,center,width,angle):
        self.center=center
        self.width=width
        self.angle=angle

        
ml01=mlever((315,120),400,3)    
ml02=mlever((380,245),340,140)
ml01.drawlever()
ml02.drawlever()

cv2.imshow("marm",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 电机模型，先画出来圆形和长型

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

angle=0
circlecenter=(260,360)
color=(0,255,0)
r=30
cv2.circle(img,circlecenter,r,color,5)
rect=(circlecenter,(2*r,4),angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)

angle=30
circlecenter=(260,360)
color=(0,255,0)
r=30
cv2.circle(img,circlecenter,r,color,5)
rect=(circlecenter,(2*r,4),angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)

angle=90
circlecenter=(260,360)
color=(0,255,0)
r=30
cv2.circle(img,circlecenter,r,color,5)
rect=(circlecenter,(2*r,4),angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)



cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 封装成函数

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

def drawmotor(center,angle):
    color=(0,255,0)
    r=30
    cv2.circle(img,circlecenter,r,color,5)
    rect=(circlecenter,(2*r,4),angle)
    box = cv2.boxPoints(rect).astype(np.int0)
    cv2.drawContours(img,[box],0,(255,0,0),3)

center=(260,360)
drawmotor(center,0)
drawmotor(center,30)
drawmotor(center,60)
drawmotor(center,90)

cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 封装成对象

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

class mmotor():
    def __init__(self,center,angle,fixangle):
        self.center=center
        self.angle=angle
        self.fixangle=fixangle
        
    def setfixangle(fixangle):
        self.fixangle=fixangle
        
    def setcenter(center):
        self.center=center
        
    def draw(self,angle):
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle+self.fixangle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)

m02=mmotor((260,360),0,0)
m01=mmotor((500,150),0,-30)
for i in range(10):
    m02.draw(i*10)
    m01.draw(i*10)
    cv2.imshow("img",img)
    cv2.waitKey(1000)

cv2.destroyAllWindows()

# %% [markdown]
# # 给杠杆添加联动点以及相对旋转角度

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
imgcon=img.copy()
print(img.shape)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("caculate center")
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            print(w,h)
            self.center=self.jointpoint-np.array([w,h])
            print(self.center)    
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjoitpoint(self,jointpoint):
        self.jointpoint=jointpoint
        
ml02=mlever((380,245),100,10,0)
ml02.setjoitpoint((270,370))

for i in range(12):
    ml02.setangle(i*30)
    ml02.draw()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()
cv2.destroyAllWindows()

# %% [markdown]
# # 一个电机与杆同时动

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,fixangle):
        self.center=center
        self.angle=angle
        self.fixangle=fixangle
        
    def setfixangle(self,fixangle):
        self.fixangle=fixangle
        ,
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle+self.fixangle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(0,0)
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("caculate center")
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=self.jointpoint-np.array([w,h])
            self.rightend=self.center-np.array([w,h])
            print(self.center)    
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjoitpoint(self,jointpoint):
        self.jointpoint=jointpoint
        
m02=mmotor((260,360),0,0)
ml02=mlever((0,0),340,20,0)
ml02.setjoitpoint((260,360))
for i in range(18):
    angle=i*10
    m02.draw(angle)
    ml02.setangle(angle)
    ml02.draw()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %%
import numpy as np

a=[1,1]
print(a)
b=(1,1)
print(b)
c=b
print(c)
d=np.array(a)
type(c)
print(d)
type(a)

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)        
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)
        

m01=mmotor((500,140),0,0)
ml01=mlever((0,0),340,20,0)
ml01.setjointpoint((460,260))
m02=mmotor((260,360),0,0)
ml02=mlever((0,0),340,20,0)
ml02.setjointpoint((260,360))

for i in range(18):
    angle=i*10
    #电机02
    m02.drawrelative(angle)
    #杆02
    ml02.setangle(angle)
    ml02.draw()
    #电机01放在杆02的右端
    m01.setcenter(ml02.rightend)
    m01.startangle=180+m02.angle
    #电机01目前保持30度不变
    m01.drawrelative(30)
    #杆01固定在电机01中心，角度与电机01一样
    ml01.setjointpoint(m01.center)
    ml01.setangle(m01.angle)
    ml01.draw()
    ml01.drawrightend()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 封装机械臂代码xy方向

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)        
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,ml01,ml02):
        self.m01=m01
        self.m02=m02
        self.ml01=ml01
        self.ml02=ml02
        self.angle1=0
        self.angle2=0
        ml02.setjointpoint(m02.center)
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        
m02=mmotor((260,360),0,0)
m01=mmotor((0,0),0,0)
ml01=mlever((0,0),340,20,0)
ml02=mlever((0,0),340,20,0)
marm=Marm(m01,m02,ml01,ml02)

for i in range(36):
    angle=i*5
    angle1=180-angle*2
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(500)
    #恢复背景
    img=imgcon.copy()

for i in range(36):
    angle=180-i*5
    angle1=45
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(500)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 调整机械臂参数，和实际吻合

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)        
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,ml01,ml02):
        self.m01=m01
        self.m02=m02
        self.ml01=ml01
        self.ml02=ml02
        self.angle1=0
        self.angle2=0
        ml02.setjointpoint(m02.center)
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        
m02=mmotor((260,360),0,0)
m01=mmotor((0,0),0,0)
ml01=mlever((0,0),350,20,0)
ml02=mlever((0,0),340,20,0)
marm=Marm(m01,m02,ml01,ml02)

for i in range(36):
    angle=i*5
    angle1=180-angle*2
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(500)
    #恢复背景
    img=imgcon.copy()

for i in range(36):
    angle=180-i*5
    angle1=45
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(500)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 添加吸盘模型，永远垂直

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml02=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        ml02.setjointpoint(m02.center)
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        ml03.setangle(90)
        L=int(ml03.width/2)
        ml03.center=np.add(ml01.rightend,(0,L))
        ml03.draw()
        ml03.drawrightend()
        

m02=mmotor((260+400,360),0,0)
m01=mmotor((0,0),0,0)
m03=mmotor((0,0),0,0)
ml01=mlever((0,0),350,20,0)
ml02=mlever((0,0),340,20,0)
ml03=mlever((0,0),100,20,0)
marm=Marm(m01,m02,m03,ml01,ml02,ml03)

for i in range(30):
    angle=i*5
    angle1=180-angle*2+10
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

for i in range(15):
    angle=150-i*5
    angle1=45
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 用解析法解逆向运动方程

# %% [markdown]
# ![](marmreverse.png)

# %% [markdown]
# im# 已知x，y坐标，为机械臂欲到达的坐标，L1，L2为机械臂长，求电机的角度Q1，Q2=Q4+Q5

# %%
import math as mt

x=500
y=100
L1=350
L2=340

# %% [markdown]
# # 这样可以算出L3

# %%
L3=mt.sqrt(y*y+x*x)
L3

# %% [markdown]
# # 根据海伦公式可以知道L1，L2，L3 组成的三角形面积

# %%
p=(L1+L2+L3)/2
S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
S

# %% [markdown]
# # 求出三角形在L3上的高 0.5*L3*h=s

# %%
h=S*2/L3
h

# %% [markdown]
# # 得出Q5并转换为角度

# %%
Q5=mt.asin(h/L2)/mt.pi*180
Q5

# %% [markdown]
# # 计算出Q4

# %%
Q4=mt.asin(y/L3)/mt.pi*180
Q4

# %% [markdown]
# # 计算出Q7

# %%
Q7=mt.asin(h/L1)/mt.pi*180
Q7

# %% [markdown]
# # 终于，得到了Q1，Q2

# %%
Q1=180-Q5-Q7
Q2=Q5+Q4
print("Q1,Q2",Q1,Q2)

# %% [markdown]
# # 整合为函数

# %%
def xytoq(x,y):
    L1=350
    L2=340
    L3=mt.sqrt(y*y+x*x)
    p=(L1+L2+L3)/2
    S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
    h=S*2/L3
    Q5=mt.asin(h/L2)/mt.pi*180
    Q4=mt.asin(y/L3)/mt.pi*180
    Q7=mt.asin(h/L1)/mt.pi*180
    Q1=180-Q5-Q7
    Q2=Q5+Q4
    #print("Q1,Q2",Q1,Q2)
    return Q1,Q2

print(xytoq(500,100))

# %% [markdown]
# # 整合到对象中

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml02=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        ml02.setjointpoint(m02.center)
    def xytoq(self,x,y):
        L1=ml01.width
        L2=ml02.width
        L3=mt.sqrt(y*y+x*x)
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        ml03.setangle(90)
        L=int(ml03.width/2)
        ml03.center=np.add(ml01.rightend,(0,L))
        ml03.draw()
        ml03.drawrightend()
        

m02=mmotor((260+400,360),0,0)
m01=mmotor((0,0),0,0)
m03=mmotor((0,0),0,0)
ml01=mlever((0,0),350,20,0)
ml02=mlever((0,0),340,20,0)
ml03=mlever((0,0),100,20,0)
marm=Marm(m01,m02,m03,ml01,ml02,ml03)

for i in range(60):
    x=i*10+10
    y=0
    angle1,angle2=marm.xytoq(x,y)
    marm.draw(angle1,angle2)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

for i in range(60):
    x=650-i*10
    y=0
    angle1,angle2=marm.xytoq(x,y)
    marm.draw(angle1,angle2)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

    
    
cv2.destroyAllWindows()

# %% [markdown]
# # 将计算电机控制的PWM值，500~2500

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        self.ml02.setjointpoint(self.m02.center)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        print("angle1disp,angle2disp,angle1,angle2",angle1disp,angle2disp,  angel1,angel2)
        self.robodraw(angel1,angel2)

mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,90)
#mM01.facetome=True
mM03=mmotor((0,0),0,0,180)
mMl01=mlever((0,0),350,20,0)
mMl02=mlever((0,0),350,20,0)
mMl03=mlever((0,0),100,20,0)
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(50):
    x=i*10-100
    y=-40
    angle1,angle2=marm.xytoq(x,y)
    marm.scrdraw(angle1,angle2)
    cv2.imshow("marm",img)
    cv2.waitKey(200)
    #恢复背景
    img=imgcon.copy()

for i in range(50):
    x=400-i*10
    y=-40
    angle1,angle2=marm.xytoq(x,y)
    marm.scrdraw(angle1,angle2)
    cv2.imshow("marm",img)
    cv2.waitKey(200)
    #恢复背景
    img=imgcon.copy()
# [117,54],[126,68],[133,77]
pwmtable=[[0x708,0x44c],[0x76c,0x4e7],[0x7b9,0x54b]]

for j in range(10):
    for i in range(3):
        pwm=pwmtable[i]
        print("pwm",pwm)
        marm.drawpwm(pwm[0],pwm[1])
        cv2.imshow("marm",img)
        cv2.waitKey(1000)
        #恢复背景
        img=imgcon.copy()
cv2.destroyAllWindows()

# %% [markdown]
# # 仿真手工测量的棋盘3个格子的运动pwm命令

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        self.ml02.setjointpoint(self.m02.center)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,angle1,angle2,A2",angle1disp,angle2disp,angel1,angel2)
        self.robodraw(A1,angel2)

mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,180)
#mM01.facetome=True
mM03=mmotor((0,0),0,0,180)
mMl01=mlever((0,0),350,20,0)
mMl02=mlever((0,0),350,20,0)
mMl03=mlever((0,0),100,20,0)
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

# [117,54],[126,68],[133,77]
pwmtable=[[0x708,0x44c],[0x76c,0x4e7],[0x7b9,0x54b]]

i=0
while True:
    pwm=pwmtable[i%3]
    i+=1
    print("pwm",pwm)
    marm.drawpwm(pwm[0],pwm[1])
    cv2.imshow("marm",img)
    if cv2.waitKey(0)&0xff == 27:
        break
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 位置xy通过PWM参数仿真运行

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        #将梁2固定在电机2的中心
        self.ml02.setjointpoint(self.m02.center)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,A1,%x,%x,"%(pwm1,pwm2),angle1disp,angle2disp,A1)
        self.robodraw(A1,angel2)
    def xytopwm(self,x,y):
        q1,q2=self.xytoq(x,y)
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        return pwm1,pwm2
    
    def serwrite(self,pwm1,pwm2):
        print("TBD,serialwrite %x %x"%(pwm1,pwm2))
        return
    
    def robotTwin(self,x,y):
        pwm1,pwm2=self.xytopwm(x,y)
        self.drawpwm(pwm1,pwm2)
        self.serwrite(pwm1,pwm2)
        
#配置零件舵机
mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,180)
mM03=mmotor((0,0),0,0,180)
#配置零件梁
mMl01=mlever((0,0),300,20,0)
mMl02=mlever((0,0),300,20,0)
mMl03=mlever((0,0),100,20,0)
#组装成机械臂
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(50):
    x=i*10+100
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

for i in range(50):
    x=600-i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 添加串口控制机械臂

# %%
import cv2
import numpy as np
import math  as mt
import serial
import serial.tools.list_ports
import string
import binascii
import time


img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        self.ser=None
        #将梁2固定在电机2的中心
        self.ml02.setjointpoint(self.m02.center)
        #打开串口
        ports = list(serial.tools.list_ports.comports())
        print (ports)
        #便利 寻找串口
        for p in ports:
            print (p[1])
            if "serial" in p[1] or "CH340" in p[1]:
                self.ser=serial.Serial(port=p[0])
                if self.ser is not None:
                    print(self.ser)
                    print("serial conected")
                else:
                    print("serial not connected")
                    return
            else:
                print ("No CH340 Device was found connected to the computer")
                return
        self.robotinit()
    def robotinit(self):
        if self.ser is None:
            return
        m0=bytes.fromhex('ff 01 00 08 00')# 舵机0速度为 72
        m1=bytes.fromhex('ff 01 01 08 00')# 舵机1速度为 72
        m2=bytes.fromhex('ff 01 02 08 00')# 舵机2速度为 72
        mo0=bytes.fromhex('ff 02 00 dc 05')#设置初始舵机0位置
        mo1=bytes.fromhex('ff 02 01 82 07')#设置初始舵机1的位置
        mo2 = bytes.fromhex('ff 02 02 dc 05')#设置初始舵机2的位置
        mo3 = bytes.fromhex('ff 02 03 dc 05')#设置初始舵机3的位置
        self.ser.write(m0)
        self.ser.write(m1)
        self.ser.write(m2)
        self.ser.write(mo0)
        self.ser.write(mo1)
        self.ser.write(mo2)
        self.ser.write(mo3)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)+0.01
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        if self.ser is not None:
            cv2.circle(img,(50,50),10,(0,255,0),3)
        else:
            cv2.circle(img,(50,50),10,(0,0,255),3)
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,A1,%x,%x,"%(pwm1,pwm2),angle1disp,angle2disp,A1)
        self.robodraw(A1,angel2)
    def xytopwm(self,x,y):
        q1,q2=self.xytoq(x,y)
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        return pwm1,pwm2
    
    def serwrite(self,pwm1,pwm2):
        if self.ser is None:
            return
        print(pwm1,pwm2)
        pw1str="%04x"%pwm1
        pw2str="%04x"%pwm2
        print(pw1str,pw2str)
        mo1hexstr="ff 02 01"+" "+pw1str[2:4]+" "+pw1str[0:2]
        mo2hexstr="ff 02 02"+" "+pw2str[2:4]+" "+pw2str[0:2]
        self.ser.write(bytes.fromhex(mo1hexstr))
        self.ser.write(bytes.fromhex(mo2hexstr))
        return
    
    def robotTwin(self,x,y):
        pwm1,pwm2=self.xytopwm(x,y)
        self.drawpwm(pwm1,pwm2)
        self.serwrite(pwm1,pwm2)
        
#配置零件舵机
mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,180)
mM03=mmotor((0,0),0,0,180)
#配置零件梁
mMl01=mlever((0,0),300,20,0)
mMl02=mlever((0,0),300,20,0)
mMl03=mlever((0,0),100,20,0)
#组装成机械臂
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(60):
    x=i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()

for i in range(60):
    x=600-i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()
    
marm.ser.close()
cv2.destroyAllWindows()

# %% [markdown]
# # 添加Z方向上的另一个视图

# %%
import cv2
import numpy as np
import math  as mt
import serial
import serial.tools.list_ports
import string
import binascii
import time

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/3)
W=int(shape[1]/3)
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,300,0,300,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
zcenter=(470,300)

#电机模型,
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        #电机中心点随杠杆旋转时电机0位与水平线的夹角
        self.startangle=startangle
        #电机中点为90度，顺时针方向为正，最小点和最大点角度
        self.maxangle=maxangle
        #self.minangle=minangle
        self.relaangle=0
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
        #画z方向
        cv2.circle(img,zcenter,3,(255,0,0),-1)
        
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
        self.zcenter=0
        self.zwidth=0
        self.zheight=20
        self.zangle=90
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)
        #画Z轴的投影
        self.zcenter=self.center
        self.zcenter=(zcenter[0],self.zcenter[0])
        self.zwidth=self.width*mt.cos(self.angle/180*mt.pi)
        self.zangle=90
        zrect=(self.zcenter, (self.zwidth,self.zheight), self.zangle)
        zbox = cv2.boxPoints(zrect).astype(np.int0)
        cv2.drawContours(img,[zbox],0,(0,255,0),3)
        
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        self.ser=None
        self.img=None
        self.imgcon=None
        #将梁2固定在电机2的中心
        self.ml02.setjointpoint(self.m02.center)
        #模拟器初始化
        self.simuinit()
        #串口及机械臂位置初始化
        self.robotinit()
        
    def robotinit(self):
        #打开串口
        ports = list(serial.tools.list_ports.comports())
        print (ports)
        #便利 寻找串口
        for p in ports:
            print (p[1])
            if "serial" in p[1] or "CH340" in p[1]:
                self.ser=serial.Serial(port=p[0])
                if self.ser is not None:
                    print(self.ser)
                    print("serial conected")
                else:
                    print("serial not connected")
                    return
            else:
                print ("No CH340 Device was found connected to the computer")
                return
        if self.ser is None:
            return
        m0=bytes.fromhex('ff 01 00 08 00')# 舵机0速度为 72
        m1=bytes.fromhex('ff 01 01 08 00')# 舵机1速度为 72
        m2=bytes.fromhex('ff 01 02 08 00')# 舵机2速度为 72
        mo0=bytes.fromhex('ff 02 00 dc 05')#设置初始舵机0位置
        mo1=bytes.fromhex('ff 02 01 82 07')#设置初始舵机1的位置
        mo2 = bytes.fromhex('ff 02 02 dc 05')#设置初始舵机2的位置
        mo3 = bytes.fromhex('ff 02 03 dc 05')#设置初始舵机3的位置
        self.ser.write(m0)
        self.ser.write(m1)
        self.ser.write(m2)
        self.ser.write(mo0)
        self.ser.write(mo1)
        self.ser.write(mo2)
        self.ser.write(mo3)
        
    def simuinit(self):
        return

    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)+0.01
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        if self.ser is not None:
            cv2.circle(img,(50,50),10,(0,255,0),3)
        else:
            cv2.circle(img,(50,50),10,(0,0,255),3)
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,A1,%x,%x,"%(pwm1,pwm2),angle1disp,angle2disp,A1)
        self.robodraw(A1,angel2)
    def xytopwm(self,x,y):
        q1,q2=self.xytoq(x,y)
        q2=q2-7
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        return pwm1,pwm2
    
    def serwrite(self,pwm1,pwm2):
        if self.ser is None:
            return
        print(pwm1,pwm2)
        pw1str="%04x"%pwm1
        pw2str="%04x"%pwm2
        print(pw1str,pw2str)
        mo1hexstr="ff 02 01"+" "+pw1str[2:4]+" "+pw1str[0:2]
        mo2hexstr="ff 02 02"+" "+pw2str[2:4]+" "+pw2str[0:2]
        self.ser.write(bytes.fromhex(mo1hexstr))
        self.ser.write(bytes.fromhex(mo2hexstr))
        return
    
    def robotTwin(self,x,y):
        pwm1,pwm2=self.xytopwm(x,y)
        self.drawpwm(pwm1,pwm2)
        self.serwrite(pwm1,pwm2)
    
    def destroy(self):
        if self.ser is not None:
            self.ser.close()
        cv2.destroyAllWindows()
        
#配置零件舵机
mM02=mmotor((170+300,240+300),0,0,180)
mM01=mmotor((0,0),0,0,180)
mM03=mmotor((0,0),0,0,180)
#配置零件梁
mMl01=mlever((0,0),200,10,0)
mMl02=mlever((0,0),200,10,0)
mMl03=mlever((0,0),60,10,0)
#组装成机械臂
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(60):
    x=i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()

for i in range(60):
    x=600-i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()
    
time.sleep(3)
marm.destroy()

# %% [markdown]
# # 让电机0旋转，正向运动模型生成

# %%
import cv2
import numpy as np
import math  as mt
import serial
import serial.tools.list_ports
import string
import binascii
import time

img=cv2.imread("marm.jpg")
img9sea=cv2.imread("9seacut.png")
img9sea=cv2.resize(img9sea,(500,350))
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/3)
W=int(shape[1]/3)
print(W,H)

shape2=img9sea.shape
print(shape2)
H2=shape2[0]
W2=shape2[1]

img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,300,0,300,0,cv2.BORDER_CONSTANT,value=(100,100,0))
img[200:200+H2,200:200+W2]=img9sea
imgcon=img.copy()

#顶视图平面中点
zcenter=(470,300)

#电机模型,
class mmotor():
    def __init__(self,center,angle,startangle,minangle,maxangle):
        self.center=center
        self.angle=angle
        #电机中心点随杠杆旋转时电机0位与水平线的夹角
        self.startangle=startangle
        #电机中点为90度，顺时针方向为正，最小点和最大点角度
        self.maxangle=maxangle
        self.minangle=minangle
        self.relaangle=0
        self.facetome=False
        self.zcenter=(0,0)
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        #通过舵机角度270判断是否为底座舵机，画图时大一些
        if self.maxangle-self.startangle >200:
            r=50
            color=(0,255,0)
            cv2.circle(img,self.center,r,color,3)
            rect=(self.center,(2*r,4),angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            cv2.drawContours(img,[box],0,color,3)
        else:
            r=20
            color=(155,0,0)
            cv2.circle(img,self.center,r,color,3)
            rect=(self.center,(2*r,4),angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            cv2.drawContours(img,[box],0,color,3)
      
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.zjointpoint=(0,0)
        self.rightend=(width,0)
        self.zrightend=(0,0)
        self.rightendr=10
        self.zcenter=(0,0)
        self.zwidth=100
        self.zheight=10
        self.zangle=60
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转 w,h为中心点相对坐标
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            #z轴的投影长度为中心点坐标的一倍
            self.zwidth=2*w
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            #z轴的投影长度为中心点坐标的一倍
            self.zwidth=2*w
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(155,0,0),3)
        #画Z轴的投影
        if self.zjointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("ZJ point",self.zjointpoint)
            w=int(self.zwidth/2*mt.cos(self.zangle/180*mt.pi))
            h=int(self.zwidth/2*mt.sin(self.zangle/180*mt.pi))
            self.zcenter=(self.zjointpoint[0]-w,self.zjointpoint[1]-h)
        else:
            self.zcenter=zcenter
            pass
        zrect=(self.zcenter, (self.zwidth,self.zheight), self.zangle)
        print("zrect",zrect)
        zbox = cv2.boxPoints(zrect).astype(np.int0)
        self.zrightend=(int((zbox[0][0]+zbox[1][0])/2),int((zbox[0][1]+zbox[1][1])/2))
        cv2.drawContours(img,[zbox],0,(0,255,0),3)
        
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def setzjointpoint(self,jointpoint):
        self.zjointpoint=jointpoint
    def setzangle(self,angle):
        self.zangle=angle
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)
        cv2.circle(img,self.zrightend,self.rightendr,(0,255,0),3)

class Marm():
    def __init__(self,m00,m01,m02,m03,ml01,ml02,ml03):
        self.m00=m00
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.ser=None
        self.img=None
        self.imgcon=None
        

        #模拟器初始化
        self.simuinit()
        #串口及机械臂位置初始化
        self.robotinit()
        
    def robotinit(self):
        #打开串口
        ports = list(serial.tools.list_ports.comports())
        print (ports)
        #便利 寻找串口
        for p in ports:
            print (p[1])
            if "serial" in p[1] or "CH340" in p[1]:
                self.ser=serial.Serial(port=p[0])
                if self.ser is not None:
                    print(self.ser)
                    print("serial conected")
                else:
                    print("serial not connected")
                    return
            else:
                print ("No CH340 Device was found connected to the computer")
                return
        if self.ser is None:
            return
        m0=bytes.fromhex('ff 01 00 08 00')# 舵机0速度为 72
        m1=bytes.fromhex('ff 01 01 08 00')# 舵机1速度为 72
        m2=bytes.fromhex('ff 01 02 08 00')# 舵机2速度为 72
        mo0=bytes.fromhex('ff 02 00 dc 05')#设置初始舵机0位置
        mo1=bytes.fromhex('ff 02 01 82 07')#设置初始舵机1的位置
        mo2 = bytes.fromhex('ff 02 02 dc 05')#设置初始舵机2的位置
        mo3 = bytes.fromhex('ff 02 03 dc 05')#设置初始舵机3的位置
        self.ser.write(m0)
        self.ser.write(m1)
        self.ser.write(m2)
        self.ser.write(mo0)
        self.ser.write(mo1)
        self.ser.write(mo2)
        self.ser.write(mo3)
        
    def simuinit(self):
        return
    
    def xztoq0(self,x,z):
        r=mt.sqrt(x*x+z*z+0.01)
        if z >=0:
            q0=180-mt.acos(z/r)/mt.pi*180
        else:
            q0=mt.acos(abs(z)/r)/mt.pi*180
        return q0
    
    def xytoq12(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)+0.01
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置,考虑杆的移动相对位置
    def scrdraw(self,angle0,angle1,angle2):
        #电机0在底盘
        self.m00.drawrelative(angle0)
        #杆02与电机0中心在z轴方向相连
        self.ml02.setzjointpoint(self.m00.center)
        self.ml02.setzangle(angle0)
        #电机02
        self.m02.drawrelative(angle2)
         #杆02,与m02的圆心相连
        self.ml02.setangle(angle2)
        self.ml02.draw()
        self.ml02.setjointpoint(self.m02.center)
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.zcenter=self.ml02.zrightend
        print("m01 zcenter is",self.m01.zcenter)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.setzjointpoint(self.m01.zcenter)
        self.ml01.setzangle(angle0)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.setzjointpoint(self.ml01.zrightend)
        self.ml03.setzangle(angle0)
        self.ml03.draw()
        self.ml03.drawrightend()
        #显示串口连接状态红未连接绿连接
        if self.ser is not None:
            cv2.circle(img,(50,50),10,(0,255,0),3)
        else:
            cv2.circle(img,(50,50),10,(0,0,255),3)
        
    #输入角度考虑电机是否对面装配，从而是逆时针旋转，然后画在图上   
    def robodraw(self,angle0,angle1,angle2):
        mangle0=angle0
        mangle1=angle1
        mangle2=angle2
        if self.m00.facetome == True:
            print("facetome")
            mangle0=self.m00.maxangle-angle0
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            print("facetome")
            mangle2=slef.m02.maxangle-angle2
        print("mangel0,mangle1,mangle2",mangle0,mangle1,mangle2)
        self.scrdraw(mangle0,mangle1,mangle2)
    
    #输入PWM值画机械臂。对于非180度舵机实施缩放处理。对零位非0度的情况进行处理
    def drawpwm(self,pwm0,pwm1,pwm2):
        angle0pc=int((pwm0-500)/2000*180)
        angle0pc=180-angle0pc
        angle1pc=int((pwm1-500)/2000*180)
        angle2pc=int((pwm2-500)/2000*180)
        angel0=int(angle0pc*(self.m00.maxangle-self.m00.minangle)/180)+self.m00.minangle
        angel1=int(angle1pc*(self.m01.maxangle-self.m01.minangle)/180)+self.m01.minangle
        angel2=int(angle2pc*(self.m02.maxangle-self.m02.minangle)/180)+self.m02.minangle
        A1=180+50-(angel1+angel2)
        print("angel0,A1,angel2",angel0,A1,angel2)
        self.robodraw(angel0,A1,angel2)
        
    def xytopwm(self,x,y,z):
        r=mt.sqrt(x*x+z*z)
        q1,q2=self.xytoq12(r,y)
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        
        q0=self.xztoq0(x,z)
        qq0=q0-self.m00.minangle
        pwmq0=qq0/(self.m00.maxangle-self.m00.minangle)*180
        pwm0=int(pwmq0/180*2000+500)
        print("pwm0,pwm1,pwm2",pwm0,pwm1,pwm2)
        return pwm0,pwm1,pwm2
    
    def serwrite(self,pwm0,pwm1,pwm2):
        if self.ser is None:
            return
        print(pwm0,pwm1,pwm2)
        pw0str="%04x"%pwm0
        pw1str="%04x"%pwm1
        pw2str="%04x"%pwm2
        print(pw0str,pw1str,pw2str)
        mo0hexstr="ff 02 00"+" "+pw0str[2:4]+" "+pw0str[0:2]
        mo1hexstr="ff 02 01"+" "+pw1str[2:4]+" "+pw1str[0:2]
        mo2hexstr="ff 02 02"+" "+pw2str[2:4]+" "+pw2str[0:2]
        self.ser.write(bytes.fromhex(mo0hexstr))
        self.ser.write(bytes.fromhex(mo1hexstr))
        self.ser.write(bytes.fromhex(mo2hexstr))
        return
    
    def robotTwin(self,x,y,z):
        pwm0,pwm1,pwm2=self.xytopwm(x,y,-1*z)
        self.drawpwm(pwm0,pwm1,pwm2)
        self.serwrite(pwm0,pwm1,pwm2)
    def show(self):
        global img
        cv2.imshow("marm",img)
        cv2.waitKey(300)
        #恢复背景
        img=imgcon.copy()
    def home(self):
        self.robotTwin(0,0,0)
        self.show()
        cv2.waitKey(5000)
    def destroy(self):
        if self.ser is not None:
            self.ser.close()
        cv2.destroyAllWindows()
        
#配置零件舵机
mM00=mmotor((170+300,240+300),0,0,-45,225)
mM02=mmotor((170+300,240+300),0,0,0,180)
mM01=mmotor((0,0),0,0,0,180)
mM03=mmotor((0,0),0,0,0,180)
#配置零件梁
mMl01=mlever((0,0),200,10,0)
mMl02=mlever((0,0),200,10,0)
mMl03=mlever((0,0),60,10,0)
#组装成机械臂
marm=Marm(mM00,mM01,mM02,mM03,mMl01,mMl02,mMl03)

marm.home()
for i in range(-25,25):
    marm.robotTwin(300,0,i*10)
    marm.show()    
    time.sleep(1)
for i in range(-25,25):
    marm.robotTwin(100,0,i*10)
    marm.show()    
    time.sleep(1)
    
marm.destroy()

# %%
# x 轴方向移动时贴地面有高度差，找原因并调整

# %%
import cv2
import numpy as np
import math  as mt
import serial
import serial.tools.list_ports
import string
import binascii
import time

img=cv2.imread("marm.jpg")
img9sea=cv2.imread("9seacut.png")
img9sea=cv2.resize(img9sea,(500,350))
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/3)
W=int(shape[1]/3)
print(W,H)

shape2=img9sea.shape
print(shape2)
H2=shape2[0]
W2=shape2[1]

img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,300,0,300,0,cv2.BORDER_CONSTANT,value=(100,100,0))
img[200:200+H2,200:200+W2]=img9sea
imgcon=img.copy()

#顶视图平面中点
zcenter=(470,300)

#电机模型,
class mmotor():
    def __init__(self,center,angle,startangle,minangle,maxangle):
        self.center=center
        self.angle=angle
        #电机中心点随杠杆旋转时电机0位与水平线的夹角
        self.startangle=startangle
        #电机中点为90度，顺时针方向为正，最小点和最大点角度
        self.maxangle=maxangle
        self.minangle=minangle
        self.relaangle=0
        self.facetome=False
        self.zcenter=(0,0)
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        #通过舵机角度270判断是否为底座舵机，画图时大一些
        if self.maxangle-self.startangle >200:
            r=50
            color=(0,255,0)
            cv2.circle(img,self.center,r,color,3)
            rect=(self.center,(2*r,4),angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            cv2.drawContours(img,[box],0,color,3)
        else:
            r=20
            color=(155,0,0)
            cv2.circle(img,self.center,r,color,3)
            rect=(self.center,(2*r,4),angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            cv2.drawContours(img,[box],0,color,3)
      
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.zjointpoint=(0,0)
        self.rightend=(width,0)
        self.zrightend=(0,0)
        self.rightendr=10
        self.zcenter=(0,0)
        self.zwidth=100
        self.zheight=10
        self.zangle=60
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转 w,h为中心点相对坐标
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            #z轴的投影长度为中心点坐标的一倍
            self.zwidth=2*w
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            #z轴的投影长度为中心点坐标的一倍
            self.zwidth=2*w
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(155,0,0),3)
        #画Z轴的投影
        if self.zjointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("ZJ point",self.zjointpoint)
            w=int(self.zwidth/2*mt.cos(self.zangle/180*mt.pi))
            h=int(self.zwidth/2*mt.sin(self.zangle/180*mt.pi))
            self.zcenter=(self.zjointpoint[0]-w,self.zjointpoint[1]-h)
        else:
            self.zcenter=zcenter
            pass
        zrect=(self.zcenter, (self.zwidth,self.zheight), self.zangle)
        print("zrect",zrect)
        zbox = cv2.boxPoints(zrect).astype(np.int0)
        self.zrightend=(int((zbox[0][0]+zbox[1][0])/2),int((zbox[0][1]+zbox[1][1])/2))
        cv2.drawContours(img,[zbox],0,(0,255,0),3)
        
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def setzjointpoint(self,jointpoint):
        self.zjointpoint=jointpoint
    def setzangle(self,angle):
        self.zangle=angle
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)
        cv2.circle(img,self.zrightend,self.rightendr,(0,255,0),3)

class Marm():
    def __init__(self,m00,m01,m02,m03,ml01,ml02,ml03):
        self.m00=m00
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.ser=None
        self.img=None
        self.imgcon=None
        

        #模拟器初始化
        self.simuinit()
        #串口及机械臂位置初始化
        self.robotinit()
        
    def robotinit(self):
        #打开串口
        ports = list(serial.tools.list_ports.comports())
        print (ports)
        #便利 寻找串口
        for p in ports:
            print (p[1])
            if "serial" in p[1] or "CH340" in p[1]:
                self.ser=serial.Serial(port=p[0])
                if self.ser is not None:
                    print(self.ser)
                    print("serial conected")
                else:
                    print("serial not connected")
                    return
            else:
                print ("No CH340 Device was found connected to the computer")
                return
        if self.ser is None:
            return
        m0=bytes.fromhex('ff 01 00 08 00')# 舵机0速度为 72
        m1=bytes.fromhex('ff 01 01 08 00')# 舵机1速度为 72
        m2=bytes.fromhex('ff 01 02 08 00')# 舵机2速度为 72
        mo0=bytes.fromhex('ff 02 00 dc 05')#设置初始舵机0位置
        mo1=bytes.fromhex('ff 02 01 82 07')#设置初始舵机1的位置
        mo2 = bytes.fromhex('ff 02 02 dc 05')#设置初始舵机2的位置
        mo3 = bytes.fromhex('ff 02 03 dc 05')#设置初始舵机3的位置
        self.ser.write(m0)
        self.ser.write(m1)
        self.ser.write(m2)
        self.ser.write(mo0)
        self.ser.write(mo1)
        self.ser.write(mo2)
        self.ser.write(mo3)
        
    def simuinit(self):
        return
    
    def xztoq0(self,x,z):
        r=mt.sqrt(x*x+z*z+0.01)
        if z >=0:
            q0=180-mt.acos(z/r)/mt.pi*180
        else:
            q0=mt.acos(abs(z)/r)/mt.pi*180
        return q0
    
    def xytoq12(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)+0.01
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置,考虑杆的移动相对位置
    def scrdraw(self,angle0,angle1,angle2):
        #电机0在底盘
        self.m00.drawrelative(angle0)
        #杆02与电机0中心在z轴方向相连
        self.ml02.setzjointpoint(self.m00.center)
        self.ml02.setzangle(angle0)
        #电机02
        self.m02.drawrelative(angle2)
         #杆02,与m02的圆心相连
        self.ml02.setangle(angle2)
        self.ml02.draw()
        self.ml02.setjointpoint(self.m02.center)
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.zcenter=self.ml02.zrightend
        print("m01 zcenter is",self.m01.zcenter)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.setzjointpoint(self.m01.zcenter)
        self.ml01.setzangle(angle0)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.setzjointpoint(self.ml01.zrightend)
        self.ml03.setzangle(angle0)
        self.ml03.draw()
        self.ml03.drawrightend()
        #显示串口连接状态红未连接绿连接
        if self.ser is not None:
            cv2.circle(img,(50,50),10,(0,255,0),3)
        else:
            cv2.circle(img,(50,50),10,(0,0,255),3)
        
    #输入角度考虑电机是否对面装配，从而是逆时针旋转，然后画在图上   
    def robodraw(self,angle0,angle1,angle2):
        mangle0=angle0
        mangle1=angle1
        mangle2=angle2
        if self.m00.facetome == True:
            print("facetome")
            mangle0=self.m00.maxangle-angle0
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            print("facetome")
            mangle2=slef.m02.maxangle-angle2
        print("mangel0,mangle1,mangle2",mangle0,mangle1,mangle2)
        self.scrdraw(mangle0,mangle1,mangle2)
    
    #输入PWM值画机械臂。对于非180度舵机实施缩放处理。对零位非0度的情况进行处理
    def drawpwm(self,pwm0,pwm1,pwm2):
        angle0pc=int((pwm0-500)/2000*180)
        angle0pc=180-angle0pc
        angle1pc=int((pwm1-500)/2000*180)
        angle2pc=int((pwm2-500)/2000*180)
        angel0=int(angle0pc*(self.m00.maxangle-self.m00.minangle)/180)+self.m00.minangle
        angel1=int(angle1pc*(self.m01.maxangle-self.m01.minangle)/180)+self.m01.minangle
        angel2=int(angle2pc*(self.m02.maxangle-self.m02.minangle)/180)+self.m02.minangle
        A1=180+50-(angel1+angel2)
        print("angel0,A1,angel2",angel0,A1,angel2)
        self.robodraw(angel0,A1,angel2)
        
    def xytopwm(self,x,y,z):
        r=mt.sqrt(x*x+z*z)
        q1,q2=self.xytoq12(r,y)
        q2=q2-7.5
        # q1=180+50-(q2+pwmq1)
        #50，20为舵机安装倾斜角度
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        
        q0=self.xztoq0(x,z)
        qq0=q0-self.m00.minangle
        pwmq0=qq0/(self.m00.maxangle-self.m00.minangle)*180
        pwm0=int(pwmq0/180*2000+500)
        print("pwm0,pwm1,pwm2",pwm0,pwm1,pwm2)
        return pwm0,pwm1,pwm2
    
    def serwrite(self,pwm0,pwm1,pwm2):
        if self.ser is None:
            return
        print(pwm0,pwm1,pwm2)
        pw0str="%04x"%pwm0
        pw1str="%04x"%pwm1
        pw2str="%04x"%pwm2
        print(pw0str,pw1str,pw2str)
        mo0hexstr="ff 02 00"+" "+pw0str[2:4]+" "+pw0str[0:2]
        mo1hexstr="ff 02 01"+" "+pw1str[2:4]+" "+pw1str[0:2]
        mo2hexstr="ff 02 02"+" "+pw2str[2:4]+" "+pw2str[0:2]
        self.ser.write(bytes.fromhex(mo0hexstr))
        self.ser.write(bytes.fromhex(mo1hexstr))
        self.ser.write(bytes.fromhex(mo2hexstr))
        return
    
    def robotTwin(self,x,y,z):
        pwm0,pwm1,pwm2=self.xytopwm(x,y,-1*z)
        self.drawpwm(pwm0,pwm1,pwm2)
        self.serwrite(pwm0,pwm1,pwm2)
    def show(self):
        global img
        cv2.imshow("marm",img)
        cv2.waitKey(300)
        #恢复背景
        img=imgcon.copy()
    def home(self):
        self.robotTwin(0,0,0)
        self.show()
        cv2.waitKey(5000)
    def destroy(self):
        if self.ser is not None:
            self.ser.close()
        cv2.destroyAllWindows()
        
#配置零件舵机
mM00=mmotor((170+300,240+300),0,0,-45,225)
mM02=mmotor((170+300,240+300),0,0,0,180)
mM01=mmotor((0,0),0,0,0,180)
mM03=mmotor((0,0),0,0,0,180)
#配置零件梁
mMl01=mlever((0,0),200,10,0)
mMl02=mlever((0,0),200,10,0)
mMl03=mlever((0,0),60,10,0)
#组装成机械臂
marm=Marm(mM00,mM01,mM02,mM03,mMl01,mMl02,mMl03)

marm.home()
for i in range(-20,20):
    marm.robotTwin(300,0,i*10)
    marm.show()    
for i in range(-20,20):
    marm.robotTwin(100,0,i*10)
    marm.show()
for i in range(-20,20):
    marm.robotTwin(50,0,i*10)
    marm.show()
    
marm.home()
for i in range(0,35):
    marm.robotTwin(i*10,0,0)
    marm.show() 
marm.destroy()
# Out:
# (1080, 1440, 3)
# 480 360
# (350, 500, 3)
# [<serial.tools.list_ports_common.ListPortInfo object at 0x0000026020E40E48>]
# USB-SERIAL CH340 (COM13)
# Serial<id=0x26020e40fd0, open=True>(port='COM13', baudrate=9600, bytesize=8, parity='N', stopbits=1, timeout=None, xonxoff=False, rtscts=False, dsrdtr=False)
# serial conected
# pwm0,pwm1,pwm2 1500 2138 1416
# angel0,A1,angel2 90 1 82
# mangel0,mangle1,mangle2 90 1 82
# ZJ point (470, 540)
# zrect ((470, 527), (26, 10), 90)
# m01 zcenter is (470, 514)
# ZJ point (470, 514)
# zrect ((470, 526), (-24, 10), 90)
# ZJ point (470, 538)
# zrect ((470, 538), (0, 10), 90)
# 1500 2138 1416
# 05dc 085a 0588
# pwm0,pwm1,pwm2 1749 1423 701
# angel0,A1,angel2 57 129 18
# mangel0,mangle1,mangle2 57 129 18
# ZJ point (470, 540)
# zrect ((419, 461), (190, 10), 57)
# m01 zcenter is (367, 381)
# ZJ point (367, 381)
# zrect ((322, 312), (166, 10), 57)
# ZJ point (276, 242)
# zrect ((276, 242), (0, 10), 57)
# 1749 1423 701
# 06d5 058f 02bd
# pwm0,pwm1,pwm2 1739 1443 721
# angel0,A1,angel2 58 127 19
# mangel0,mangle1,mangle2 58 127 19
# ZJ point (470, 540)
# zrect ((421, 461), (188, 10), 58)
# m01 zcenter is (370, 380)
# ZJ point (370, 380)
# zrect ((327, 311), (164, 10), 58)
# ZJ point (283, 241)
# zrect ((283, 241), (0, 10), 58)
# 1739 1443 721
# 06cb 05a3 02d1
# pwm0,pwm1,pwm2 1729 1461 738
# angel0,A1,angel2 60 123 21
# mangel0,mangle1,mangle2 60 123 21
# ZJ point (470, 540)
# zrect ((424, 460), (186, 10), 60)
# m01 zcenter is (377, 378)
# ZJ point (377, 378)
# zrect ((337, 309), (160, 10), 60)
# ZJ point (296, 239)
# zrect ((296, 239), (0, 10), 60)
# 1729 1461 738
# 06c1 05b5 02e2
# pwm0,pwm1,pwm2 1718 1477 754
# angel0,A1,angel2 61 121 22
# mangel0,mangle1,mangle2 61 121 22
# ZJ point (470, 540)
# zrect ((426, 460), (184, 10), 61)
# m01 zcenter is (381, 379)
# ZJ point (381, 379)
# zrect ((343, 310), (158, 10), 61)
# ZJ point (304, 240)
# zrect ((304, 240), (0, 10), 61)
# 1718 1477 754
# 06b6 05c5 02f2
# pwm0,pwm1,pwm2 1707 1492 769
# angel0,A1,angel2 63 117 24
# mangel0,mangle1,mangle2 63 117 24
# ZJ point (470, 540)
# zrect ((429, 459), (182, 10), 63)
# m01 zcenter is (387, 377)
# ZJ point (387, 377)
# zrect ((353, 309), (154, 10), 63)
# ZJ point (317, 240)
# zrect ((317, 240), (0, 10), 63)
# 1707 1492 769
# 06ab 05d4 0301
# pwm0,pwm1,pwm2 1696 1505 783
# angel0,A1,angel2 64 115 25
# mangel0,mangle1,mangle2 64 115 25
# ZJ point (470, 540)
# zrect ((431, 460), (180, 10), 64)
# m01 zcenter is (391, 378)
# ZJ point (391, 378)
# zrect ((358, 310), (152, 10), 64)
# ZJ point (324, 241)
# zrect ((324, 241), (0, 10), 64)
# 1696 1505 783
# 06a0 05e1 030f
# pwm0,pwm1,pwm2 1685 1518 795
# angel0,A1,angel2 66 113 26
# mangel0,mangle1,mangle2 66 113 26
# ZJ point (470, 540)
# zrect ((434, 459), (178, 10), 66)
# m01 zcenter is (397, 377)
# ZJ point (397, 377)
# zrect ((367, 309), (150, 10), 66)
# ZJ point (336, 240)
# zrect ((336, 240), (0, 10), 66)
# 1685 1518 795
# 0695 05ee 031b
# pwm0,pwm1,pwm2 1673 1529 807
# angel0,A1,angel2 67 111 27
# mangel0,mangle1,mangle2 67 111 27
# ZJ point (470, 540)
# zrect ((436, 459), (178, 10), 67)
# m01 zcenter is (400, 377)
# ZJ point (400, 377)
# zrect ((372, 309), (148, 10), 67)
# ZJ point (342, 240)
# zrect ((342, 240), (0, 10), 67)
# 1673 1529 807
# 0689 05f9 0327
# pwm0,pwm1,pwm2 1661 1540 817
# angel0,A1,angel2 69 109 28
# mangel0,mangle1,mangle2 69 109 28
# ZJ point (470, 540)
# zrect ((439, 458), (176, 10), 69)
# m01 zcenter is (407, 375)
# ZJ point (407, 375)
# zrect ((381, 307), (146, 10), 69)
# ZJ point (354, 238)
# zrect ((354, 238), (0, 10), 69)
# 1661 1540 817
# 067d 0604 0331
# pwm0,pwm1,pwm2 1649 1549 827
# angel0,A1,angel2 70 107 29
# mangel0,mangle1,mangle2 70 107 29
# ZJ point (470, 540)
# zrect ((441, 459), (174, 10), 70)
# m01 zcenter is (410, 376)
# ZJ point (410, 376)
# zrect ((386, 310), (142, 10), 70)
# ZJ point (361, 242)
# zrect ((361, 242), (0, 10), 70)
# 1649 1549 827
# 0671 060d 033b
# pwm0,pwm1,pwm2 1636 1558 836
# angel0,A1,angel2 72 105 30
# mangel0,mangle1,mangle2 72 105 30
# ZJ point (470, 540)
# zrect ((444, 459), (172, 10), 72)
# m01 zcenter is (417, 376)
# ZJ point (417, 376)
# zrect ((396, 310), (140, 10), 72)
# ZJ point (374, 242)
# zrect ((374, 242), (0, 10), 72)
# 1636 1558 836
# 0664 0616 0344
# pwm0,pwm1,pwm2 1623 1566 843
# angel0,A1,angel2 73 105 30
# mangel0,mangle1,mangle2 73 105 30
# ZJ point (470, 540)
# zrect ((445, 458), (172, 10), 73)
# m01 zcenter is (419, 375)
# ZJ point (419, 375)
# zrect ((399, 309), (140, 10), 73)
# ZJ point (378, 241)
# zrect ((378, 241), (0, 10), 73)
# 1623 1566 843
# 0657 061e 034b
# pwm0,pwm1,pwm2 1610 1573 850
# angel0,A1,angel2 76 103 31
# mangel0,mangle1,mangle2 76 103 31
# ZJ point (470, 540)
# zrect ((450, 458), (170, 10), 76)
# m01 zcenter is (429, 375)
# ZJ point (429, 375)
# zrect ((413, 309), (138, 10), 76)
# ZJ point (396, 241)
# zrect ((396, 241), (0, 10), 76)
# 1610 1573 850
# 064a 0625 0352
# pwm0,pwm1,pwm2 1597 1579 857
# angel0,A1,angel2 78 101 32
# mangel0,mangle1,mangle2 78 101 32
# ZJ point (470, 540)
# zrect ((453, 458), (168, 10), 78)
# m01 zcenter is (435, 375)
# ZJ point (435, 375)
# zrect ((421, 309), (136, 10), 78)
# ZJ point (406, 242)
# zrect ((406, 242), (0, 10), 78)
# 1597 1579 857
# 063d 062b 0359
# pwm0,pwm1,pwm2 1583 1584 862
# angel0,A1,angel2 79 101 32
# mangel0,mangle1,mangle2 79 101 32
# ZJ point (470, 540)
# zrect ((454, 458), (168, 10), 79)
# m01 zcenter is (437, 375)
# ZJ point (437, 375)
# zrect ((425, 309), (136, 10), 79)
# ZJ point (411, 242)
# zrect ((411, 242), (0, 10), 79)
# 1583 1584 862
# 062f 0630 035e
# pwm0,pwm1,pwm2 1570 1588 866
# angel0,A1,angel2 81 101 32
# mangel0,mangle1,mangle2 81 101 32
# ZJ point (470, 540)
# zrect ((457, 458), (168, 10), 81)
# m01 zcenter is (443, 374)
# ZJ point (443, 374)
# zrect ((433, 307), (136, 10), 81)
# ZJ point (422, 239)
# zrect ((422, 239), (0, 10), 81)
# 1570 1588 866
# 0622 0634 0362
# pwm0,pwm1,pwm2 1556 1592 870
# angel0,A1,angel2 82 99 33
# mangel0,mangle1,mangle2 82 99 33
# ZJ point (470, 540)
# zrect ((459, 458), (166, 10), 82)
# m01 zcenter is (447, 375)
# ZJ point (447, 375)
# zrect ((438, 310), (132, 10), 82)
# ZJ point (428, 244)
# zrect ((428, 244), (0, 10), 82)
# 1556 1592 870
# 0614 0638 0366
# pwm0,pwm1,pwm2 1542 1595 873
# angel0,A1,angel2 85 99 33
# mangel0,mangle1,mangle2 85 99 33
# ZJ point (470, 540)
# zrect ((463, 458), (166, 10), 85)
# m01 zcenter is (455, 374)
# ZJ point (455, 374)
# zrect ((450, 309), (132, 10), 85)
# ZJ point (444, 242)
# zrect ((444, 242), (0, 10), 85)
# 1542 1595 873
# 0606 063b 0369
# pwm0,pwm1,pwm2 1528 1597 875
# angel0,A1,angel2 87 99 33
# mangel0,mangle1,mangle2 87 99 33
# ZJ point (470, 540)
# zrect ((466, 458), (166, 10), 87)
# m01 zcenter is (461, 374)
# ZJ point (461, 374)
# zrect ((458, 309), (132, 10), 87)
# ZJ point (454, 242)
# zrect ((454, 242), (0, 10), 87)
# 1528 1597 875
# 05f8 063d 036b
# pwm0,pwm1,pwm2 1514 1598 876
# angel0,A1,angel2 88 99 33
# mangel0,mangle1,mangle2 88 99 33
# ZJ point (470, 540)
# zrect ((468, 458), (166, 10), 88)
# m01 zcenter is (465, 374)
# ZJ point (465, 374)
# zrect ((463, 309), (132, 10), 88)
# ZJ point (460, 242)
# zrect ((460, 242), (0, 10), 88)
# 1514 1598 876
# 05ea 063e 036c
# pwm0,pwm1,pwm2 1500 1598 876
# angel0,A1,angel2 90 99 33
# mangel0,mangle1,mangle2 90 99 33
# ZJ point (470, 540)
# zrect ((470, 457), (166, 10), 90)
# m01 zcenter is (470, 374)
# ZJ point (470, 374)
# zrect ((470, 308), (132, 10), 90)
# ZJ point (470, 242)
# zrect ((470, 242), (0, 10), 90)
# 1500 1598 876
# 05dc 063e 036c
# pwm0,pwm1,pwm2 1485 1598 876
# angel0,A1,angel2 93 99 33
# mangel0,mangle1,mangle2 93 99 33
# ZJ point (470, 540)
# zrect ((474, 458), (166, 10), 93)
# m01 zcenter is (478, 374)
# ZJ point (478, 374)
# zrect ((481, 309), (132, 10), 93)
# ZJ point (484, 242)
# zrect ((484, 242), (0, 10), 93)
# 1485 1598 876
# 05cd 063e 036c
# pwm0,pwm1,pwm2 1471 1597 875
# angel0,A1,angel2 94 99 33
# mangel0,mangle1,mangle2 94 99 33
# ZJ point (470, 540)
# zrect ((475, 458), (166, 10), 94)
# m01 zcenter is (480, 374)
# ZJ point (480, 374)
# zrect ((484, 309), (132, 10), 94)
# ZJ point (488, 242)
# zrect ((488, 242), (0, 10), 94)
# 1471 1597 875
# 05bf 063d 036b
# pwm0,pwm1,pwm2 1457 1595 873
# angel0,A1,angel2 96 99 33
# mangel0,mangle1,mangle2 96 99 33
# ZJ point (470, 540)
# zrect ((478, 458), (166, 10), 96)
# m01 zcenter is (486, 374)
# ZJ point (486, 374)
# zrect ((492, 309), (132, 10), 96)
# ZJ point (498, 242)
# zrect ((498, 242), (0, 10), 96)
# 1457 1595 873
# 05b1 063b 0369
# pwm0,pwm1,pwm2 1443 1592 870
# angel0,A1,angel2 99 99 33
# mangel0,mangle1,mangle2 99 99 33
# ZJ point (470, 540)
# zrect ((482, 459), (166, 10), 99)
# m01 zcenter is (494, 376)
# ZJ point (494, 376)
# zrect ((504, 311), (132, 10), 99)
# ZJ point (514, 245)
# zrect ((514, 245), (0, 10), 99)
# 1443 1592 870
# 05a3 0638 0366
# pwm0,pwm1,pwm2 1429 1588 866
# angel0,A1,angel2 100 101 32
# mangel0,mangle1,mangle2 100 101 32
# ZJ point (470, 540)
# zrect ((484, 458), (168, 10), 100)
# m01 zcenter is (498, 375)
# ZJ point (498, 375)
# zrect ((509, 309), (136, 10), 100)
# ZJ point (520, 241)
# zrect ((520, 241), (0, 10), 100)
# 1429 1588 866
# 0595 0634 0362
# pwm0,pwm1,pwm2 1416 1584 862
# angel0,A1,angel2 102 101 32
# mangel0,mangle1,mangle2 102 101 32
# ZJ point (470, 540)
# zrect ((487, 458), (168, 10), 102)
# m01 zcenter is (504, 375)
# ZJ point (504, 375)
# zrect ((518, 309), (136, 10), 102)
# ZJ point (532, 242)
# zrect ((532, 242), (0, 10), 102)
# 1416 1584 862
# 0588 0630 035e
# pwm0,pwm1,pwm2 1402 1579 857
# angel0,A1,angel2 103 101 32
# mangel0,mangle1,mangle2 103 101 32
# ZJ point (470, 540)
# zrect ((488, 459), (168, 10), 103)
# m01 zcenter is (506, 377)
# ZJ point (506, 377)
# zrect ((521, 311), (136, 10), 103)
# ZJ point (536, 244)
# zrect ((536, 244), (0, 10), 103)
# 1402 1579 857
# 057a 062b 0359
# pwm0,pwm1,pwm2 1389 1573 850
# angel0,A1,angel2 105 103 31
# mangel0,mangle1,mangle2 105 103 31
# ZJ point (470, 540)
# zrect ((491, 458), (170, 10), 105)
# m01 zcenter is (512, 375)
# ZJ point (512, 375)
# zrect ((529, 309), (138, 10), 105)
# ZJ point (546, 242)
# zrect ((546, 242), (0, 10), 105)
# 1389 1573 850
# 056d 0625 0352
# pwm0,pwm1,pwm2 1376 1566 843
# angel0,A1,angel2 108 105 30
# mangel0,mangle1,mangle2 108 105 30
# ZJ point (470, 540)
# zrect ((496, 459), (172, 10), 108)
# m01 zcenter is (522, 376)
# ZJ point (522, 376)
# zrect ((543, 310), (140, 10), 108)
# ZJ point (564, 242)
# zrect ((564, 242), (0, 10), 108)
# 1376 1566 843
# 0560 061e 034b
# pwm0,pwm1,pwm2 1363 1558 836
# angel0,A1,angel2 109 105 30
# mangel0,mangle1,mangle2 109 105 30
# ZJ point (470, 540)
# zrect ((497, 459), (172, 10), 109)
# m01 zcenter is (524, 377)
# ZJ point (524, 377)
# zrect ((546, 311), (140, 10), 109)
# ZJ point (568, 244)
# zrect ((568, 244), (0, 10), 109)
# 1363 1558 836
# 0553 0616 0344
# pwm0,pwm1,pwm2 1350 1549 827
# angel0,A1,angel2 111 107 29
# mangel0,mangle1,mangle2 111 107 29
# ZJ point (470, 540)
# zrect ((501, 459), (174, 10), 111)
# m01 zcenter is (531, 377)
# ZJ point (531, 377)
# zrect ((556, 311), (142, 10), 111)
# ZJ point (581, 244)
# zrect ((581, 244), (0, 10), 111)
# 1350 1549 827
# 0546 060d 033b
# pwm0,pwm1,pwm2 1338 1540 817
# angel0,A1,angel2 112 109 28
# mangel0,mangle1,mangle2 112 109 28
# ZJ point (470, 540)
# zrect ((502, 459), (176, 10), 112)
# m01 zcenter is (534, 377)
# ZJ point (534, 377)
# zrect ((561, 310), (146, 10), 112)
# ZJ point (587, 242)
# zrect ((587, 242), (0, 10), 112)
# 1338 1540 817
# 053a 0604 0331
# pwm0,pwm1,pwm2 1326 1529 807
# angel0,A1,angel2 114 111 27
# mangel0,mangle1,mangle2 114 111 27
# ZJ point (470, 540)
# zrect ((506, 459), (178, 10), 114)
# m01 zcenter is (541, 377)
# ZJ point (541, 377)
# zrect ((571, 310), (148, 10), 114)
# ZJ point (600, 242)
# zrect ((600, 242), (0, 10), 114)
# 1326 1529 807
# 052e 05f9 0327
# pwm0,pwm1,pwm2 1314 1518 795
# angel0,A1,angel2 115 113 26
# mangel0,mangle1,mangle2 115 113 26
# ZJ point (470, 540)
# zrect ((507, 460), (178, 10), 115)
# m01 zcenter is (544, 379)
# ZJ point (544, 379)
# zrect ((575, 312), (150, 10), 115)
# ZJ point (606, 243)
# zrect ((606, 243), (0, 10), 115)
# 1314 1518 795
# 0522 05ee 031b
# pwm0,pwm1,pwm2 1303 1505 783
# angel0,A1,angel2 117 115 25
# mangel0,mangle1,mangle2 117 115 25
# ZJ point (470, 540)
# zrect ((510, 460), (180, 10), 117)
# m01 zcenter is (550, 379)
# ZJ point (550, 379)
# zrect ((584, 312), (152, 10), 117)
# ZJ point (618, 244)
# zrect ((618, 244), (0, 10), 117)
# 1303 1505 783
# 0517 05e1 030f
# pwm0,pwm1,pwm2 1292 1492 769
# angel0,A1,angel2 118 117 24
# mangel0,mangle1,mangle2 118 117 24
# ZJ point (470, 540)
# zrect ((512, 460), (182, 10), 118)
# m01 zcenter is (554, 379)
# ZJ point (554, 379)
# zrect ((590, 312), (154, 10), 118)
# ZJ point (625, 243)
# zrect ((625, 243), (0, 10), 118)
# 1292 1492 769
# 050c 05d4 0301
# pwm0,pwm1,pwm2 1281 1477 754
# angel0,A1,angel2 120 121 22
# mangel0,mangle1,mangle2 120 121 22
# ZJ point (470, 540)
# zrect ((515, 461), (184, 10), 120)
# m01 zcenter is (560, 380)
# ZJ point (560, 380)
# zrect ((599, 312), (158, 10), 120)
# ZJ point (638, 243)
# zrect ((638, 243), (0, 10), 120)
# 1281 1477 754
# 0501 05c5 02f2
# pwm0,pwm1,pwm2 1270 1461 738
# angel0,A1,angel2 121 123 21
# mangel0,mangle1,mangle2 121 123 21
# ZJ point (470, 540)
# zrect ((517, 461), (186, 10), 121)
# m01 zcenter is (564, 380)
# ZJ point (564, 380)
# zrect ((605, 312), (160, 10), 121)
# ZJ point (645, 243)
# zrect ((645, 243), (0, 10), 121)
# 1270 1461 738
# 04f6 05b5 02e2
# pwm0,pwm1,pwm2 1260 1443 721
# angel0,A1,angel2 123 127 19
# mangel0,mangle1,mangle2 123 127 19
# ZJ point (470, 540)
# zrect ((521, 462), (188, 10), 123)
# m01 zcenter is (572, 382)
# ZJ point (572, 382)
# zrect ((616, 314), (164, 10), 123)
# ZJ point (660, 244)
# zrect ((660, 244), (0, 10), 123)
# 1260 1443 721
# 04ec 05a3 02d1
# pwm0,pwm1,pwm2 1969 1761 1039
# angel0,A1,angel2 27 69 48
# mangel0,mangle1,mangle2 27 69 48
# ZJ point (470, 540)
# zrect ((412, 511), (132, 10), 27)
# m01 zcenter is (352, 480)
# ZJ point (352, 480)
# zrect ((312, 460), (90, 10), 27)
# ZJ point (271, 439)
# zrect ((271, 439), (0, 10), 27)
# 1969 1761 1039
# 07b1 06e1 040f
# pwm0,pwm1,pwm2 1961 1778 1055
# angel0,A1,angel2 28 66 49
# mangel0,mangle1,mangle2 28 66 49
# ZJ point (470, 540)
# zrect ((413, 510), (130, 10), 28)
# m01 zcenter is (355, 479)
# ZJ point (355, 479)
# zrect ((318, 460), (84, 10), 28)
# ZJ point (280, 439)
# zrect ((280, 439), (0, 10), 28)
# 1961 1778 1055
# 07a9 06f2 041f
# pwm0,pwm1,pwm2 1951 1794 1072
# angel0,A1,angel2 30 63 51
# mangel0,mangle1,mangle2 30 63 51
# ZJ point (470, 540)
# zrect ((417, 510), (124, 10), 30)
# m01 zcenter is (362, 478)
# ZJ point (362, 478)
# zrect ((328, 459), (80, 10), 30)
# ZJ point (292, 438)
# zrect ((292, 438), (0, 10), 30)
# 1951 1794 1072
# 079f 0702 0430
# pwm0,pwm1,pwm2 1940 1810 1088
# angel0,A1,angel2 31 61 52
# mangel0,mangle1,mangle2 31 61 52
# ZJ point (470, 540)
# zrect ((418, 509), (122, 10), 31)
# m01 zcenter is (365, 477)
# ZJ point (365, 477)
# zrect ((332, 457), (78, 10), 31)
# ZJ point (298, 436)
# zrect ((298, 436), (0, 10), 31)
# 1940 1810 1088
# 0794 0712 0440
# pwm0,pwm1,pwm2 1929 1826 1103
# angel0,A1,angel2 33 57 54
# mangel0,mangle1,mangle2 33 57 54
# ZJ point (470, 540)
# zrect ((422, 509), (116, 10), 33)
# m01 zcenter is (373, 477)
# ZJ point (373, 477)
# zrect ((344, 458), (70, 10), 33)
# ZJ point (314, 438)
# zrect ((314, 438), (0, 10), 33)
# 1929 1826 1103
# 0789 0722 044f
# pwm0,pwm1,pwm2 1917 1841 1119
# angel0,A1,angel2 34 55 55
# mangel0,mangle1,mangle2 34 55 55
# ZJ point (470, 540)
# zrect ((423, 509), (114, 10), 34)
# m01 zcenter is (375, 476)
# ZJ point (375, 476)
# zrect ((347, 457), (68, 10), 34)
# ZJ point (318, 437)
# zrect ((318, 437), (0, 10), 34)
# 1917 1841 1119
# 077d 0731 045f
# pwm0,pwm1,pwm2 1903 1855 1133
# angel0,A1,angel2 36 53 56
# mangel0,mangle1,mangle2 36 53 56
# ZJ point (470, 540)
# zrect ((426, 508), (110, 10), 36)
# m01 zcenter is (381, 475)
# ZJ point (381, 475)
# zrect ((356, 457), (64, 10), 36)
# ZJ point (330, 438)
# zrect ((330, 438), (0, 10), 36)
# 1903 1855 1133
# 076f 073f 046d
# pwm0,pwm1,pwm2 1888 1869 1147
# angel0,A1,angel2 39 49 58
# mangel0,mangle1,mangle2 39 49 58
# ZJ point (470, 540)
# zrect ((430, 508), (104, 10), 39)
# m01 zcenter is (389, 475)
# ZJ point (389, 475)
# zrect ((367, 457), (58, 10), 39)
# ZJ point (344, 438)
# zrect ((344, 438), (0, 10), 39)
# 1888 1869 1147
# 0760 074d 047b
# pwm0,pwm1,pwm2 1871 1883 1161
# angel0,A1,angel2 40 47 59
# mangel0,mangle1,mangle2 40 47 59
# ZJ point (470, 540)
# zrect ((431, 508), (102, 10), 40)
# m01 zcenter is (391, 475)
# ZJ point (391, 475)
# zrect ((371, 458), (54, 10), 40)
# ZJ point (350, 440)
# zrect ((350, 440), (0, 10), 40)
# 1871 1883 1161
# 074f 075b 0489
# pwm0,pwm1,pwm2 1853 1896 1174
# angel0,A1,angel2 43 45 60
# mangel0,mangle1,mangle2 43 45 60
# ZJ point (470, 540)
# zrect ((434, 506), (100, 10), 43)
# m01 zcenter is (397, 471)
# ZJ point (397, 471)
# zrect ((379, 454), (50, 10), 43)
# ZJ point (360, 436)
# zrect ((360, 436), (0, 10), 43)
# 1853 1896 1174
# 073d 0768 0496
# pwm0,pwm1,pwm2 1833 1908 1186
# angel0,A1,angel2 46 43 61
# mangel0,mangle1,mangle2 46 43 61
# ZJ point (470, 540)
# zrect ((437, 506), (96, 10), 46)
# m01 zcenter is (403, 470)
# ZJ point (403, 470)
# zrect ((387, 453), (48, 10), 46)
# ZJ point (369, 435)
# zrect ((369, 435), (0, 10), 46)
# 1833 1908 1186
# 0729 0774 04a2
# pwm0,pwm1,pwm2 1811 1920 1198
# angel0,A1,angel2 49 41 62
# mangel0,mangle1,mangle2 49 41 62
# ZJ point (470, 540)
# zrect ((440, 506), (92, 10), 49)
# m01 zcenter is (409, 471)
# ZJ point (409, 471)
# zrect ((395, 455), (44, 10), 49)
# ZJ point (380, 438)
# zrect ((380, 438), (0, 10), 49)
# 1811 1920 1198
# 0713 0780 04ae
# pwm0,pwm1,pwm2 1786 1931 1209
# angel0,A1,angel2 52 39 63
# mangel0,mangle1,mangle2 52 39 63
# ZJ point (470, 540)
# zrect ((443, 505), (90, 10), 52)
# m01 zcenter is (415, 469)
# ZJ point (415, 469)
# zrect ((403, 454), (40, 10), 52)
# ZJ point (390, 438)
# zrect ((390, 438), (0, 10), 52)
# 1786 1931 1209
# 06fa 078b 04b9
# pwm0,pwm1,pwm2 1759 1941 1219
# angel0,A1,angel2 55 37 64
# mangel0,mangle1,mangle2 55 37 64
# ZJ point (470, 540)
# zrect ((446, 505), (86, 10), 55)
# m01 zcenter is (421, 469)
# ZJ point (421, 469)
# zrect ((411, 454), (38, 10), 55)
# ZJ point (400, 438)
# zrect ((400, 438), (0, 10), 55)
# 1759 1941 1219
# 06df 0795 04c3
# pwm0,pwm1,pwm2 1729 1950 1228
# angel0,A1,angel2 60 35 65
# mangel0,mangle1,mangle2 60 35 65
# ZJ point (470, 540)
# zrect ((449, 504), (84, 10), 60)
# m01 zcenter is (427, 467)
# ZJ point (427, 467)
# zrect ((419, 453), (34, 10), 60)
# ZJ point (410, 437)
# zrect ((410, 437), (0, 10), 60)
# 1729 1950 1228
# 06c1 079e 04cc
# pwm0,pwm1,pwm2 1696 1958 1236
# angel0,A1,angel2 64 33 66
# mangel0,mangle1,mangle2 64 33 66
# ZJ point (470, 540)
# zrect ((453, 505), (80, 10), 64)
# m01 zcenter is (434, 468)
# ZJ point (434, 468)
# zrect ((428, 455), (30, 10), 64)
# ZJ point (420, 441)
# zrect ((420, 441), (0, 10), 64)
# 1696 1958 1236
# 06a0 07a6 04d4
# pwm0,pwm1,pwm2 1661 1965 1243
# angel0,A1,angel2 69 33 66
# mangel0,mangle1,mangle2 69 33 66
# ZJ point (470, 540)
# zrect ((456, 503), (80, 10), 69)
# m01 zcenter is (441, 465)
# ZJ point (441, 465)
# zrect ((436, 451), (30, 10), 69)
# ZJ point (430, 436)
# zrect ((430, 436), (0, 10), 69)
# 1661 1965 1243
# 067d 07ad 04db
# pwm0,pwm1,pwm2 1623 1970 1248
# angel0,A1,angel2 73 31 67
# mangel0,mangle1,mangle2 73 31 67
# ZJ point (470, 540)
# zrect ((459, 503), (78, 10), 73)
# m01 zcenter is (447, 465)
# ZJ point (447, 465)
# zrect ((444, 453), (26, 10), 73)
# ZJ point (439, 440)
# zrect ((439, 440), (0, 10), 73)
# 1623 1970 1248
# 0657 07b2 04e0
# pwm0,pwm1,pwm2 1583 1974 1252
# angel0,A1,angel2 79 31 67
# mangel0,mangle1,mangle2 79 31 67
# ZJ point (470, 540)
# zrect ((463, 502), (78, 10), 79)
# m01 zcenter is (455, 463)
# ZJ point (455, 463)
# zrect ((453, 451), (26, 10), 79)
# ZJ point (450, 438)
# zrect ((450, 438), (0, 10), 79)
# 1583 1974 1252
# 062f 07b6 04e4
# pwm0,pwm1,pwm2 1542 1977 1254
# angel0,A1,angel2 85 31 67
# mangel0,mangle1,mangle2 85 31 67
# ZJ point (470, 540)
# zrect ((467, 502), (78, 10), 85)
# m01 zcenter is (463, 462)
# ZJ point (463, 462)
# zrect ((462, 450), (26, 10), 85)
# ZJ point (460, 436)
# zrect ((460, 436), (0, 10), 85)
# 1542 1977 1254
# 0606 07b9 04e6
# pwm0,pwm1,pwm2 1500 1978 1255
# angel0,A1,angel2 90 30 67
# mangel0,mangle1,mangle2 90 30 67
# ZJ point (470, 540)
# zrect ((470, 501), (78, 10), 90)
# m01 zcenter is (470, 462)
# ZJ point (470, 462)
# zrect ((470, 450), (24, 10), 90)
# ZJ point (470, 438)
# zrect ((470, 438), (0, 10), 90)
# 1500 1978 1255
# 05dc 07ba 04e7
# pwm0,pwm1,pwm2 1457 1977 1254
# angel0,A1,angel2 96 31 67
# mangel0,mangle1,mangle2 96 31 67
# ZJ point (470, 540)
# zrect ((474, 502), (78, 10), 96)
# m01 zcenter is (478, 462)
# ZJ point (478, 462)
# zrect ((479, 450), (26, 10), 96)
# ZJ point (480, 436)
# zrect ((480, 436), (0, 10), 96)
# 1457 1977 1254
# 05b1 07b9 04e6
# pwm0,pwm1,pwm2 1416 1974 1252
# angel0,A1,angel2 102 31 67
# mangel0,mangle1,mangle2 102 31 67
# ZJ point (470, 540)
# zrect ((478, 502), (78, 10), 102)
# m01 zcenter is (485, 463)
# ZJ point (485, 463)
# zrect ((487, 451), (26, 10), 102)
# ZJ point (489, 438)
# zrect ((489, 438), (0, 10), 102)
# 1416 1974 1252
# 0588 07b6 04e4
# pwm0,pwm1,pwm2 1376 1970 1248
# angel0,A1,angel2 108 31 67
# mangel0,mangle1,mangle2 108 31 67
# ZJ point (470, 540)
# zrect ((482, 503), (78, 10), 108)
# m01 zcenter is (493, 465)
# ZJ point (493, 465)
# zrect ((497, 453), (26, 10), 108)
# ZJ point (500, 440)
# zrect ((500, 440), (0, 10), 108)
# 1376 1970 1248
# 0560 07b2 04e0
# pwm0,pwm1,pwm2 1338 1965 1243
# angel0,A1,angel2 112 33 66
# mangel0,mangle1,mangle2 112 33 66
# ZJ point (470, 540)
# zrect ((484, 503), (80, 10), 112)
# m01 zcenter is (498, 465)
# ZJ point (498, 465)
# zrect ((503, 452), (30, 10), 112)
# ZJ point (508, 437)
# zrect ((508, 437), (0, 10), 112)
# 1338 1965 1243
# 053a 07ad 04db
# pwm0,pwm1,pwm2 1303 1958 1236
# angel0,A1,angel2 117 33 66
# mangel0,mangle1,mangle2 117 33 66
# ZJ point (470, 540)
# zrect ((488, 505), (80, 10), 117)
# m01 zcenter is (505, 469)
# ZJ point (505, 469)
# zrect ((511, 456), (30, 10), 117)
# ZJ point (517, 442)
# zrect ((517, 442), (0, 10), 117)
# 1303 1958 1236
# 0517 07a6 04d4
# pwm0,pwm1,pwm2 1270 1950 1228
# angel0,A1,angel2 121 35 65
# mangel0,mangle1,mangle2 121 35 65
# ZJ point (470, 540)
# zrect ((491, 504), (84, 10), 121)
# m01 zcenter is (512, 467)
# ZJ point (512, 467)
# zrect ((520, 453), (34, 10), 121)
# ZJ point (528, 438)
# zrect ((528, 438), (0, 10), 121)
# 1270 1950 1228
# 04f6 079e 04cc
# pwm0,pwm1,pwm2 1240 1941 1219
# angel0,A1,angel2 126 37 64
# mangel0,mangle1,mangle2 126 37 64
# ZJ point (470, 540)
# zrect ((495, 506), (86, 10), 126)
# m01 zcenter is (520, 471)
# ZJ point (520, 471)
# zrect ((531, 456), (38, 10), 126)
# ZJ point (542, 440)
# zrect ((542, 440), (0, 10), 126)
# 1240 1941 1219
# 04d8 0795 04c3
# pwm0,pwm1,pwm2 1213 1931 1209
# angel0,A1,angel2 129 39 63
# mangel0,mangle1,mangle2 129 39 63
# ZJ point (470, 540)
# zrect ((498, 506), (90, 10), 129)
# m01 zcenter is (526, 470)
# ZJ point (526, 470)
# zrect ((538, 455), (40, 10), 129)
# ZJ point (550, 439)
# zrect ((550, 439), (0, 10), 129)
# 1213 1931 1209
# 04bd 078b 04b9
# pwm0,pwm1,pwm2 1188 1920 1198
# angel0,A1,angel2 133 41 62
# mangel0,mangle1,mangle2 133 41 62
# ZJ point (470, 540)
# zrect ((501, 507), (92, 10), 133)
# m01 zcenter is (532, 472)
# ZJ point (532, 472)
# zrect ((547, 456), (44, 10), 133)
# ZJ point (561, 439)
# zrect ((561, 439), (0, 10), 133)
# 1188 1920 1198
# 04a4 0780 04ae
# pwm0,pwm1,pwm2 1166 1908 1186
# angel0,A1,angel2 136 43 61
# mangel0,mangle1,mangle2 136 43 61
# ZJ point (470, 540)
# zrect ((504, 507), (96, 10), 136)
# m01 zcenter is (538, 473)
# ZJ point (538, 473)
# zrect ((555, 457), (48, 10), 136)
# ZJ point (571, 439)
# zrect ((571, 439), (0, 10), 136)
# 1166 1908 1186
# 048e 0774 04a2
# pwm0,pwm1,pwm2 1146 1896 1174
# angel0,A1,angel2 138 45 60
# mangel0,mangle1,mangle2 138 45 60
# ZJ point (470, 540)
# zrect ((507, 507), (100, 10), 138)
# m01 zcenter is (543, 473)
# ZJ point (543, 473)
# zrect ((561, 457), (50, 10), 138)
# ZJ point (579, 439)
# zrect ((579, 439), (0, 10), 138)
# 1146 1896 1174
# 047a 0768 0496
# pwm0,pwm1,pwm2 1128 1883 1161
# angel0,A1,angel2 141 47 59
# mangel0,mangle1,mangle2 141 47 59
# ZJ point (470, 540)
# zrect ((509, 508), (102, 10), 141)
# m01 zcenter is (548, 475)
# ZJ point (548, 475)
# zrect ((568, 459), (54, 10), 141)
# ZJ point (588, 441)
# zrect ((588, 441), (0, 10), 141)
# 1128 1883 1161
# 0468 075b 0489
# pwm0,pwm1,pwm2 1111 1869 1147
# angel0,A1,angel2 144 49 58
# mangel0,mangle1,mangle2 144 49 58
# ZJ point (470, 540)
# zrect ((512, 510), (104, 10), 144)
# m01 zcenter is (554, 479)
# ZJ point (554, 479)
# zrect ((577, 462), (58, 10), 144)
# ZJ point (600, 444)
# zrect ((600, 444), (0, 10), 144)
# 1111 1869 1147
# 0457 074d 047b
# pwm0,pwm1,pwm2 1096 1855 1133
# angel0,A1,angel2 145 53 56
# mangel0,mangle1,mangle2 145 53 56
# ZJ point (470, 540)
# zrect ((515, 509), (110, 10), 145)
# m01 zcenter is (559, 477)
# ZJ point (559, 477)
# zrect ((585, 459), (64, 10), 145)
# ZJ point (611, 440)
# zrect ((611, 440), (0, 10), 145)
# 1096 1855 1133
# 0448 073f 046d
# pwm0,pwm1,pwm2 1082 1841 1119
# angel0,A1,angel2 147 55 55
# mangel0,mangle1,mangle2 147 55 55
# ZJ point (470, 540)
# zrect ((517, 509), (114, 10), 147)
# m01 zcenter is (564, 477)
# ZJ point (564, 477)
# zrect ((592, 459), (68, 10), 147)
# ZJ point (620, 440)
# zrect ((620, 440), (0, 10), 147)
# 1082 1841 1119
# 043a 0731 045f
# pwm0,pwm1,pwm2 1070 1826 1103
# angel0,A1,angel2 148 57 54
# mangel0,mangle1,mangle2 148 57 54
# ZJ point (470, 540)
# zrect ((519, 510), (116, 10), 148)
# m01 zcenter is (567, 479)
# ZJ point (567, 479)
# zrect ((596, 461), (70, 10), 148)
# ZJ point (625, 442)
# zrect ((625, 442), (0, 10), 148)
# 1070 1826 1103
# 042e 0722 044f
# pwm0,pwm1,pwm2 1059 1810 1088
# angel0,A1,angel2 150 61 52
# mangel0,mangle1,mangle2 150 61 52
# ZJ point (470, 540)
# zrect ((522, 510), (122, 10), 150)
# m01 zcenter is (574, 479)
# ZJ point (574, 479)
# zrect ((607, 460), (78, 10), 150)
# ZJ point (640, 440)
# zrect ((640, 440), (0, 10), 150)
# 1059 1810 1088
# 0423 0712 0440
# pwm0,pwm1,pwm2 1048 1794 1072
# angel0,A1,angel2 151 63 51
# mangel0,mangle1,mangle2 151 63 51
# ZJ point (470, 540)
# zrect ((524, 510), (124, 10), 151)
# m01 zcenter is (577, 479)
# ZJ point (577, 479)
# zrect ((611, 460), (80, 10), 151)
# ZJ point (645, 440)
# zrect ((645, 440), (0, 10), 151)
# 1048 1794 1072
# 0418 0702 0430
# pwm0,pwm1,pwm2 1038 1778 1055
# angel0,A1,angel2 153 66 49
# mangel0,mangle1,mangle2 153 66 49
# ZJ point (470, 540)
# zrect ((527, 511), (130, 10), 153)
# m01 zcenter is (584, 481)
# ZJ point (584, 481)
# zrect ((621, 462), (84, 10), 153)
# ZJ point (658, 442)
# zrect ((658, 442), (0, 10), 153)
# 1038 1778 1055
# 040e 06f2 041f
# pwm0,pwm1,pwm2 2062 1794 1071
# angel0,A1,angel2 15 63 51
# mangel0,mangle1,mangle2 15 63 51
# ZJ point (470, 540)
# zrect ((411, 524), (124, 10), 15)
# m01 zcenter is (350, 507)
# ZJ point (350, 507)
# zrect ((312, 497), (80, 10), 15)
# ZJ point (273, 486)
# zrect ((273, 486), (0, 10), 15)
# 2062 1794 1071
# 080e 0702 042f
# pwm0,pwm1,pwm2 2057 1812 1089
# angel0,A1,angel2 15 59 53
# mangel0,mangle1,mangle2 15 59 53
# ZJ point (470, 540)
# zrect ((413, 525), (120, 10), 15)
# m01 zcenter is (354, 509)
# ZJ point (354, 509)
# zrect ((319, 500), (74, 10), 15)
# ZJ point (282, 490)
# zrect ((282, 490), (0, 10), 15)
# 2057 1812 1089
# 0809 0714 0441
# pwm0,pwm1,pwm2 2051 1829 1107
# angel0,A1,angel2 16 57 54
# mangel0,mangle1,mangle2 16 57 54
# ZJ point (470, 540)
# zrect ((415, 525), (116, 10), 16)
# m01 zcenter is (358, 508)
# ZJ point (358, 508)
# zrect ((325, 499), (70, 10), 16)
# ZJ point (290, 489)
# zrect ((290, 489), (0, 10), 16)
# 2051 1829 1107
# 0803 0725 0453
# pwm0,pwm1,pwm2 2045 1846 1124
# angel0,A1,angel2 16 53 56
# mangel0,mangle1,mangle2 16 53 56
# ZJ point (470, 540)
# zrect ((418, 525), (110, 10), 16)
# m01 zcenter is (364, 509)
# ZJ point (364, 509)
# zrect ((334, 501), (64, 10), 16)
# ZJ point (302, 491)
# zrect ((302, 491), (0, 10), 16)
# 2045 1846 1124
# 07fd 0736 0464
# pwm0,pwm1,pwm2 2038 1863 1141
# angel0,A1,angel2 18 51 57
# mangel0,mangle1,mangle2 18 51 57
# ZJ point (470, 540)
# zrect ((419, 524), (108, 10), 18)
# m01 zcenter is (367, 507)
# ZJ point (367, 507)
# zrect ((339, 498), (60, 10), 18)
# ZJ point (310, 488)
# zrect ((310, 488), (0, 10), 18)
# 2038 1863 1141
# 07f6 0747 0475
# pwm0,pwm1,pwm2 2030 1880 1157
# angel0,A1,angel2 19 47 59
# mangel0,mangle1,mangle2 19 47 59
# ZJ point (470, 540)
# zrect ((422, 524), (102, 10), 19)
# m01 zcenter is (373, 507)
# ZJ point (373, 507)
# zrect ((348, 499), (54, 10), 19)
# ZJ point (322, 489)
# zrect ((322, 489), (0, 10), 19)
# 2030 1880 1157
# 07ee 0758 0485
# pwm0,pwm1,pwm2 2021 1896 1174
# angel0,A1,angel2 21 45 60
# mangel0,mangle1,mangle2 21 45 60
# ZJ point (470, 540)
# zrect ((424, 523), (100, 10), 21)
# m01 zcenter is (377, 504)
# ZJ point (377, 504)
# zrect ((354, 496), (50, 10), 21)
# ZJ point (330, 486)
# zrect ((330, 486), (0, 10), 21)
# 2021 1896 1174
# 07e5 0768 0496
# pwm0,pwm1,pwm2 2010 1912 1190
# angel0,A1,angel2 22 41 62
# mangel0,mangle1,mangle2 22 41 62
# ZJ point (470, 540)
# zrect ((428, 523), (92, 10), 22)
# m01 zcenter is (385, 505)
# ZJ point (385, 505)
# zrect ((365, 497), (44, 10), 22)
# ZJ point (344, 488)
# zrect ((344, 488), (0, 10), 22)
# 2010 1912 1190
# 07da 0778 04a6
# pwm0,pwm1,pwm2 1999 1928 1205
# angel0,A1,angel2 24 39 63
# mangel0,mangle1,mangle2 24 39 63
# ZJ point (470, 540)
# zrect ((429, 522), (90, 10), 24)
# m01 zcenter is (387, 503)
# ZJ point (387, 503)
# zrect ((369, 495), (40, 10), 24)
# ZJ point (350, 486)
# zrect ((350, 486), (0, 10), 24)
# 1999 1928 1205
# 07cf 0788 04b5
# pwm0,pwm1,pwm2 1985 1943 1221
# angel0,A1,angel2 25 37 64
# mangel0,mangle1,mangle2 25 37 64
# ZJ point (470, 540)
# zrect ((432, 522), (86, 10), 25)
# m01 zcenter is (392, 503)
# ZJ point (392, 503)
# zrect ((375, 495), (38, 10), 25)
# ZJ point (357, 486)
# zrect ((357, 486), (0, 10), 25)
# 1985 1943 1221
# 07c1 0797 04c5
# pwm0,pwm1,pwm2 1969 1958 1236
# angel0,A1,angel2 27 33 66
# mangel0,mangle1,mangle2 27 33 66
# ZJ point (470, 540)
# zrect ((435, 522), (80, 10), 27)
# m01 zcenter is (399, 503)
# ZJ point (399, 503)
# zrect ((386, 497), (30, 10), 27)
# ZJ point (372, 489)
# zrect ((372, 489), (0, 10), 27)
# 1969 1958 1236
# 07b1 07a6 04d4
# pwm0,pwm1,pwm2 1951 1973 1250
# angel0,A1,angel2 30 31 67
# mangel0,mangle1,mangle2 30 31 67
# ZJ point (470, 540)
# zrect ((437, 521), (78, 10), 30)
# m01 zcenter is (402, 501)
# ZJ point (402, 501)
# zrect ((391, 495), (26, 10), 30)
# ZJ point (379, 488)
# zrect ((379, 488), (0, 10), 30)
# 1951 1973 1250
# 079f 07b5 04e2
# pwm0,pwm1,pwm2 1929 1987 1265
# angel0,A1,angel2 33 29 68
# mangel0,mangle1,mangle2 33 29 68
# ZJ point (470, 540)
# zrect ((439, 520), (74, 10), 33)
# m01 zcenter is (407, 499)
# ZJ point (407, 499)
# zrect ((397, 493), (24, 10), 33)
# ZJ point (386, 486)
# zrect ((386, 486), (0, 10), 33)
# 1929 1987 1265
# 0789 07c3 04f1
# pwm0,pwm1,pwm2 1903 2000 1278
# angel0,A1,angel2 36 25 70
# mangel0,mangle1,mangle2 36 25 70
# ZJ point (470, 540)
# zrect ((443, 521), (68, 10), 36)
# m01 zcenter is (415, 500)
# ZJ point (415, 500)
# zrect ((409, 496), (16, 10), 36)
# ZJ point (402, 491)
# zrect ((402, 491), (0, 10), 36)
# 1903 2000 1278
# 076f 07d0 04fe
# pwm0,pwm1,pwm2 1871 2013 1291
# angel0,A1,angel2 40 23 71
# mangel0,mangle1,mangle2 40 23 71
# ZJ point (470, 540)
# zrect ((446, 520), (64, 10), 40)
# m01 zcenter is (421, 499)
# ZJ point (421, 499)
# zrect ((417, 496), (12, 10), 40)
# ZJ point (412, 491)
# zrect ((412, 491), (0, 10), 40)
# 1871 2013 1291
# 074f 07dd 050b
# pwm0,pwm1,pwm2 1833 2025 1303
# angel0,A1,angel2 46 21 72
# mangel0,mangle1,mangle2 46 21 72
# ZJ point (470, 540)
# zrect ((450, 519), (60, 10), 46)
# m01 zcenter is (428, 496)
# ZJ point (428, 496)
# zrect ((425, 493), (10, 10), 46)
# ZJ point (421, 488)
# zrect ((421, 488), (0, 10), 46)
# 1833 2025 1303
# 0729 07e9 0517
# pwm0,pwm1,pwm2 1786 2036 1314
# angel0,A1,angel2 52 19 73
# mangel0,mangle1,mangle2 52 19 73
# ZJ point (470, 540)
# zrect ((453, 518), (58, 10), 52)
# m01 zcenter is (435, 495)
# ZJ point (435, 495)
# zrect ((434, 493), (6, 10), 52)
# ZJ point (432, 490)
# zrect ((432, 490), (0, 10), 52)
# 1786 2036 1314
# 06fa 07f4 0522
# pwm0,pwm1,pwm2 1729 2045 1323
# angel0,A1,angel2 60 17 74
# mangel0,mangle1,mangle2 60 17 74
# ZJ point (470, 540)
# zrect ((457, 517), (54, 10), 60)
# m01 zcenter is (443, 493)
# ZJ point (443, 493)
# zrect ((443, 493), (2, 10), 60)
# ZJ point (442, 491)
# zrect ((442, 491), (0, 10), 60)
# 1729 2045 1323
# 06c1 07fd 052b
# pwm0,pwm1,pwm2 1661 2052 1330
# angel0,A1,angel2 69 17 74
# mangel0,mangle1,mangle2 69 17 74
# ZJ point (470, 540)
# zrect ((461, 515), (54, 10), 69)
# m01 zcenter is (450, 489)
# ZJ point (450, 489)
# zrect ((450, 489), (2, 10), 69)
# ZJ point (449, 487)
# zrect ((449, 487), (0, 10), 69)
# 1661 2052 1330
# 067d 0804 0532
# pwm0,pwm1,pwm2 1583 2057 1335
# angel0,A1,angel2 79 15 75
# mangel0,mangle1,mangle2 79 15 75
# ZJ point (470, 540)
# zrect ((466, 516), (50, 10), 79)
# m01 zcenter is (461, 491)
# ZJ point (461, 491)
# zrect ((461, 491), (0, 10), 79)
# ZJ point (460, 490)
# zrect ((460, 490), (0, 10), 79)
# 1583 2057 1335
# 062f 0809 0537
# pwm0,pwm1,pwm2 1500 2059 1336
# angel0,A1,angel2 90 15 75
# mangel0,mangle1,mangle2 90 15 75
# ZJ point (470, 540)
# zrect ((470, 515), (50, 10), 90)
# m01 zcenter is (470, 490)
# ZJ point (470, 490)
# zrect ((470, 490), (0, 10), 90)
# ZJ point (470, 490)
# zrect ((470, 490), (0, 10), 90)
# 1500 2059 1336
# 05dc 080b 0538
# pwm0,pwm1,pwm2 1416 2057 1335
# angel0,A1,angel2 102 15 75
# mangel0,mangle1,mangle2 102 15 75
# ZJ point (470, 540)
# zrect ((475, 516), (50, 10), 102)
# m01 zcenter is (480, 491)
# ZJ point (480, 491)
# zrect ((480, 491), (0, 10), 102)
# ZJ point (479, 490)
# zrect ((479, 490), (0, 10), 102)
# 1416 2057 1335
# 0588 0809 0537
# pwm0,pwm1,pwm2 1338 2052 1330
# angel0,A1,angel2 112 17 74
# mangel0,mangle1,mangle2 112 17 74
# ZJ point (470, 540)
# zrect ((480, 515), (54, 10), 112)
# m01 zcenter is (489, 489)
# ZJ point (489, 489)
# zrect ((489, 489), (2, 10), 112)
# ZJ point (489, 487)
# zrect ((489, 487), (0, 10), 112)
# 1338 2052 1330
# 053a 0804 0532
# pwm0,pwm1,pwm2 1270 2045 1323
# angel0,A1,angel2 121 17 74
# mangel0,mangle1,mangle2 121 17 74
# ZJ point (470, 540)
# zrect ((483, 517), (54, 10), 121)
# m01 zcenter is (496, 493)
# ZJ point (496, 493)
# zrect ((496, 493), (2, 10), 121)
# ZJ point (496, 491)
# zrect ((496, 491), (0, 10), 121)
# 1270 2045 1323
# 04f6 07fd 052b
# pwm0,pwm1,pwm2 1213 2036 1314
# angel0,A1,angel2 129 19 73
# mangel0,mangle1,mangle2 129 19 73
# ZJ point (470, 540)
# zrect ((488, 518), (58, 10), 129)
# m01 zcenter is (506, 495)
# ZJ point (506, 495)
# zrect ((507, 493), (6, 10), 129)
# ZJ point (508, 490)
# zrect ((508, 490), (0, 10), 129)
# 1213 2036 1314
# 04bd 07f4 0522
# pwm0,pwm1,pwm2 1166 2025 1303
# angel0,A1,angel2 136 21 72
# mangel0,mangle1,mangle2 136 21 72
# ZJ point (470, 540)
# zrect ((491, 520), (60, 10), 136)
# m01 zcenter is (512, 498)
# ZJ point (512, 498)
# zrect ((515, 495), (10, 10), 136)
# ZJ point (518, 491)
# zrect ((518, 491), (0, 10), 136)
# 1166 2025 1303
# 048e 07e9 0517
# pwm0,pwm1,pwm2 1128 2013 1291
# angel0,A1,angel2 141 23 71
# mangel0,mangle1,mangle2 141 23 71
# ZJ point (470, 540)
# zrect ((494, 520), (64, 10), 141)
# m01 zcenter is (518, 499)
# ZJ point (518, 499)
# zrect ((522, 496), (12, 10), 141)
# ZJ point (526, 492)
# zrect ((526, 492), (0, 10), 141)
# 1128 2013 1291
# 0468 07dd 050b
# pwm0,pwm1,pwm2 1096 2000 1278
# angel0,A1,angel2 145 25 70
# mangel0,mangle1,mangle2 145 25 70
# ZJ point (470, 540)
# zrect ((497, 521), (68, 10), 145)
# m01 zcenter is (524, 501)
# ZJ point (524, 501)
# zrect ((530, 497), (16, 10), 145)
# ZJ point (536, 492)
# zrect ((536, 492), (0, 10), 145)
# 1096 2000 1278
# 0448 07d0 04fe
# pwm0,pwm1,pwm2 1070 1987 1265
# angel0,A1,angel2 148 29 68
# mangel0,mangle1,mangle2 148 29 68
# ZJ point (470, 540)
# zrect ((501, 521), (74, 10), 148)
# m01 zcenter is (532, 501)
# ZJ point (532, 501)
# zrect ((542, 495), (24, 10), 148)
# ZJ point (551, 488)
# zrect ((551, 488), (0, 10), 148)
# 1070 1987 1265
# 042e 07c3 04f1
# pwm0,pwm1,pwm2 1048 1973 1250
# angel0,A1,angel2 151 31 67
# mangel0,mangle1,mangle2 151 31 67
# ZJ point (470, 540)
# zrect ((504, 522), (78, 10), 151)
# m01 zcenter is (537, 502)
# ZJ point (537, 502)
# zrect ((548, 496), (26, 10), 151)
# ZJ point (558, 489)
# zrect ((558, 489), (0, 10), 151)
# 1048 1973 1250
# 0418 07b5 04e2
# pwm0,pwm1,pwm2 1030 1958 1236
# angel0,A1,angel2 154 33 66
# mangel0,mangle1,mangle2 154 33 66
# ZJ point (470, 540)
# zrect ((505, 523), (80, 10), 154)
# m01 zcenter is (540, 504)
# ZJ point (540, 504)
# zrect ((553, 498), (30, 10), 154)
# ZJ point (566, 490)
# zrect ((566, 490), (0, 10), 154)
# 1030 1958 1236
# 0406 07a6 04d4
# pwm0,pwm1,pwm2 1014 1943 1221
# angel0,A1,angel2 156 37 64
# mangel0,mangle1,mangle2 156 37 64
# ZJ point (470, 540)
# zrect ((509, 523), (86, 10), 156)
# m01 zcenter is (548, 505)
# ZJ point (548, 505)
# zrect ((565, 498), (38, 10), 156)
# ZJ point (582, 489)
# zrect ((582, 489), (0, 10), 156)
# 1014 1943 1221
# 03f6 0797 04c5
# pwm0,pwm1,pwm2 1000 1928 1205
# angel0,A1,angel2 157 39 63
# mangel0,mangle1,mangle2 157 39 63
# ZJ point (470, 540)
# zrect ((511, 523), (90, 10), 157)
# m01 zcenter is (552, 505)
# ZJ point (552, 505)
# zrect ((570, 498), (40, 10), 157)
# ZJ point (588, 489)
# zrect ((588, 489), (0, 10), 157)
# 1000 1928 1205
# 03e8 0788 04b5
# pwm0,pwm1,pwm2 989 1912 1190
# angel0,A1,angel2 159 41 62
# mangel0,mangle1,mangle2 159 41 62
# ZJ point (470, 540)
# zrect ((512, 524), (92, 10), 159)
# m01 zcenter is (554, 507)
# ZJ point (554, 507)
# zrect ((574, 500), (44, 10), 159)
# ZJ point (594, 491)
# zrect ((594, 491), (0, 10), 159)
# 989 1912 1190
# 03dd 0778 04a6
# pwm0,pwm1,pwm2 978 1896 1174
# angel0,A1,angel2 160 45 60
# mangel0,mangle1,mangle2 160 45 60
# ZJ point (470, 540)
# zrect ((516, 523), (100, 10), 160)
# m01 zcenter is (562, 505)
# ZJ point (562, 505)
# zrect ((585, 497), (50, 10), 160)
# ZJ point (608, 488)
# zrect ((608, 488), (0, 10), 160)
# 978 1896 1174
# 03d2 0768 0496
# pwm0,pwm1,pwm2 969 1880 1157
# angel0,A1,angel2 162 47 59
# mangel0,mangle1,mangle2 162 47 59
# ZJ point (470, 540)
# zrect ((518, 525), (102, 10), 162)
# m01 zcenter is (566, 508)
# ZJ point (566, 508)
# zrect ((591, 500), (54, 10), 162)
# ZJ point (616, 491)
# zrect ((616, 491), (0, 10), 162)
# 969 1880 1157
# 03c9 0758 0485
# pwm0,pwm1,pwm2 961 1863 1141
# angel0,A1,angel2 163 51 57
# mangel0,mangle1,mangle2 163 51 57
# ZJ point (470, 540)
# zrect ((521, 525), (108, 10), 163)
# m01 zcenter is (572, 508)
# ZJ point (572, 508)
# zrect ((600, 500), (60, 10), 163)
# ZJ point (628, 491)
# zrect ((628, 491), (0, 10), 163)
# 961 1863 1141
# 03c1 0747 0475
# pwm0,pwm1,pwm2 954 1846 1124
# angel0,A1,angel2 165 53 56
# mangel0,mangle1,mangle2 165 53 56
# ZJ point (470, 540)
# zrect ((523, 526), (110, 10), 165)
# m01 zcenter is (575, 511)
# ZJ point (575, 511)
# zrect ((605, 503), (64, 10), 165)
# ZJ point (635, 494)
# zrect ((635, 494), (0, 10), 165)
# 954 1846 1124
# 03ba 0736 0464
# pwm0,pwm1,pwm2 948 1829 1107
# angel0,A1,angel2 165 57 54
# mangel0,mangle1,mangle2 165 57 54
# ZJ point (470, 540)
# zrect ((526, 525), (116, 10), 165)
# m01 zcenter is (581, 509)
# ZJ point (581, 509)
# zrect ((614, 500), (70, 10), 165)
# ZJ point (647, 490)
# zrect ((647, 490), (0, 10), 165)
# 948 1829 1107
# 03b4 0725 0453
# pwm0,pwm1,pwm2 942 1812 1089
# angel0,A1,angel2 166 59 53
# mangel0,mangle1,mangle2 166 59 53
# ZJ point (470, 540)
# zrect ((528, 526), (120, 10), 166)
# m01 zcenter is (586, 511)
# ZJ point (586, 511)
# zrect ((621, 503), (74, 10), 166)
# ZJ point (656, 493)
# zrect ((656, 493), (0, 10), 166)
# 942 1812 1089
# 03ae 0714 0441
# pwm0,pwm1,pwm2 1500 2138 1416
# angel0,A1,angel2 90 1 82
# mangel0,mangle1,mangle2 90 1 82
# ZJ point (470, 540)
# zrect ((470, 527), (26, 10), 90)
# m01 zcenter is (470, 514)
# ZJ point (470, 514)
# zrect ((470, 526), (-24, 10), 90)
# ZJ point (470, 538)
# zrect ((470, 538), (0, 10), 90)
# 1500 2138 1416
# 05dc 085a 0588
# pwm0,pwm1,pwm2 1500 2138 1416
# angel0,A1,angel2 90 1 82
# mangel0,mangle1,mangle2 90 1 82
# ZJ point (470, 540)
# zrect ((470, 527), (26, 10), 90)
# m01 zcenter is (470, 514)
# ZJ point (470, 514)
# zrect ((470, 526), (-24, 10), 90)
# ZJ point (470, 538)
# zrect ((470, 538), (0, 10), 90)
# 1500 2138 1416
# 05dc 085a 0588
# pwm0,pwm1,pwm2 1500 2122 1400
# angel0,A1,angel2 90 4 81
# mangel0,mangle1,mangle2 90 4 81
# ZJ point (470, 540)
# zrect ((470, 525), (30, 10), 90)
# m01 zcenter is (470, 510)
# ZJ point (470, 510)
# zrect ((470, 518), (-16, 10), 90)
# ZJ point (470, 526)
# zrect ((470, 526), (0, 10), 90)
# 1500 2122 1400
# 05dc 084a 0578
# pwm0,pwm1,pwm2 1500 2107 1384
# angel0,A1,angel2 90 7 79
# mangel0,mangle1,mangle2 90 7 79
# ZJ point (470, 540)
# zrect ((470, 521), (38, 10), 90)
# m01 zcenter is (470, 502)
# ZJ point (470, 502)
# zrect ((470, 508), (-12, 10), 90)
# ZJ point (470, 514)
# zrect ((470, 514), (0, 10), 90)
# 1500 2107 1384
# 05dc 083b 0568
# pwm0,pwm1,pwm2 1500 2091 1368
# angel0,A1,angel2 90 9 78
# mangel0,mangle1,mangle2 90 9 78
# ZJ point (470, 540)
# zrect ((470, 520), (40, 10), 90)
# m01 zcenter is (470, 500)
# ZJ point (470, 500)
# zrect ((470, 505), (-10, 10), 90)
# ZJ point (470, 510)
# zrect ((470, 510), (0, 10), 90)
# 1500 2091 1368
# 05dc 082b 0558
# pwm0,pwm1,pwm2 1500 2075 1352
# angel0,A1,angel2 90 13 76
# mangel0,mangle1,mangle2 90 13 76
# ZJ point (470, 540)
# zrect ((470, 516), (48, 10), 90)
# m01 zcenter is (470, 492)
# ZJ point (470, 492)
# zrect ((470, 493), (-2, 10), 90)
# ZJ point (470, 494)
# zrect ((470, 494), (0, 10), 90)
# 1500 2075 1352
# 05dc 081b 0548
# pwm0,pwm1,pwm2 1500 2059 1336
# angel0,A1,angel2 90 15 75
# mangel0,mangle1,mangle2 90 15 75
# ZJ point (470, 540)
# zrect ((470, 515), (50, 10), 90)
# m01 zcenter is (470, 490)
# ZJ point (470, 490)
# zrect ((470, 490), (0, 10), 90)
# ZJ point (470, 490)
# zrect ((470, 490), (0, 10), 90)
# 1500 2059 1336
# 05dc 080b 0538
# pwm0,pwm1,pwm2 1500 2043 1320
# angel0,A1,angel2 90 19 73
# mangel0,mangle1,mangle2 90 19 73
# ZJ point (470, 540)
# zrect ((470, 511), (58, 10), 90)
# m01 zcenter is (470, 482)
# ZJ point (470, 482)
# zrect ((470, 479), (6, 10), 90)
# ZJ point (470, 476)
# zrect ((470, 476), (0, 10), 90)
# 1500 2043 1320
# 05dc 07fb 0528
# pwm0,pwm1,pwm2 1500 2026 1304
# angel0,A1,angel2 90 21 72
# mangel0,mangle1,mangle2 90 21 72
# ZJ point (470, 540)
# zrect ((470, 510), (60, 10), 90)
# m01 zcenter is (470, 480)
# ZJ point (470, 480)
# zrect ((470, 475), (10, 10), 90)
# ZJ point (470, 470)
# zrect ((470, 470), (0, 10), 90)
# 1500 2026 1304
# 05dc 07ea 0518
# pwm0,pwm1,pwm2 1500 2010 1288
# angel0,A1,angel2 90 25 70
# mangel0,mangle1,mangle2 90 25 70
# ZJ point (470, 540)
# zrect ((470, 506), (68, 10), 90)
# m01 zcenter is (470, 472)
# ZJ point (470, 472)
# zrect ((470, 464), (16, 10), 90)
# ZJ point (470, 456)
# zrect ((470, 456), (0, 10), 90)
# 1500 2010 1288
# 05dc 07da 0508
# pwm0,pwm1,pwm2 1500 1994 1272
# angel0,A1,angel2 90 27 69
# mangel0,mangle1,mangle2 90 27 69
# ZJ point (470, 540)
# zrect ((470, 505), (70, 10), 90)
# m01 zcenter is (470, 470)
# ZJ point (470, 470)
# zrect ((470, 460), (20, 10), 90)
# ZJ point (470, 450)
# zrect ((470, 450), (0, 10), 90)
# 1500 1994 1272
# 05dc 07ca 04f8
# pwm0,pwm1,pwm2 1500 1978 1255
# angel0,A1,angel2 90 30 67
# mangel0,mangle1,mangle2 90 30 67
# ZJ point (470, 540)
# zrect ((470, 501), (78, 10), 90)
# m01 zcenter is (470, 462)
# ZJ point (470, 462)
# zrect ((470, 450), (24, 10), 90)
# ZJ point (470, 438)
# zrect ((470, 438), (0, 10), 90)
# 1500 1978 1255
# 05dc 07ba 04e7
# pwm0,pwm1,pwm2 1500 1961 1239
# angel0,A1,angel2 90 33 66
# mangel0,mangle1,mangle2 90 33 66
# ZJ point (470, 540)
# zrect ((470, 500), (80, 10), 90)
# m01 zcenter is (470, 460)
# ZJ point (470, 460)
# zrect ((470, 445), (30, 10), 90)
# ZJ point (470, 430)
# zrect ((470, 430), (0, 10), 90)
# 1500 1961 1239
# 05dc 07a9 04d7
# pwm0,pwm1,pwm2 1500 1944 1222
# angel0,A1,angel2 90 37 64
# mangel0,mangle1,mangle2 90 37 64
# ZJ point (470, 540)
# zrect ((470, 497), (86, 10), 90)
# m01 zcenter is (470, 454)
# ZJ point (470, 454)
# zrect ((470, 435), (38, 10), 90)
# ZJ point (470, 416)
# zrect ((470, 416), (0, 10), 90)
# 1500 1944 1222
# 05dc 0798 04c6
# pwm0,pwm1,pwm2 1500 1928 1205
# angel0,A1,angel2 90 39 63
# mangel0,mangle1,mangle2 90 39 63
# ZJ point (470, 540)
# zrect ((470, 495), (90, 10), 90)
# m01 zcenter is (470, 450)
# ZJ point (470, 450)
# zrect ((470, 430), (40, 10), 90)
# ZJ point (470, 410)
# zrect ((470, 410), (0, 10), 90)
# 1500 1928 1205
# 05dc 0788 04b5
# pwm0,pwm1,pwm2 1500 1911 1189
# angel0,A1,angel2 90 42 62
# mangel0,mangle1,mangle2 90 42 62
# ZJ point (470, 540)
# zrect ((470, 494), (92, 10), 90)
# m01 zcenter is (470, 448)
# ZJ point (470, 448)
# zrect ((470, 424), (48, 10), 90)
# ZJ point (470, 400)
# zrect ((470, 400), (0, 10), 90)
# 1500 1911 1189
# 05dc 0777 04a5
# pwm0,pwm1,pwm2 1500 1894 1171
# angel0,A1,angel2 90 45 60
# mangel0,mangle1,mangle2 90 45 60
# ZJ point (470, 540)
# zrect ((470, 490), (100, 10), 90)
# m01 zcenter is (470, 440)
# ZJ point (470, 440)
# zrect ((470, 415), (50, 10), 90)
# ZJ point (470, 390)
# zrect ((470, 390), (0, 10), 90)
# 1500 1894 1171
# 05dc 0766 0493
# pwm0,pwm1,pwm2 1500 1876 1154
# angel0,A1,angel2 90 49 58
# mangel0,mangle1,mangle2 90 49 58
# ZJ point (470, 540)
# zrect ((470, 488), (104, 10), 90)
# m01 zcenter is (470, 436)
# ZJ point (470, 436)
# zrect ((470, 407), (58, 10), 90)
# ZJ point (470, 378)
# zrect ((470, 378), (0, 10), 90)
# 1500 1876 1154
# 05dc 0754 0482
# pwm0,pwm1,pwm2 1500 1859 1137
# angel0,A1,angel2 90 51 57
# mangel0,mangle1,mangle2 90 51 57
# ZJ point (470, 540)
# zrect ((470, 486), (108, 10), 90)
# m01 zcenter is (470, 432)
# ZJ point (470, 432)
# zrect ((470, 402), (60, 10), 90)
# ZJ point (470, 372)
# zrect ((470, 372), (0, 10), 90)
# 1500 1859 1137
# 05dc 0743 0471
# pwm0,pwm1,pwm2 1500 1841 1119
# angel0,A1,angel2 90 55 55
# mangel0,mangle1,mangle2 90 55 55
# ZJ point (470, 540)
# zrect ((470, 483), (114, 10), 90)
# m01 zcenter is (470, 426)
# ZJ point (470, 426)
# zrect ((470, 392), (68, 10), 90)
# ZJ point (470, 358)
# zrect ((470, 358), (0, 10), 90)
# 1500 1841 1119
# 05dc 0731 045f
# pwm0,pwm1,pwm2 1500 1823 1101
# angel0,A1,angel2 90 57 54
# mangel0,mangle1,mangle2 90 57 54
# ZJ point (470, 540)
# zrect ((470, 482), (116, 10), 90)
# m01 zcenter is (470, 424)
# ZJ point (470, 424)
# zrect ((470, 389), (70, 10), 90)
# ZJ point (470, 354)
# zrect ((470, 354), (0, 10), 90)
# 1500 1823 1101
# 05dc 071f 044d
# pwm0,pwm1,pwm2 1500 1805 1083
# angel0,A1,angel2 90 61 52
# mangel0,mangle1,mangle2 90 61 52
# ZJ point (470, 540)
# zrect ((470, 479), (122, 10), 90)
# m01 zcenter is (470, 418)
# ZJ point (470, 418)
# zrect ((470, 379), (78, 10), 90)
# ZJ point (470, 340)
# zrect ((470, 340), (0, 10), 90)
# 1500 1805 1083
# 05dc 070d 043b
# pwm0,pwm1,pwm2 1500 1787 1064
# angel0,A1,angel2 90 65 50
# mangel0,mangle1,mangle2 90 65 50
# ZJ point (470, 540)
# zrect ((470, 476), (128, 10), 90)
# m01 zcenter is (470, 412)
# ZJ point (470, 412)
# zrect ((470, 370), (84, 10), 90)
# ZJ point (470, 328)
# zrect ((470, 328), (0, 10), 90)
# 1500 1787 1064
# 05dc 06fb 0428
# pwm0,pwm1,pwm2 1500 1768 1045
# angel0,A1,angel2 90 67 49
# mangel0,mangle1,mangle2 90 67 49
# ZJ point (470, 540)
# zrect ((470, 475), (130, 10), 90)
# m01 zcenter is (470, 410)
# ZJ point (470, 410)
# zrect ((470, 367), (86, 10), 90)
# ZJ point (470, 324)
# zrect ((470, 324), (0, 10), 90)
# 1500 1768 1045
# 05dc 06e8 0415
# pwm0,pwm1,pwm2 1500 1748 1026
# angel0,A1,angel2 90 71 47
# mangel0,mangle1,mangle2 90 71 47
# ZJ point (470, 540)
# zrect ((470, 472), (136, 10), 90)
# m01 zcenter is (470, 404)
# ZJ point (470, 404)
# zrect ((470, 358), (92, 10), 90)
# ZJ point (470, 312)
# zrect ((470, 312), (0, 10), 90)
# 1500 1748 1026
# 05dc 06d4 0402
# pwm0,pwm1,pwm2 1500 1729 1006
# angel0,A1,angel2 90 75 45
# mangel0,mangle1,mangle2 90 75 45
# ZJ point (470, 540)
# zrect ((470, 470), (140, 10), 90)
# m01 zcenter is (470, 400)
# ZJ point (470, 400)
# zrect ((470, 350), (100, 10), 90)
# ZJ point (470, 300)
# zrect ((470, 300), (0, 10), 90)
# 1500 1729 1006
# 05dc 06c1 03ee
# pwm0,pwm1,pwm2 1500 1709 986
# angel0,A1,angel2 90 79 43
# mangel0,mangle1,mangle2 90 79 43
# ZJ point (470, 540)
# zrect ((470, 467), (146, 10), 90)
# m01 zcenter is (470, 394)
# ZJ point (470, 394)
# zrect ((470, 342), (104, 10), 90)
# ZJ point (470, 290)
# zrect ((470, 290), (0, 10), 90)
# 1500 1709 986
# 05dc 06ad 03da
# pwm0,pwm1,pwm2 1500 1688 966
# angel0,A1,angel2 90 83 41
# mangel0,mangle1,mangle2 90 83 41
# ZJ point (470, 540)
# zrect ((470, 465), (150, 10), 90)
# m01 zcenter is (470, 390)
# ZJ point (470, 390)
# zrect ((470, 335), (110, 10), 90)
# ZJ point (470, 280)
# zrect ((470, 280), (0, 10), 90)
# 1500 1688 966
# 05dc 0698 03c6
# pwm0,pwm1,pwm2 1500 1667 944
# angel0,A1,angel2 90 86 39
# mangel0,mangle1,mangle2 90 86 39
# ZJ point (470, 540)
# zrect ((470, 463), (154, 10), 90)
# m01 zcenter is (470, 386)
# ZJ point (470, 386)
# zrect ((470, 329), (114, 10), 90)
# ZJ point (470, 272)
# zrect ((470, 272), (0, 10), 90)
# 1500 1667 944
# 05dc 0683 03b0
# pwm0,pwm1,pwm2 1500 1645 923
# angel0,A1,angel2 90 89 38
# mangel0,mangle1,mangle2 90 89 38
# ZJ point (470, 540)
# zrect ((470, 462), (156, 10), 90)
# m01 zcenter is (470, 384)
# ZJ point (470, 384)
# zrect ((470, 324), (120, 10), 90)
# ZJ point (470, 264)
# zrect ((470, 264), (0, 10), 90)
# 1500 1645 923
# 05dc 066d 039b
# pwm0,pwm1,pwm2 1500 1622 900
# angel0,A1,angel2 90 94 36
# mangel0,mangle1,mangle2 90 94 36
# ZJ point (470, 540)
# zrect ((470, 460), (160, 10), 90)
# m01 zcenter is (470, 380)
# ZJ point (470, 380)
# zrect ((470, 316), (128, 10), 90)
# ZJ point (470, 252)
# zrect ((470, 252), (0, 10), 90)
# 1500 1622 900
# 05dc 0656 0384
# pwm0,pwm1,pwm2 1500 1598 876
# angel0,A1,angel2 90 99 33
# mangel0,mangle1,mangle2 90 99 33
# ZJ point (470, 540)
# zrect ((470, 457), (166, 10), 90)
# m01 zcenter is (470, 374)
# ZJ point (470, 374)
# zrect ((470, 308), (132, 10), 90)
# ZJ point (470, 242)
# zrect ((470, 242), (0, 10), 90)
# 1500 1598 876
# 05dc 063e 036c
# pwm0,pwm1,pwm2 1500 1574 852
# angel0,A1,angel2 90 103 31
# mangel0,mangle1,mangle2 90 103 31
# ZJ point (470, 540)
# zrect ((470, 455), (170, 10), 90)
# m01 zcenter is (470, 370)
# ZJ point (470, 370)
# zrect ((470, 301), (138, 10), 90)
# ZJ point (470, 232)
# zrect ((470, 232), (0, 10), 90)
# 1500 1574 852
# 05dc 0626 0354
# pwm0,pwm1,pwm2 1500 1548 826
# angel0,A1,angel2 90 107 29
# mangel0,mangle1,mangle2 90 107 29
# ZJ point (470, 540)
# zrect ((470, 453), (174, 10), 90)
# m01 zcenter is (470, 366)
# ZJ point (470, 366)
# zrect ((470, 295), (142, 10), 90)
# ZJ point (470, 224)
# zrect ((470, 224), (0, 10), 90)
# 1500 1548 826
# 05dc 060c 033a
# pwm0,pwm1,pwm2 1500 1521 798
# angel0,A1,angel2 90 113 26
# mangel0,mangle1,mangle2 90 113 26
# ZJ point (470, 540)
# zrect ((470, 451), (178, 10), 90)
# m01 zcenter is (470, 362)
# ZJ point (470, 362)
# zrect ((470, 287), (150, 10), 90)
# ZJ point (470, 212)
# zrect ((470, 212), (0, 10), 90)
# 1500 1521 798
# 05dc 05f1 031e
# pwm0,pwm1,pwm2 1500 1492 769
# angel0,A1,angel2 90 117 24
# mangel0,mangle1,mangle2 90 117 24
# ZJ point (470, 540)
# zrect ((470, 449), (182, 10), 90)
# m01 zcenter is (470, 358)
# ZJ point (470, 358)
# zrect ((470, 281), (154, 10), 90)
# ZJ point (470, 204)
# zrect ((470, 204), (0, 10), 90)
# 1500 1492 769
# 05dc 05d4 0301
