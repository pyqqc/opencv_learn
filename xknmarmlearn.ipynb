# %% [markdown]
# # 用Python对 码垛机器人运动学建模

# %% [markdown]
# ## 机器人照片如下

# %% [markdown]
# ![](marm.jpg)

# %% [markdown]
# # 先用OpenCV在图上标出各个零部件的尺寸，以像素为单位

# %% [markdown]
# ## 为此，先学习一下如何画倾斜的矩形，利用OpenCV中的画轮廓

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")
center=(200,100)
width=200
height=100
angle=10
rect=(center, (width, height), angle)
box = cv2.boxPoints(rect).astype(np.int0)
print(box)
cv2.drawContours(img,[box],0,(255,0,0),3)
cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()
type(box[2])

# %% [markdown]
# # 画一个以左端为基准点同样角度的矩形

# %%
import cv2
import numpy as np
import math as m
img=cv2.imread("marm.jpg")
leftbuttom=(92,131)
width=200
height=100
angle=10
print(m.sin(angle))
print(m.cos(angle))

x=int(m.sin(angle/180*m.pi)*width/2)
y=int(m.cos(angle/188*m.pi)*width/2)
center=leftbuttom+np.array([y,x])
rect=(center, (width, height), angle)
box = cv2.boxPoints(rect).astype(np.int0)
print(box)
cv2.drawContours(img,[box],0,(255,0,0),3)
cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 封装成函数

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#中心点，长度，角度
def drawlever(center,width,angle):
    height=100
    rect=(center, (width, height), angle)
    box = cv2.boxPoints(rect).astype(np.int0)
    cv2.drawContours(img,[box],0,(255,0,0),3)
    cv2.imshow("marm",img)

drawlever((630,250),800,3)    
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 封装成对象

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

# 臂模型
class mlever():
    def __init__(self,center,width,angle):
        self.center=center
        self.width=width
        self.angle=angle

    def drawlever(self):
        center=self.center
        width=self.width
        angle=self.angle
        height=100
        rect=(center, (width, height), angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
        
    def setlever(self,center,width,angle):
        self.center=center
        self.width=width
        self.angle=angle

        
ml01=mlever((315,120),400,3)    
ml02=mlever((380,245),340,140)
ml01.drawlever()
ml02.drawlever()

cv2.imshow("marm",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 电机模型，先画出来圆形和长型

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

angle=0
circlecenter=(260,360)
color=(0,255,0)
r=30
cv2.circle(img,circlecenter,r,color,5)
rect=(circlecenter,(2*r,4),angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)

angle=30
circlecenter=(260,360)
color=(0,255,0)
r=30
cv2.circle(img,circlecenter,r,color,5)
rect=(circlecenter,(2*r,4),angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)

angle=90
circlecenter=(260,360)
color=(0,255,0)
r=30
cv2.circle(img,circlecenter,r,color,5)
rect=(circlecenter,(2*r,4),angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)



cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 封装成函数

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

def drawmotor(center,angle):
    color=(0,255,0)
    r=30
    cv2.circle(img,circlecenter,r,color,5)
    rect=(circlecenter,(2*r,4),angle)
    box = cv2.boxPoints(rect).astype(np.int0)
    cv2.drawContours(img,[box],0,(255,0,0),3)

center=(260,360)
drawmotor(center,0)
drawmotor(center,30)
drawmotor(center,60)
drawmotor(center,90)

cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 封装成对象

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

class mmotor():
    def __init__(self,center,angle,fixangle):
        self.center=center
        self.angle=angle
        self.fixangle=fixangle
        
    def setfixangle(fixangle):
        self.fixangle=fixangle
        
    def setcenter(center):
        self.center=center
        
    def draw(self,angle):
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle+self.fixangle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)

m02=mmotor((260,360),0,0)
m01=mmotor((500,150),0,-30)
for i in range(10):
    m02.draw(i*10)
    m01.draw(i*10)
    cv2.imshow("img",img)
    cv2.waitKey(1000)

cv2.destroyAllWindows()

# %% [markdown]
# # 给杠杆添加联动点以及相对旋转角度

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
imgcon=img.copy()
print(img.shape)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("caculate center")
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            print(w,h)
            self.center=self.jointpoint-np.array([w,h])
            print(self.center)    
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjoitpoint(self,jointpoint):
        self.jointpoint=jointpoint
        
ml02=mlever((380,245),100,10,0)
ml02.setjoitpoint((270,370))

for i in range(12):
    ml02.setangle(i*30)
    ml02.draw()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()
cv2.destroyAllWindows()

# %% [markdown]
# # 一个电机与杆同时动

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,fixangle):
        self.center=center
        self.angle=angle
        self.fixangle=fixangle
        
    def setfixangle(self,fixangle):
        self.fixangle=fixangle
        ,
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle+self.fixangle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(0,0)
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("caculate center")
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=self.jointpoint-np.array([w,h])
            self.rightend=self.center-np.array([w,h])
            print(self.center)    
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjoitpoint(self,jointpoint):
        self.jointpoint=jointpoint
        
m02=mmotor((260,360),0,0)
ml02=mlever((0,0),340,20,0)
ml02.setjoitpoint((260,360))
for i in range(18):
    angle=i*10
    m02.draw(angle)
    ml02.setangle(angle)
    ml02.draw()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %%
import numpy as np

a=[1,1]
print(a)
b=(1,1)
print(b)
c=b
print(c)
d=np.array(a)
type(c)
print(d)
type(a)

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)        
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)
        

m01=mmotor((500,140),0,0)
ml01=mlever((0,0),340,20,0)
ml01.setjointpoint((460,260))
m02=mmotor((260,360),0,0)
ml02=mlever((0,0),340,20,0)
ml02.setjointpoint((260,360))

for i in range(18):
    angle=i*10
    #电机02
    m02.drawrelative(angle)
    #杆02
    ml02.setangle(angle)
    ml02.draw()
    #电机01放在杆02的右端
    m01.setcenter(ml02.rightend)
    m01.startangle=180+m02.angle
    #电机01目前保持30度不变
    m01.drawrelative(30)
    #杆01固定在电机01中心，角度与电机01一样
    ml01.setjointpoint(m01.center)
    ml01.setangle(m01.angle)
    ml01.draw()
    ml01.drawrightend()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 封装机械臂代码xy方向

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)        
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,ml01,ml02):
        self.m01=m01
        self.m02=m02
        self.ml01=ml01
        self.ml02=ml02
        self.angle1=0
        self.angle2=0
        ml02.setjointpoint(m02.center)
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        
m02=mmotor((260,360),0,0)
m01=mmotor((0,0),0,0)
ml01=mlever((0,0),340,20,0)
ml02=mlever((0,0),340,20,0)
marm=Marm(m01,m02,ml01,ml02)

for i in range(36):
    angle=i*5
    angle1=180-angle*2
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(500)
    #恢复背景
    img=imgcon.copy()

for i in range(36):
    angle=180-i*5
    angle1=45
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(500)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 调整机械臂参数，和实际吻合

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)        
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,ml01,ml02):
        self.m01=m01
        self.m02=m02
        self.ml01=ml01
        self.ml02=ml02
        self.angle1=0
        self.angle2=0
        ml02.setjointpoint(m02.center)
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        
m02=mmotor((260,360),0,0)
m01=mmotor((0,0),0,0)
ml01=mlever((0,0),350,20,0)
ml02=mlever((0,0),340,20,0)
marm=Marm(m01,m02,ml01,ml02)

for i in range(36):
    angle=i*5
    angle1=180-angle*2
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(500)
    #恢复背景
    img=imgcon.copy()

for i in range(36):
    angle=180-i*5
    angle1=45
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(500)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 添加吸盘模型，永远垂直

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml02=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        ml02.setjointpoint(m02.center)
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        ml03.setangle(90)
        L=int(ml03.width/2)
        ml03.center=np.add(ml01.rightend,(0,L))
        ml03.draw()
        ml03.drawrightend()
        

m02=mmotor((260+400,360),0,0)
m01=mmotor((0,0),0,0)
m03=mmotor((0,0),0,0)
ml01=mlever((0,0),350,20,0)
ml02=mlever((0,0),340,20,0)
ml03=mlever((0,0),100,20,0)
marm=Marm(m01,m02,m03,ml01,ml02,ml03)

for i in range(30):
    angle=i*5
    angle1=180-angle*2+10
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

for i in range(15):
    angle=150-i*5
    angle1=45
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 用解析法解逆向运动方程

# %% [markdown]
# ![](marmreverse.png)

# %% [markdown]
# im# 已知x，y坐标，为机械臂欲到达的坐标，L1，L2为机械臂长，求电机的角度Q1，Q2=Q4+Q5

# %%
import math as mt

x=500
y=100
L1=350
L2=340

# %% [markdown]
# # 这样可以算出L3

# %%
L3=mt.sqrt(y*y+x*x)
L3

# %% [markdown]
# # 根据海伦公式可以知道L1，L2，L3 组成的三角形面积

# %%
p=(L1+L2+L3)/2
S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
S

# %% [markdown]
# # 求出三角形在L3上的高 0.5*L3*h=s

# %%
h=S*2/L3
h

# %% [markdown]
# # 得出Q5并转换为角度

# %%
Q5=mt.asin(h/L2)/mt.pi*180
Q5

# %% [markdown]
# # 计算出Q4

# %%
Q4=mt.asin(y/L3)/mt.pi*180
Q4

# %% [markdown]
# # 计算出Q7

# %%
Q7=mt.asin(h/L1)/mt.pi*180
Q7

# %% [markdown]
# # 终于，得到了Q1，Q2

# %%
Q1=180-Q5-Q7
Q2=Q5+Q4
print("Q1,Q2",Q1,Q2)

# %% [markdown]
# # 整合为函数

# %%
def xytoq(x,y):
    L1=350
    L2=340
    L3=mt.sqrt(y*y+x*x)
    p=(L1+L2+L3)/2
    S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
    h=S*2/L3
    Q5=mt.asin(h/L2)/mt.pi*180
    Q4=mt.asin(y/L3)/mt.pi*180
    Q7=mt.asin(h/L1)/mt.pi*180
    Q1=180-Q5-Q7
    Q2=Q5+Q4
    #print("Q1,Q2",Q1,Q2)
    return Q1,Q2

print(xytoq(500,100))

# %% [markdown]
# # 整合到对象中

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml02=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        ml02.setjointpoint(m02.center)
    def xytoq(self,x,y):
        L1=ml01.width
        L2=ml02.width
        L3=mt.sqrt(y*y+x*x)
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        ml03.setangle(90)
        L=int(ml03.width/2)
        ml03.center=np.add(ml01.rightend,(0,L))
        ml03.draw()
        ml03.drawrightend()
        

m02=mmotor((260+400,360),0,0)
m01=mmotor((0,0),0,0)
m03=mmotor((0,0),0,0)
ml01=mlever((0,0),350,20,0)
ml02=mlever((0,0),340,20,0)
ml03=mlever((0,0),100,20,0)
marm=Marm(m01,m02,m03,ml01,ml02,ml03)

for i in range(60):
    x=i*10+10
    y=0
    angle1,angle2=marm.xytoq(x,y)
    marm.draw(angle1,angle2)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

for i in range(60):
    x=650-i*10
    y=0
    angle1,angle2=marm.xytoq(x,y)
    marm.draw(angle1,angle2)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

    
    
cv2.destroyAllWindows()

# %% [markdown]
# # 将计算电机控制的PWM值，500~2500

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        self.ml02.setjointpoint(self.m02.center)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        print("angle1disp,angle2disp,angle1,angle2",angle1disp,angle2disp,  angel1,angel2)
        self.robodraw(angel1,angel2)

mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,90)
#mM01.facetome=True
mM03=mmotor((0,0),0,0,180)
mMl01=mlever((0,0),350,20,0)
mMl02=mlever((0,0),350,20,0)
mMl03=mlever((0,0),100,20,0)
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(50):
    x=i*10-100
    y=-40
    angle1,angle2=marm.xytoq(x,y)
    marm.scrdraw(angle1,angle2)
    cv2.imshow("marm",img)
    cv2.waitKey(200)
    #恢复背景
    img=imgcon.copy()

for i in range(50):
    x=400-i*10
    y=-40
    angle1,angle2=marm.xytoq(x,y)
    marm.scrdraw(angle1,angle2)
    cv2.imshow("marm",img)
    cv2.waitKey(200)
    #恢复背景
    img=imgcon.copy()
# [117,54],[126,68],[133,77]
pwmtable=[[0x708,0x44c],[0x76c,0x4e7],[0x7b9,0x54b]]

for j in range(10):
    for i in range(3):
        pwm=pwmtable[i]
        print("pwm",pwm)
        marm.drawpwm(pwm[0],pwm[1])
        cv2.imshow("marm",img)
        cv2.waitKey(1000)
        #恢复背景
        img=imgcon.copy()
cv2.destroyAllWindows()

# %% [markdown]
# # 仿真手工测量的棋盘3个格子的运动pwm命令

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        self.ml02.setjointpoint(self.m02.center)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,angle1,angle2,A2",angle1disp,angle2disp,angel1,angel2)
        self.robodraw(A1,angel2)

mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,180)
#mM01.facetome=True
mM03=mmotor((0,0),0,0,180)
mMl01=mlever((0,0),350,20,0)
mMl02=mlever((0,0),350,20,0)
mMl03=mlever((0,0),100,20,0)
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

# [117,54],[126,68],[133,77]
pwmtable=[[0x708,0x44c],[0x76c,0x4e7],[0x7b9,0x54b]]

i=0
while True:
    pwm=pwmtable[i%3]
    i+=1
    print("pwm",pwm)
    marm.drawpwm(pwm[0],pwm[1])
    cv2.imshow("marm",img)
    if cv2.waitKey(0)&0xff == 27:
        break
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 位置xy通过PWM参数仿真运行

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        #将梁2固定在电机2的中心
        self.ml02.setjointpoint(self.m02.center)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,A1,%x,%x,"%(pwm1,pwm2),angle1disp,angle2disp,A1)
        self.robodraw(A1,angel2)
    def xytopwm(self,x,y):
        q1,q2=self.xytoq(x,y)
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        return pwm1,pwm2
    
    def serwrite(self,pwm1,pwm2):
        print("TBD,serialwrite %x %x"%(pwm1,pwm2))
        return
    
    def robotTwin(self,x,y):
        pwm1,pwm2=self.xytopwm(x,y)
        self.drawpwm(pwm1,pwm2)
        self.serwrite(pwm1,pwm2)
        
#配置零件舵机
mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,180)
mM03=mmotor((0,0),0,0,180)
#配置零件梁
mMl01=mlever((0,0),300,20,0)
mMl02=mlever((0,0),300,20,0)
mMl03=mlever((0,0),100,20,0)
#组装成机械臂
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(50):
    x=i*10+100
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

for i in range(50):
    x=600-i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 添加串口控制机械臂

# %%
import cv2
import numpy as np
import math  as mt
import serial
import serial.tools.list_ports
import string
import binascii
import time


img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        self.ser=None
        #将梁2固定在电机2的中心
        self.ml02.setjointpoint(self.m02.center)
        #打开串口
        ports = list(serial.tools.list_ports.comports())
        print (ports)
        #便利 寻找串口
        for p in ports:
            print (p[1])
            if "serial" in p[1] or "CH340" in p[1]:
                self.ser=serial.Serial(port=p[0])
                if self.ser is not None:
                    print(self.ser)
                    print("serial conected")
                else:
                    print("serial not connected")
                    return
            else:
                print ("No CH340 Device was found connected to the computer")
                return
        self.robotinit()
    def robotinit(self):
        if self.ser is None:
            return
        m0=bytes.fromhex('ff 01 00 08 00')# 舵机0速度为 72
        m1=bytes.fromhex('ff 01 01 08 00')# 舵机1速度为 72
        m2=bytes.fromhex('ff 01 02 08 00')# 舵机2速度为 72
        mo0=bytes.fromhex('ff 02 00 dc 05')#设置初始舵机0位置
        mo1=bytes.fromhex('ff 02 01 82 07')#设置初始舵机1的位置
        mo2 = bytes.fromhex('ff 02 02 dc 05')#设置初始舵机2的位置
        mo3 = bytes.fromhex('ff 02 03 dc 05')#设置初始舵机3的位置
        self.ser.write(m0)
        self.ser.write(m1)
        self.ser.write(m2)
        self.ser.write(mo0)
        self.ser.write(mo1)
        self.ser.write(mo2)
        self.ser.write(mo3)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)+0.01
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        if self.ser is not None:
            cv2.circle(img,(50,50),10,(0,255,0),3)
        else:
            cv2.circle(img,(50,50),10,(0,0,255),3)
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,A1,%x,%x,"%(pwm1,pwm2),angle1disp,angle2disp,A1)
        self.robodraw(A1,angel2)
    def xytopwm(self,x,y):
        q1,q2=self.xytoq(x,y)
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        return pwm1,pwm2
    
    def serwrite(self,pwm1,pwm2):
        if self.ser is None:
            return
        print(pwm1,pwm2)
        pw1str="%04x"%pwm1
        pw2str="%04x"%pwm2
        print(pw1str,pw2str)
        mo1hexstr="ff 02 01"+" "+pw1str[2:4]+" "+pw1str[0:2]
        mo2hexstr="ff 02 02"+" "+pw2str[2:4]+" "+pw2str[0:2]
        self.ser.write(bytes.fromhex(mo1hexstr))
        self.ser.write(bytes.fromhex(mo2hexstr))
        return
    
    def robotTwin(self,x,y):
        pwm1,pwm2=self.xytopwm(x,y)
        self.drawpwm(pwm1,pwm2)
        self.serwrite(pwm1,pwm2)
        
#配置零件舵机
mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,180)
mM03=mmotor((0,0),0,0,180)
#配置零件梁
mMl01=mlever((0,0),300,20,0)
mMl02=mlever((0,0),300,20,0)
mMl03=mlever((0,0),100,20,0)
#组装成机械臂
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(60):
    x=i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()

for i in range(60):
    x=600-i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()
    
marm.ser.close()
cv2.destroyAllWindows()

# %% [markdown]
# # 添加Z方向上的另一个视图

# %%
import cv2
import numpy as np
import math  as mt
import serial
import serial.tools.list_ports
import string
import binascii
import time

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/3)
W=int(shape[1]/3)
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,300,0,300,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
zcenter=(470,300)

#电机模型,
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        #电机中心点随杠杆旋转时电机0位与水平线的夹角
        self.startangle=startangle
        #电机中点为90度，顺时针方向为正，最小点和最大点角度
        self.maxangle=maxangle
        #self.minangle=minangle
        self.relaangle=0
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
        #画z方向
        cv2.circle(img,zcenter,3,(255,0,0),-1)
        
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
        self.zcenter=0
        self.zwidth=0
        self.zheight=20
        self.zangle=90
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)
        #画Z轴的投影
        self.zcenter=self.center
        self.zcenter=(zcenter[0],self.zcenter[0])
        self.zwidth=self.width*mt.cos(self.angle/180*mt.pi)
        self.zangle=90
        zrect=(self.zcenter, (self.zwidth,self.zheight), self.zangle)
        zbox = cv2.boxPoints(zrect).astype(np.int0)
        cv2.drawContours(img,[zbox],0,(0,255,0),3)
        
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        self.ser=None
        self.img=None
        self.imgcon=None
        #将梁2固定在电机2的中心
        self.ml02.setjointpoint(self.m02.center)
        #模拟器初始化
        self.simuinit()
        #串口及机械臂位置初始化
        self.robotinit()
        
    def robotinit(self):
        #打开串口
        ports = list(serial.tools.list_ports.comports())
        print (ports)
        #便利 寻找串口
        for p in ports:
            print (p[1])
            if "serial" in p[1] or "CH340" in p[1]:
                self.ser=serial.Serial(port=p[0])
                if self.ser is not None:
                    print(self.ser)
                    print("serial conected")
                else:
                    print("serial not connected")
                    return
            else:
                print ("No CH340 Device was found connected to the computer")
                return
        if self.ser is None:
            return
        m0=bytes.fromhex('ff 01 00 08 00')# 舵机0速度为 72
        m1=bytes.fromhex('ff 01 01 08 00')# 舵机1速度为 72
        m2=bytes.fromhex('ff 01 02 08 00')# 舵机2速度为 72
        mo0=bytes.fromhex('ff 02 00 dc 05')#设置初始舵机0位置
        mo1=bytes.fromhex('ff 02 01 82 07')#设置初始舵机1的位置
        mo2 = bytes.fromhex('ff 02 02 dc 05')#设置初始舵机2的位置
        mo3 = bytes.fromhex('ff 02 03 dc 05')#设置初始舵机3的位置
        self.ser.write(m0)
        self.ser.write(m1)
        self.ser.write(m2)
        self.ser.write(mo0)
        self.ser.write(mo1)
        self.ser.write(mo2)
        self.ser.write(mo3)
        
    def simuinit(self):
        return

    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)+0.01
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        if self.ser is not None:
            cv2.circle(img,(50,50),10,(0,255,0),3)
        else:
            cv2.circle(img,(50,50),10,(0,0,255),3)
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,A1,%x,%x,"%(pwm1,pwm2),angle1disp,angle2disp,A1)
        self.robodraw(A1,angel2)
    def xytopwm(self,x,y):
        q1,q2=self.xytoq(x,y)
        q2=q2-7
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        return pwm1,pwm2
    
    def serwrite(self,pwm1,pwm2):
        if self.ser is None:
            return
        print(pwm1,pwm2)
        pw1str="%04x"%pwm1
        pw2str="%04x"%pwm2
        print(pw1str,pw2str)
        mo1hexstr="ff 02 01"+" "+pw1str[2:4]+" "+pw1str[0:2]
        mo2hexstr="ff 02 02"+" "+pw2str[2:4]+" "+pw2str[0:2]
        self.ser.write(bytes.fromhex(mo1hexstr))
        self.ser.write(bytes.fromhex(mo2hexstr))
        return
    
    def robotTwin(self,x,y):
        pwm1,pwm2=self.xytopwm(x,y)
        self.drawpwm(pwm1,pwm2)
        self.serwrite(pwm1,pwm2)
    
    def destroy(self):
        if self.ser is not None:
            self.ser.close()
        cv2.destroyAllWindows()
        
#配置零件舵机
mM02=mmotor((170+300,240+300),0,0,180)
mM01=mmotor((0,0),0,0,180)
mM03=mmotor((0,0),0,0,180)
#配置零件梁
mMl01=mlever((0,0),200,10,0)
mMl02=mlever((0,0),200,10,0)
mMl03=mlever((0,0),60,10,0)
#组装成机械臂
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(60):
    x=i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()

for i in range(60):
    x=600-i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()
    
time.sleep(3)
marm.destroy()

# %% [markdown]
# # 让电机0旋转，正向运动模型生成

# %%
import cv2
import numpy as np
import math  as mt
import serial
import serial.tools.list_ports
import string
import binascii
import time

img=cv2.imread("marm.jpg")
img9sea=cv2.imread("9seacut.png")
img9sea=cv2.resize(img9sea,(500,350))
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/3)
W=int(shape[1]/3)
print(W,H)

shape2=img9sea.shape
print(shape2)
H2=shape2[0]
W2=shape2[1]

img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,300,0,300,0,cv2.BORDER_CONSTANT,value=(100,100,0))
img[200:200+H2,200:200+W2]=img9sea
imgcon=img.copy()

#顶视图平面中点
zcenter=(470,300)

#电机模型,
class mmotor():
    def __init__(self,center,angle,startangle,minangle,maxangle):
        self.center=center
        self.angle=angle
        #电机中心点随杠杆旋转时电机0位与水平线的夹角
        self.startangle=startangle
        #电机中点为90度，顺时针方向为正，最小点和最大点角度
        self.maxangle=maxangle
        self.minangle=minangle
        self.relaangle=0
        self.facetome=False
        self.zcenter=(0,0)
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        #通过舵机角度270判断是否为底座舵机，画图时大一些
        if self.maxangle-self.startangle >200:
            r=50
            color=(0,255,0)
            cv2.circle(img,self.center,r,color,3)
            rect=(self.center,(2*r,4),angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            cv2.drawContours(img,[box],0,color,3)
        else:
            r=20
            color=(155,0,0)
            cv2.circle(img,self.center,r,color,3)
            rect=(self.center,(2*r,4),angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            cv2.drawContours(img,[box],0,color,3)
      
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.zjointpoint=(0,0)
        self.rightend=(width,0)
        self.zrightend=(0,0)
        self.rightendr=10
        self.zcenter=(0,0)
        self.zwidth=100
        self.zheight=10
        self.zangle=60
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转 w,h为中心点相对坐标
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            #z轴的投影长度为中心点坐标的一倍
            self.zwidth=2*w
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            #z轴的投影长度为中心点坐标的一倍
            self.zwidth=2*w
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(155,0,0),3)
        #画Z轴的投影
        if self.zjointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("ZJ point",self.zjointpoint)
            w=int(self.zwidth/2*mt.cos(self.zangle/180*mt.pi))
            h=int(self.zwidth/2*mt.sin(self.zangle/180*mt.pi))
            self.zcenter=(self.zjointpoint[0]-w,self.zjointpoint[1]-h)
        else:
            self.zcenter=zcenter
            pass
        zrect=(self.zcenter, (self.zwidth,self.zheight), self.zangle)
        print("zrect",zrect)
        zbox = cv2.boxPoints(zrect).astype(np.int0)
        self.zrightend=(int((zbox[0][0]+zbox[1][0])/2),int((zbox[0][1]+zbox[1][1])/2))
        cv2.drawContours(img,[zbox],0,(0,255,0),3)
        
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def setzjointpoint(self,jointpoint):
        self.zjointpoint=jointpoint
    def setzangle(self,angle):
        self.zangle=angle
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)
        cv2.circle(img,self.zrightend,self.rightendr,(0,255,0),3)

class Marm():
    def __init__(self,m00,m01,m02,m03,ml01,ml02,ml03):
        self.m00=m00
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.ser=None
        self.img=None
        self.imgcon=None
        

        #模拟器初始化
        self.simuinit()
        #串口及机械臂位置初始化
        self.robotinit()
        
    def robotinit(self):
        #打开串口
        ports = list(serial.tools.list_ports.comports())
        print (ports)
        #便利 寻找串口
        for p in ports:
            print (p[1])
            if "serial" in p[1] or "CH340" in p[1]:
                self.ser=serial.Serial(port=p[0])
                if self.ser is not None:
                    print(self.ser)
                    print("serial conected")
                else:
                    print("serial not connected")
                    return
            else:
                print ("No CH340 Device was found connected to the computer")
                return
        if self.ser is None:
            return
        m0=bytes.fromhex('ff 01 00 08 00')# 舵机0速度为 72
        m1=bytes.fromhex('ff 01 01 08 00')# 舵机1速度为 72
        m2=bytes.fromhex('ff 01 02 08 00')# 舵机2速度为 72
        mo0=bytes.fromhex('ff 02 00 dc 05')#设置初始舵机0位置
        mo1=bytes.fromhex('ff 02 01 82 07')#设置初始舵机1的位置
        mo2 = bytes.fromhex('ff 02 02 dc 05')#设置初始舵机2的位置
        mo3 = bytes.fromhex('ff 02 03 dc 05')#设置初始舵机3的位置
        self.ser.write(m0)
        self.ser.write(m1)
        self.ser.write(m2)
        self.ser.write(mo0)
        self.ser.write(mo1)
        self.ser.write(mo2)
        self.ser.write(mo3)
        
    def simuinit(self):
        return
    
    def xztoq0(self,x,z):
        r=mt.sqrt(x*x+z*z+0.01)
        if z >=0:
            q0=180-mt.acos(z/r)/mt.pi*180
        else:
            q0=mt.acos(abs(z)/r)/mt.pi*180
        return q0
    
    def xytoq12(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)+0.01
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置,考虑杆的移动相对位置
    def scrdraw(self,angle0,angle1,angle2):
        #电机0在底盘
        self.m00.drawrelative(angle0)
        #杆02与电机0中心在z轴方向相连
        self.ml02.setzjointpoint(self.m00.center)
        self.ml02.setzangle(angle0)
        #电机02
        self.m02.drawrelative(angle2)
         #杆02,与m02的圆心相连
        self.ml02.setangle(angle2)
        self.ml02.draw()
        self.ml02.setjointpoint(self.m02.center)
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.zcenter=self.ml02.zrightend
        print("m01 zcenter is",self.m01.zcenter)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.setzjointpoint(self.m01.zcenter)
        self.ml01.setzangle(angle0)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.setzjointpoint(self.ml01.zrightend)
        self.ml03.setzangle(angle0)
        self.ml03.draw()
        self.ml03.drawrightend()
        #显示串口连接状态红未连接绿连接
        if self.ser is not None:
            cv2.circle(img,(50,50),10,(0,255,0),3)
        else:
            cv2.circle(img,(50,50),10,(0,0,255),3)
        
    #输入角度考虑电机是否对面装配，从而是逆时针旋转，然后画在图上   
    def robodraw(self,angle0,angle1,angle2):
        mangle0=angle0
        mangle1=angle1
        mangle2=angle2
        if self.m00.facetome == True:
            print("facetome")
            mangle0=self.m00.maxangle-angle0
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            print("facetome")
            mangle2=slef.m02.maxangle-angle2
        print("mangel0,mangle1,mangle2",mangle0,mangle1,mangle2)
        self.scrdraw(mangle0,mangle1,mangle2)
    
    #输入PWM值画机械臂。对于非180度舵机实施缩放处理。对零位非0度的情况进行处理
    def drawpwm(self,pwm0,pwm1,pwm2):
        angle0pc=int((pwm0-500)/2000*180)
        angle0pc=180-angle0pc
        angle1pc=int((pwm1-500)/2000*180)
        angle2pc=int((pwm2-500)/2000*180)
        angel0=int(angle0pc*(self.m00.maxangle-self.m00.minangle)/180)+self.m00.minangle
        angel1=int(angle1pc*(self.m01.maxangle-self.m01.minangle)/180)+self.m01.minangle
        angel2=int(angle2pc*(self.m02.maxangle-self.m02.minangle)/180)+self.m02.minangle
        A1=180+50-(angel1+angel2)
        print("angel0,A1,angel2",angel0,A1,angel2)
        self.robodraw(angel0,A1,angel2)
        
    def xytopwm(self,x,y,z):
        r=mt.sqrt(x*x+z*z)
        q1,q2=self.xytoq12(r,y)
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        
        q0=self.xztoq0(x,z)
        qq0=q0-self.m00.minangle
        pwmq0=qq0/(self.m00.maxangle-self.m00.minangle)*180
        pwm0=int(pwmq0/180*2000+500)
        print("pwm0,pwm1,pwm2",pwm0,pwm1,pwm2)
        return pwm0,pwm1,pwm2
    
    def serwrite(self,pwm0,pwm1,pwm2):
        if self.ser is None:
            return
        print(pwm0,pwm1,pwm2)
        pw0str="%04x"%pwm0
        pw1str="%04x"%pwm1
        pw2str="%04x"%pwm2
        print(pw0str,pw1str,pw2str)
        mo0hexstr="ff 02 00"+" "+pw0str[2:4]+" "+pw0str[0:2]
        mo1hexstr="ff 02 01"+" "+pw1str[2:4]+" "+pw1str[0:2]
        mo2hexstr="ff 02 02"+" "+pw2str[2:4]+" "+pw2str[0:2]
        self.ser.write(bytes.fromhex(mo0hexstr))
        self.ser.write(bytes.fromhex(mo1hexstr))
        self.ser.write(bytes.fromhex(mo2hexstr))
        return
    
    def robotTwin(self,x,y,z):
        pwm0,pwm1,pwm2=self.xytopwm(x,y,-1*z)
        self.drawpwm(pwm0,pwm1,pwm2)
        self.serwrite(pwm0,pwm1,pwm2)
    def show(self):
        global img
        cv2.imshow("marm",img)
        cv2.waitKey(300)
        #恢复背景
        img=imgcon.copy()
    def home(self):
        self.robotTwin(0,0,0)
        self.show()
        cv2.waitKey(5000)
    def destroy(self):
        if self.ser is not None:
            self.ser.close()
        cv2.destroyAllWindows()
        
#配置零件舵机
mM00=mmotor((170+300,240+300),0,0,-45,225)
mM02=mmotor((170+300,240+300),0,0,0,180)
mM01=mmotor((0,0),0,0,0,180)
mM03=mmotor((0,0),0,0,0,180)
#配置零件梁
mMl01=mlever((0,0),200,10,0)
mMl02=mlever((0,0),200,10,0)
mMl03=mlever((0,0),60,10,0)
#组装成机械臂
marm=Marm(mM00,mM01,mM02,mM03,mMl01,mMl02,mMl03)

marm.home()
for i in range(-25,25):
    marm.robotTwin(300,0,i*10)
    marm.show()    
    time.sleep(1)
for i in range(-25,25):
    marm.robotTwin(100,0,i*10)
    marm.show()    
    time.sleep(1)
    
marm.destroy()

# %% [markdown]
# # x 轴方向移动时贴地面有高度差，找原因并调整

# %%
import cv2
import numpy as np
import math  as mt
import serial
import serial.tools.list_ports
import string
import binascii
import time

img=cv2.imread("marm.jpg")
img9sea=cv2.imread("9seacut.png")
img9sea=cv2.resize(img9sea,(420,395))
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/3)
W=int(shape[1]/3)
print(W,H)

shape2=img9sea.shape
print(shape2)
H2=shape2[0]
W2=shape2[1]

img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,300,0,300,0,cv2.BORDER_CONSTANT,value=(100,100,0))
img[90:90+H2,250:250+W2]=img9sea
imgcon=img.copy()

#顶视图平面中点
zcenter=(470,300)

#电机模型,
class mmotor():
    def __init__(self,center,angle,startangle,minangle,maxangle):
        self.center=center
        self.angle=angle
        #电机中心点随杠杆旋转时电机0位与水平线的夹角
        self.startangle=startangle
        #电机中点为90度，顺时针方向为正，最小点和最大点角度
        self.maxangle=maxangle
        self.minangle=minangle
        self.relaangle=0
        self.facetome=False
        self.zcenter=(0,0)
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        #通过舵机角度270判断是否为底座舵机，画图时大一些
        if self.maxangle-self.startangle >200:
            r=50
            color=(0,255,0)
            cv2.circle(img,self.center,r,color,3)
            rect=(self.center,(2*r,4),angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            cv2.drawContours(img,[box],0,color,3)
        else:
            r=20
            color=(155,0,0)
            cv2.circle(img,self.center,r,color,3)
            rect=(self.center,(2*r,4),angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            cv2.drawContours(img,[box],0,color,3)
      
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.zjointpoint=(0,0)
        self.rightend=(width,0)
        self.zrightend=(0,0)
        self.rightendr=10
        self.zcenter=(0,0)
        self.zwidth=100
        self.zheight=10
        self.zangle=60
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转 w,h为中心点相对坐标
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            #z轴的投影长度为中心点坐标的一倍
            self.zwidth=2*w
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            #z轴的投影长度为中心点坐标的一倍
            self.zwidth=2*w
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(155,0,0),3)
        #画Z轴的投影
        print("ZJ point",self.zjointpoint)
        if (self.zwidth==0):
            zwidth=75
        else:
            zwidth=self.zwidth
        w=int(zwidth/2*mt.cos(self.zangle/180*mt.pi))
        h=int(zwidth/2*mt.sin(self.zangle/180*mt.pi))
        self.zcenter=(self.zjointpoint[0]-w,self.zjointpoint[1]-h)
 
        zrect=(self.zcenter, (zwidth,self.zheight), self.zangle)
        print("zrect",zrect)
        zbox = cv2.boxPoints(zrect).astype(np.int0)
        self.zrightend=(int((zbox[0][0]+zbox[1][0])/2),int((zbox[0][1]+zbox[1][1])/2))
        cv2.drawContours(img,[zbox],0,(0,255,0),3)
        
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def setzjointpoint(self,jointpoint):
        self.zjointpoint=jointpoint
    def setzangle(self,angle):
        self.zangle=angle
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)
        cv2.circle(img,self.zrightend,self.rightendr,(0,255,0),3)

class Marm():
    def __init__(self,m00,m01,m02,m03,ml01,ml02,ml03):
        self.m00=m00
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.ser=None
        self.img=None
        self.imgcon=None
        self.zl03=75
        self.x0=75
        

        #模拟器初始化
        self.simuinit()
        #串口及机械臂位置初始化
        self.robotinit()
        
    def robotinit(self):
        #打开串口
        ports = list(serial.tools.list_ports.comports())
        print (ports)
        #便利 寻找串口
        for p in ports:
            print (p[1])
            if "serial" in p[1] or "CH340" in p[1]:
                self.ser=serial.Serial(port=p[0])
                if self.ser is not None:
                    print(self.ser)
                    print("serial conected")
                else:
                    print("serial not connected")
                    return
            else:
                print ("No CH340 Device was found connected to the computer")
                return
        if self.ser is None:
            return
        m0=bytes.fromhex('ff 01 00 08 00')# 舵机0速度为 72
        m1=bytes.fromhex('ff 01 01 08 00')# 舵机1速度为 72
        m2=bytes.fromhex('ff 01 02 08 00')# 舵机2速度为 72
        mo0=bytes.fromhex('ff 02 00 dc 05')#设置初始舵机0位置
        mo1=bytes.fromhex('ff 02 01 82 07')#设置初始舵机1的位置
        mo2 = bytes.fromhex('ff 02 02 dc 05')#设置初始舵机2的位置
        mo3 = bytes.fromhex('ff 02 03 dc 05')#设置初始舵机3的位置
        self.ser.write(m0)
        self.ser.write(m1)
        self.ser.write(m2)
        self.ser.write(mo0)
        self.ser.write(mo1)
        self.ser.write(mo2)
        self.ser.write(mo3)
        
    def simuinit(self):
        return
    
    def xztoq0(self,x,z):
        r=mt.sqrt(x*x+z*z+0.01)
        if z >=0:
            q0=180-mt.acos(z/r)/mt.pi*180
        else:
            q0=mt.acos(abs(z)/r)/mt.pi*180
        return q0
    
    def xytoq12(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)+0.01
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置,考虑杆的移动相对位置
    def scrdraw(self,angle0,angle1,angle2):
        #电机0在底盘
        self.m00.drawrelative(angle0)
        #杆02与电机0中心在z轴方向相连
        self.ml02.setzjointpoint(self.m00.center)
        self.ml02.setzangle(angle0)
        #电机02
        self.m02.drawrelative(angle2)
         #杆02,与m02的圆心相连
        self.ml02.setangle(angle2)
        self.ml02.draw()
        self.ml02.setjointpoint(self.m02.center)
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.zcenter=self.ml02.zrightend
        print("m01 zcenter is",self.m01.zcenter)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.setzjointpoint(self.m01.zcenter)
        self.ml01.setzangle(angle0)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方靠左75
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(-75,L))
        self.ml03.setzjointpoint(self.ml01.zrightend)
        self.ml03.setzangle(angle0)
        self.ml03.draw()
        self.ml03.drawrightend()
        #显示串口连接状态红未连接绿连接
        if self.ser is not None:
            cv2.circle(img,(50,50),10,(0,255,0),3)
        else:
            cv2.circle(img,(50,50),10,(0,0,255),3)
        
    #输入角度考虑电机是否对面装配，从而是逆时针旋转，然后画在图上   
    def robodraw(self,angle0,angle1,angle2):
        mangle0=angle0
        mangle1=angle1
        mangle2=angle2
        if self.m00.facetome == True:
            print("facetome")
            mangle0=self.m00.maxangle-angle0
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            print("facetome")
            mangle2=slef.m02.maxangle-angle2
        print("mangel0,mangle1,mangle2",mangle0,mangle1,mangle2)
        self.scrdraw(mangle0,mangle1,mangle2)
    
    #输入PWM值画机械臂。对于非180度舵机实施缩放处理。对零位非0度的情况进行处理
    def drawpwm(self,pwm0,pwm1,pwm2):
        angle0pc=int((pwm0-500)/2000*180)
        angle0pc=180-angle0pc
        angle1pc=int((pwm1-500)/2000*180)
        angle2pc=int((pwm2-500)/2000*180)
        angel0=int(angle0pc*(self.m00.maxangle-self.m00.minangle)/180)+self.m00.minangle
        angel1=int(angle1pc*(self.m01.maxangle-self.m01.minangle)/180)+self.m01.minangle
        angel2=int(angle2pc*(self.m02.maxangle-self.m02.minangle)/180)+self.m02.minangle
        A1=180+50-(angel1+angel2)
        print("angel0,A1,angel2",angel0,A1,angel2)
        self.robodraw(angel0,A1,angel2)
        
    def xytopwm(self,x,y,z):
        r=mt.sqrt(x*x+z*z)
        #考虑到吸盘与杆1端点之间有60毫米距离，200*60/160=75
        r-=75
        print("r",r)
        q1,q2=self.xytoq12(r,y)
        q2=q2-7.2
        # q1=180+50-(q2+pwmq1)
        #50，20为舵机安装倾斜角度
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        
        q0=self.xztoq0(x+self.x0,z)
        qq0=q0-self.m00.minangle
        pwmq0=qq0/(self.m00.maxangle-self.m00.minangle)*180
        pwm0=int(pwmq0/180*2000+500)
        print("pwm0,pwm1,pwm2",pwm0,pwm1,pwm2)
        return pwm0,pwm1,pwm2
    
    def serwrite(self,pwm0,pwm1,pwm2):
        if self.ser is None:
            return
        print(pwm0,pwm1,pwm2)
        pw0str="%04x"%pwm0
        pw1str="%04x"%pwm1
        pw2str="%04x"%pwm2
        print(pw0str,pw1str,pw2str)
        mo0hexstr="ff 02 00"+" "+pw0str[2:4]+" "+pw0str[0:2]
        mo1hexstr="ff 02 01"+" "+pw1str[2:4]+" "+pw1str[0:2]
        mo2hexstr="ff 02 02"+" "+pw2str[2:4]+" "+pw2str[0:2]
        self.ser.write(bytes.fromhex(mo0hexstr))
        self.ser.write(bytes.fromhex(mo1hexstr))
        self.ser.write(bytes.fromhex(mo2hexstr))
        return
    
    def robotTwin(self,x,y,z):
        pwm0,pwm1,pwm2=self.xytopwm(x,y,-1*z)
        self.drawpwm(pwm0,pwm1,pwm2)
        self.serwrite(pwm0,pwm1,pwm2)
    def show(self):
        global img
        cv2.imshow("marm",img)
        cv2.waitKey(1000)
        #恢复背景
        img=imgcon.copy()
    def home(self):
        self.robotTwin(0,0,0)
        self.show()
        cv2.waitKey(5000)
    def destroy(self):
        if self.ser is not None:
            self.ser.close()
        cv2.destroyAllWindows()
        
#配置零件舵机
mM00=mmotor((170+300,240+300),0,0,-45,225)
mM02=mmotor((170+300,240+300),0,0,0,180)
mM01=mmotor((0,0),0,0,0,180)
mM03=mmotor((0,0),0,0,0,180)
#配置零件梁
mMl01=mlever((0,0),200,10,0)
mMl02=mlever((0,0),200,10,0)
mMl03=mlever((0,0),60,10,0)
#组装成机械臂
marm=Marm(mM00,mM01,mM02,mM03,mMl01,mMl02,mMl03)


marm.home()
for i in range(0,60):
    marm.robotTwin(150,0,i*10-300)
    marm.show() 
    time.sleep(2)
marm.destroy()

# %% [markdown]
# # 线性不好，退回到z方向的极坐标正向模型测试，找原因

# %%
import cv2
import numpy as np
import math  as mt
import serial
import serial.tools.list_ports
import string
import binascii
import time

img=cv2.imread("marm.jpg")
img9sea=cv2.imread("9seacut.png")
img9sea=cv2.resize(img9sea,(520,460))
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/3)
W=int(shape[1]/3)
print(W,H)

shape2=img9sea.shape
print(shape2)
H2=shape2[0]
W2=shape2[1]

img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,300,0,300,0,cv2.BORDER_CONSTANT,value=(100,100,0))
img[120:120+H2,200:200+W2]=img9sea
imgcon=img.copy()

#顶视图平面中点
zcenter=(470,300)

#电机模型,
class mmotor():
    def __init__(self,center,angle,startangle,minangle,maxangle):
        self.center=center
        self.angle=angle
        #电机中心点随杠杆旋转时电机0位与水平线的夹角
        self.startangle=startangle
        #电机中点为90度，顺时针方向为正，最小点和最大点角度
        self.maxangle=maxangle
        self.minangle=minangle
        self.relaangle=0
        self.facetome=False
        self.zcenter=(0,0)
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        #通过舵机角度270判断是否为底座舵机，画图时大一些
        if self.maxangle-self.startangle >200:
            r=50
            color=(0,255,0)
            cv2.circle(img,self.center,r,color,3)
            rect=(self.center,(2*r,4),angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            cv2.drawContours(img,[box],0,color,3)
        else:
            r=20
            color=(155,0,0)
            cv2.circle(img,self.center,r,color,3)
            rect=(self.center,(2*r,4),angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            cv2.drawContours(img,[box],0,color,3)
      
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.zjointpoint=(0,0)
        self.rightend=(width,0)
        self.zrightend=(0,0)
        self.rightendr=10
        self.zcenter=(0,0)
        self.zwidth=100
        self.zheight=10
        self.zangle=60
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转 w,h为中心点相对坐标
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            #z轴的投影长度为中心点坐标的一倍
            self.zwidth=2*w
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            #z轴的投影长度为中心点坐标的一倍
            self.zwidth=2*w
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(155,0,0),3)
        #画Z轴的投影
        print("ZJ point",self.zjointpoint)
        if (self.zwidth==0):
            zwidth=75
        else:
            zwidth=self.zwidth
        w=int(zwidth/2*mt.cos(self.zangle/180*mt.pi))
        h=int(zwidth/2*mt.sin(self.zangle/180*mt.pi))
        self.zcenter=(self.zjointpoint[0]-w,self.zjointpoint[1]-h)
 
        zrect=(self.zcenter, (zwidth,self.zheight), self.zangle)
        print("zrect",zrect)
        zbox = cv2.boxPoints(zrect).astype(np.int0)
        self.zrightend=(int((zbox[0][0]+zbox[1][0])/2),int((zbox[0][1]+zbox[1][1])/2))
        cv2.drawContours(img,[zbox],0,(0,255,0),3)
        
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def setzjointpoint(self,jointpoint):
        self.zjointpoint=jointpoint
    def setzangle(self,angle):
        self.zangle=angle
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)
        cv2.circle(img,self.zrightend,self.rightendr,(0,255,0),3)

class Marm():
    def __init__(self,m00,m01,m02,m03,ml01,ml02,ml03):
        self.m00=m00
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.ser=None
        self.img=None
        self.imgcon=None
        self.zl03=75
        #self.x0>=self.zl03
        self.x0=self.zl03+5
        self.y0=0
        #模拟器初始化
        self.simuinit()
        #串口及机械臂位置初始化
        self.robotinit()
        
    def robotinit(self):
        #打开串口
        ports = list(serial.tools.list_ports.comports())
        print (ports)
        #便利 寻找串口
        for p in ports:
            print (p[1])
            if "serial" in p[1] or "CH340" in p[1]:
                self.ser=serial.Serial(port=p[0])
                if self.ser is not None:
                    print(self.ser)
                    print("serial conected")
                else:
                    print("serial not connected")
                    return
            else:
                print ("No CH340 Device was found connected to the computer")
                return
        if self.ser is None:
            return
        m0=bytes.fromhex('ff 01 00 08 00')# 舵机0速度为 72
        m1=bytes.fromhex('ff 01 01 08 00')# 舵机1速度为 72
        m2=bytes.fromhex('ff 01 02 08 00')# 舵机2速度为 72
        mo0=bytes.fromhex('ff 02 00 dc 05')#设置初始舵机0位置
        mo1=bytes.fromhex('ff 02 01 82 07')#设置初始舵机1的位置
        mo2 = bytes.fromhex('ff 02 02 dc 05')#设置初始舵机2的位置
        mo3 = bytes.fromhex('ff 02 03 dc 05')#设置初始舵机3的位置
        self.ser.write(m0)
        self.ser.write(m1)
        self.ser.write(m2)
        self.ser.write(mo0)
        self.ser.write(mo1)
        self.ser.write(mo2)
        self.ser.write(mo3)
        
    def simuinit(self):
        return
    
    def xztoq0(self,x,z):
        r=mt.sqrt(x*x+z*z+0.01)
        if z >=0:
            q0=180-mt.acos(z/r)/mt.pi*180
        else:
            q0=mt.acos(abs(z)/r)/mt.pi*180
        return q0
    
    def xytoq12(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)+0.001
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置,考虑杆的移动相对位置
    def scrdraw(self,angle0,angle1,angle2):
        #电机0在底盘,安装误差10度
        angle0+=10
        self.m00.drawrelative(angle0)
        #杆02与电机0中心在z轴方向相连
        self.ml02.setzjointpoint(self.m00.center)
        self.ml02.setzangle(angle0)
        #电机02
        self.m02.drawrelative(angle2)
         #杆02,与m02的圆心相连
        self.ml02.setangle(angle2)
        self.ml02.draw()
        self.ml02.setjointpoint(self.m02.center)
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.zcenter=self.ml02.zrightend
        print("m01 zcenter is",self.m01.zcenter)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.setzjointpoint(self.m01.zcenter)
        self.ml01.setzangle(angle0)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方靠左75
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(-self.zl03,L))
        self.ml03.setzjointpoint(self.ml01.zrightend)
        self.ml03.setzangle(angle0)
        self.ml03.draw()
        self.ml03.drawrightend()
        #显示串口连接状态红未连接绿连接
        if self.ser is not None:
            cv2.circle(img,(50,50),10,(0,255,0),3)
        else:
            cv2.circle(img,(50,50),10,(0,0,255),3)
        
    #输入角度考虑电机是否对面装配，从而是逆时针旋转，然后画在图上   
    def robodraw(self,angle0,angle1,angle2):
        mangle0=angle0
        mangle1=angle1
        mangle2=angle2
        if self.m00.facetome == True:
            print("facetome")
            mangle0=self.m00.maxangle-angle0
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            print("facetome")
            mangle2=slef.m02.maxangle-angle2
        print("mangel0,mangle1,mangle2",mangle0,mangle1,mangle2)
        self.scrdraw(mangle0,mangle1,mangle2)
    
    #输入PWM值画机械臂。对于非180度舵机实施缩放处理。对零位非0度的情况进行处理
    def drawpwm(self,pwm0,pwm1,pwm2):
        angle0pc=int((pwm0-500)/2000*180)
        angle0pc=180-angle0pc
        angle1pc=int((pwm1-500)/2000*180)
        angle2pc=int((pwm2-500)/2000*180)
        angel0=int(angle0pc*(self.m00.maxangle-self.m00.minangle)/180)+self.m00.minangle
        angel1=int(angle1pc*(self.m01.maxangle-self.m01.minangle)/180)+self.m01.minangle
        angel2=int(angle2pc*(self.m02.maxangle-self.m02.minangle)/180)+self.m02.minangle
        A1=180+50-(angel1+angel2)
        print("angel0,A1,angel2",angel0,A1,angel2)
        self.robodraw(angel0,A1,angel2)
        
    def xytopwm(self,x,y,z):
        rx=mt.sqrt((x+self.x0)*(x+self.x0)+z*z)
        r=rx-self.x0
        q1,q2=self.xytoq12(r,y+self.y0)
        q2=q2-4
        # q1=180+50-(q2+pwmq1)
        #50，20为舵机安装倾斜角度
        pwmq1=180+55-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        
        q0=self.xztoq0(x+self.x0,z)
        qq0=q0-self.m00.minangle
        pwmq0=qq0/(self.m00.maxangle-self.m00.minangle)*180
        pwm0=int(pwmq0/180*2000+500)
        print("pwm0,pwm1,pwm2",pwm0,pwm1,pwm2)
        return pwm0,pwm1,pwm2
    
    def serwrite(self,pwm0,pwm1,pwm2):
        if self.ser is None:
            return
        print(pwm0,pwm1,pwm2)
        pw0str="%04x"%pwm0
        pw1str="%04x"%pwm1
        pw2str="%04x"%pwm2
        print(pw0str,pw1str,pw2str)
        mo0hexstr="ff 02 00"+" "+pw0str[2:4]+" "+pw0str[0:2]
        mo1hexstr="ff 02 01"+" "+pw1str[2:4]+" "+pw1str[0:2]
        mo2hexstr="ff 02 02"+" "+pw2str[2:4]+" "+pw2str[0:2]
        self.ser.write(bytes.fromhex(mo0hexstr))
        self.ser.write(bytes.fromhex(mo1hexstr))
        self.ser.write(bytes.fromhex(mo2hexstr))
        return
    
    def robotTwin(self,x,y,z):
        pwm0,pwm1,pwm2=self.xytopwm(x,y,-1*z)
        self.drawpwm(pwm0,pwm1,pwm2)
        self.serwrite(pwm0,pwm1,pwm2)
    def show(self):
        global img
        cv2.imshow("marm",img)
        cv2.waitKey(300)
        #恢复背景
        img=imgcon.copy()
    def home(self):
        self.robotTwin(0,0,0)
        self.show()
        cv2.waitKey(5000)
    def destroy(self):
        if self.ser is not None:
            self.ser.close()
        cv2.destroyAllWindows()
        
#配置零件舵机
mM00=mmotor((170+300,240+300),0,0,-50,220)
mM02=mmotor((170+300,240+300),0,0,0,180)
mM01=mmotor((0,0),0,0,0,180)
mM03=mmotor((0,0),0,0,0,180)
#配置零件梁
mMl01=mlever((0,0),200,10,0)
mMl02=mlever((0,0),200,10,0)
mMl03=mlever((0,0),60,10,0)
#组装成机械臂
marm=Marm(mM00,mM01,mM02,mM03,mMl01,mMl02,mMl03)


marm.home()
time.sleep(5)
marm.robotTwin(100,0,-240)
marm.show()
time.sleep(5)
marm.robotTwin(100,0,240)
marm.show()
time.sleep(5)

for i in range(48):
    print("i",i)
    marm.robotTwin(100,0,i*10-240)
    marm.show()

for i in range(35):
    print("i",i)
    marm.robotTwin(i*10,0,0)
    marm.show()


points=[(50,0,0),(50,0,-100),(175,0,-100),(300,0,-100),(250,0,0),(250,0,100),(150,0,100),(50,0,100),(50,0,0)]

for point in points:
    marm.robotTwin(point[0],point[1],point[2])
    marm.show()
    time.sleep(3)
time.sleep(5)
marm.destroy()
# Out:
# (1080, 1440, 3)
# 480 360
# (460, 520, 3)
# [<serial.tools.list_ports_common.ListPortInfo object at 0x000002561D4BE438>]
# USB-SERIAL CH340 (COM13)
# Serial<id=0x2561d4be5c0, open=True>(port='COM13', baudrate=9600, bytesize=8, parity='N', stopbits=1, timeout=None, xonxoff=False, rtscts=False, dsrdtr=False)
# serial conected
# pwm0,pwm1,pwm2 1537 2155 1455
# angel0,A1,angel2 80 -3 85
# mangel0,mangle1,mangle2 80 -3 85
# ZJ point (470, 540)
# zrect ((470, 532), (16, 10), 90)
# m01 zcenter is (470, 524)
# ZJ point (470, 524)
# zrect ((470, 532), (-16, 10), 90)
# ZJ point (470, 540)
# zrect ((470, 503), (75, 10), 90)
# 1537 2155 1455
# 0601 086b 05af
# pwm0,pwm1,pwm2 1930 1784 1084
# angel0,A1,angel2 28 63 52
# mangel0,mangle1,mangle2 28 63 52
# ZJ point (470, 540)
# zrect ((422, 503), (122, 10), 38)
# m01 zcenter is (373, 465)
# ZJ point (373, 465)
# zrect ((340, 440), (84, 10), 38)
# ZJ point (306, 414)
# zrect ((277, 391), (75, 10), 38)
# 1930 1784 1084
# 078a 06f8 043c
# pwm0,pwm1,pwm2 1143 1784 1084
# angel0,A1,angel2 134 63 52
# mangel0,mangle1,mangle2 134 63 52
# ZJ point (470, 540)
# zrect ((519, 505), (122, 10), 144)
# m01 zcenter is (568, 469)
# ZJ point (568, 469)
# zrect ((601, 445), (84, 10), 144)
# ZJ point (634, 420)
# zrect ((664, 398), (75, 10), 144)
# 1143 1784 1084
# 0477 06f8 043c
# i 0
# pwm0,pwm1,pwm2 1930 1784 1084
# angel0,A1,angel2 28 63 52
# mangel0,mangle1,mangle2 28 63 52
# ZJ point (470, 540)
# zrect ((422, 503), (122, 10), 38)
# m01 zcenter is (373, 465)
# ZJ point (373, 465)
# zrect ((340, 440), (84, 10), 38)
# ZJ point (306, 414)
# zrect ((277, 391), (75, 10), 38)
# 1930 1784 1084
# 078a 06f8 043c
# i 1
# pwm0,pwm1,pwm2 1921 1799 1099
# angel0,A1,angel2 29 61 53
# mangel0,mangle1,mangle2 29 61 53
# ZJ point (470, 540)
# zrect ((424, 503), (120, 10), 39)
# m01 zcenter is (377, 465)
# ZJ point (377, 465)
# zrect ((346, 440), (80, 10), 39)
# ZJ point (314, 414)
# zrect ((285, 391), (75, 10), 39)
# 1921 1799 1099
# 0781 0707 044b
# i 2
# pwm0,pwm1,pwm2 1912 1814 1114
# angel0,A1,angel2 29 57 55
# mangel0,mangle1,mangle2 29 57 55
# ZJ point (470, 540)
# zrect ((426, 505), (114, 10), 39)
# m01 zcenter is (381, 469)
# ZJ point (381, 469)
# zrect ((353, 446), (74, 10), 39)
# ZJ point (324, 422)
# zrect ((295, 399), (75, 10), 39)
# 1912 1814 1114
# 0778 0716 045a
# i 3
# pwm0,pwm1,pwm2 1902 1828 1128
# angel0,A1,angel2 31 55 56
# mangel0,mangle1,mangle2 31 55 56
# ZJ point (470, 540)
# zrect ((429, 504), (110, 10), 41)
# m01 zcenter is (387, 467)
# ZJ point (387, 467)
# zrect ((361, 445), (70, 10), 41)
# ZJ point (334, 421)
# zrect ((306, 397), (75, 10), 41)
# 1902 1828 1128
# 076e 0724 0468
# i 4
# pwm0,pwm1,pwm2 1892 1842 1142
# angel0,A1,angel2 32 53 57
# mangel0,mangle1,mangle2 32 53 57
# ZJ point (470, 540)
# zrect ((430, 504), (108, 10), 42)
# m01 zcenter is (389, 467)
# ZJ point (389, 467)
# zrect ((364, 445), (68, 10), 42)
# ZJ point (338, 421)
# zrect ((311, 396), (75, 10), 42)
# 1892 1842 1142
# 0764 0732 0476
# i 5
# pwm0,pwm1,pwm2 1881 1855 1155
# angel0,A1,angel2 34 51 58
# mangel0,mangle1,mangle2 34 51 58
# ZJ point (470, 540)
# zrect ((433, 504), (104, 10), 44)
# m01 zcenter is (395, 467)
# ZJ point (395, 467)
# zrect ((372, 445), (64, 10), 44)
# ZJ point (348, 422)
# zrect ((322, 396), (75, 10), 44)
# 1881 1855 1155
# 0759 073f 0483
# i 6
# pwm0,pwm1,pwm2 1870 1868 1168
# angel0,A1,angel2 35 47 60
# mangel0,mangle1,mangle2 35 47 60
# ZJ point (470, 540)
# zrect ((435, 505), (100, 10), 45)
# m01 zcenter is (399, 469)
# ZJ point (399, 469)
# zrect ((379, 449), (58, 10), 45)
# ZJ point (358, 428)
# zrect ((332, 402), (75, 10), 45)
# 1870 1868 1168
# 074e 074c 0490
# i 7
# pwm0,pwm1,pwm2 1858 1880 1180
# angel0,A1,angel2 37 45 61
# mangel0,mangle1,mangle2 37 45 61
# ZJ point (470, 540)
# zrect ((438, 505), (96, 10), 47)
# m01 zcenter is (404, 469)
# ZJ point (404, 469)
# zrect ((386, 450), (54, 10), 47)
# ZJ point (367, 429)
# zrect ((342, 402), (75, 10), 47)
# 1858 1880 1180
# 0742 0758 049c
# i 8
# pwm0,pwm1,pwm2 1845 1892 1192
# angel0,A1,angel2 38 43 62
# mangel0,mangle1,mangle2 38 43 62
# ZJ point (470, 540)
# zrect ((440, 506), (92, 10), 48)
# m01 zcenter is (408, 471)
# ZJ point (408, 471)
# zrect ((392, 453), (50, 10), 48)
# ZJ point (374, 434)
# zrect ((349, 407), (75, 10), 48)
# 1845 1892 1192
# 0735 0764 04a8
# i 9
# pwm0,pwm1,pwm2 1831 1903 1203
# angel0,A1,angel2 41 41 63
# mangel0,mangle1,mangle2 41 41 63
# ZJ point (470, 540)
# zrect ((442, 506), (90, 10), 51)
# m01 zcenter is (413, 470)
# ZJ point (413, 470)
# zrect ((398, 452), (48, 10), 51)
# ZJ point (382, 433)
# zrect ((359, 404), (75, 10), 51)
# 1831 1903 1203
# 0727 076f 04b3
# i 10
# pwm0,pwm1,pwm2 1817 1914 1214
# angel0,A1,angel2 43 39 64
# mangel0,mangle1,mangle2 43 39 64
# ZJ point (470, 540)
# zrect ((445, 506), (86, 10), 53)
# m01 zcenter is (419, 471)
# ZJ point (419, 471)
# zrect ((406, 454), (44, 10), 53)
# ZJ point (392, 436)
# zrect ((370, 407), (75, 10), 53)
# 1817 1914 1214
# 0719 077a 04be
# i 11
# pwm0,pwm1,pwm2 1802 1924 1224
# angel0,A1,angel2 44 37 65
# mangel0,mangle1,mangle2 44 37 65
# ZJ point (470, 540)
# zrect ((446, 507), (84, 10), 54)
# m01 zcenter is (421, 472)
# ZJ point (421, 472)
# zrect ((410, 456), (40, 10), 54)
# ZJ point (398, 439)
# zrect ((376, 409), (75, 10), 54)
# 1802 1924 1224
# 070a 0784 04c8
# i 12
# pwm0,pwm1,pwm2 1786 1934 1234
# angel0,A1,angel2 47 35 66
# mangel0,mangle1,mangle2 47 35 66
# ZJ point (470, 540)
# zrect ((449, 507), (80, 10), 57)
# m01 zcenter is (427, 473)
# ZJ point (427, 473)
# zrect ((417, 458), (38, 10), 57)
# ZJ point (406, 441)
# zrect ((386, 410), (75, 10), 57)
# 1786 1934 1234
# 06fa 078e 04d2
# i 13
# pwm0,pwm1,pwm2 1769 1943 1243
# angel0,A1,angel2 49 35 66
# mangel0,mangle1,mangle2 49 35 66
# ZJ point (470, 540)
# zrect ((450, 506), (80, 10), 59)
# m01 zcenter is (429, 471)
# ZJ point (429, 471)
# zrect ((420, 455), (38, 10), 59)
# ZJ point (409, 438)
# zrect ((390, 406), (75, 10), 59)
# 1769 1943 1243
# 06e9 0797 04db
# i 14
# pwm0,pwm1,pwm2 1752 1951 1251
# angel0,A1,angel2 52 33 67
# mangel0,mangle1,mangle2 52 33 67
# ZJ point (470, 540)
# zrect ((452, 506), (78, 10), 62)
# m01 zcenter is (433, 471)
# ZJ point (433, 471)
# zrect ((426, 456), (34, 10), 62)
# ZJ point (417, 440)
# zrect ((400, 407), (75, 10), 62)
# 1752 1951 1251
# 06d8 079f 04e3
# i 15
# pwm0,pwm1,pwm2 1733 1959 1259
# angel0,A1,angel2 55 31 68
# mangel0,mangle1,mangle2 55 31 68
# ZJ point (470, 540)
# zrect ((455, 507), (74, 10), 65)
# m01 zcenter is (438, 473)
# ZJ point (438, 473)
# zrect ((432, 460), (30, 10), 65)
# ZJ point (425, 446)
# zrect ((410, 413), (75, 10), 65)
# 1733 1959 1259
# 06c5 07a7 04eb
# i 16
# pwm0,pwm1,pwm2 1714 1966 1266
# angel0,A1,angel2 56 31 68
# mangel0,mangle1,mangle2 56 31 68
# ZJ point (470, 540)
# zrect ((455, 507), (74, 10), 66)
# m01 zcenter is (439, 473)
# ZJ point (439, 473)
# zrect ((433, 460), (30, 10), 66)
# ZJ point (426, 446)
# zrect ((411, 412), (75, 10), 66)
# 1714 1966 1266
# 06b2 07ae 04f2
# i 17
# pwm0,pwm1,pwm2 1694 1973 1273
# angel0,A1,angel2 59 29 69
# mangel0,mangle1,mangle2 59 29 69
# ZJ point (470, 540)
# zrect ((458, 508), (70, 10), 69)
# m01 zcenter is (445, 475)
# ZJ point (445, 475)
# zrect ((441, 463), (26, 10), 69)
# ZJ point (436, 450)
# zrect ((423, 415), (75, 10), 69)
# 1694 1973 1273
# 069e 07b5 04f9
# i 18
# pwm0,pwm1,pwm2 1673 1978 1278
# angel0,A1,angel2 62 27 70
# mangel0,mangle1,mangle2 62 27 70
# ZJ point (470, 540)
# zrect ((460, 508), (68, 10), 72)
# m01 zcenter is (449, 475)
# ZJ point (449, 475)
# zrect ((446, 464), (24, 10), 72)
# ZJ point (442, 452)
# zrect ((431, 417), (75, 10), 72)
# 1673 1978 1278
# 0689 07ba 04fe
# i 19
# pwm0,pwm1,pwm2 1652 1983 1283
# angel0,A1,angel2 65 27 70
# mangel0,mangle1,mangle2 65 27 70
# ZJ point (470, 540)
# zrect ((462, 508), (68, 10), 75)
# m01 zcenter is (453, 474)
# ZJ point (453, 474)
# zrect ((450, 463), (24, 10), 75)
# ZJ point (446, 451)
# zrect ((437, 415), (75, 10), 75)
# 1652 1983 1283
# 0674 07bf 0503
# i 20
# pwm0,pwm1,pwm2 1629 1987 1287
# angel0,A1,angel2 68 27 70
# mangel0,mangle1,mangle2 68 27 70
# ZJ point (470, 540)
# zrect ((463, 507), (68, 10), 78)
# m01 zcenter is (455, 473)
# ZJ point (455, 473)
# zrect ((453, 462), (24, 10), 78)
# ZJ point (450, 450)
# zrect ((443, 414), (75, 10), 78)
# 1629 1987 1287
# 065d 07c3 0507
# i 21
# pwm0,pwm1,pwm2 1607 1990 1290
# angel0,A1,angel2 71 25 71
# mangel0,mangle1,mangle2 71 25 71
# ZJ point (470, 540)
# zrect ((465, 509), (64, 10), 81)
# m01 zcenter is (459, 477)
# ZJ point (459, 477)
# zrect ((458, 468), (20, 10), 81)
# ZJ point (456, 457)
# zrect ((451, 420), (75, 10), 81)
# 1607 1990 1290
# 0647 07c6 050a
# i 22
# pwm0,pwm1,pwm2 1584 1992 1292
# angel0,A1,angel2 74 25 71
# mangel0,mangle1,mangle2 74 25 71
# ZJ point (470, 540)
# zrect ((467, 509), (64, 10), 84)
# m01 zcenter is (463, 476)
# ZJ point (463, 476)
# zrect ((462, 467), (20, 10), 84)
# ZJ point (460, 456)
# zrect ((457, 419), (75, 10), 84)
# 1584 1992 1292
# 0630 07c8 050c
# i 23
# pwm0,pwm1,pwm2 1560 1994 1294
# angel0,A1,angel2 77 25 71
# mangel0,mangle1,mangle2 77 25 71
# ZJ point (470, 540)
# zrect ((469, 509), (64, 10), 87)
# m01 zcenter is (467, 476)
# ZJ point (467, 476)
# zrect ((467, 467), (20, 10), 87)
# ZJ point (466, 456)
# zrect ((465, 419), (75, 10), 87)
# 1560 1994 1294
# 0618 07ca 050e
# i 24
# pwm0,pwm1,pwm2 1537 1994 1294
# angel0,A1,angel2 80 25 71
# mangel0,mangle1,mangle2 80 25 71
# ZJ point (470, 540)
# zrect ((470, 508), (64, 10), 90)
# m01 zcenter is (470, 476)
# ZJ point (470, 476)
# zrect ((470, 466), (20, 10), 90)
# ZJ point (470, 456)
# zrect ((470, 419), (75, 10), 90)
# 1537 1994 1294
# 0601 07ca 050e
# i 25
# pwm0,pwm1,pwm2 1513 1994 1294
# angel0,A1,angel2 83 25 71
# mangel0,mangle1,mangle2 83 25 71
# ZJ point (470, 540)
# zrect ((471, 509), (64, 10), 93)
# m01 zcenter is (472, 476)
# ZJ point (472, 476)
# zrect ((472, 467), (20, 10), 93)
# ZJ point (472, 456)
# zrect ((473, 419), (75, 10), 93)
# 1513 1994 1294
# 05e9 07ca 050e
# i 26
# pwm0,pwm1,pwm2 1490 1992 1292
# angel0,A1,angel2 86 25 71
# mangel0,mangle1,mangle2 86 25 71
# ZJ point (470, 540)
# zrect ((473, 509), (64, 10), 96)
# m01 zcenter is (476, 476)
# ZJ point (476, 476)
# zrect ((477, 467), (20, 10), 96)
# ZJ point (478, 456)
# zrect ((481, 419), (75, 10), 96)
# 1490 1992 1292
# 05d2 07c8 050c
# i 27
# pwm0,pwm1,pwm2 1466 1990 1290
# angel0,A1,angel2 91 25 71
# mangel0,mangle1,mangle2 91 25 71
# ZJ point (470, 540)
# zrect ((476, 509), (64, 10), 101)
# m01 zcenter is (482, 477)
# ZJ point (482, 477)
# zrect ((483, 468), (20, 10), 101)
# ZJ point (484, 458)
# zrect ((491, 422), (75, 10), 101)
# 1466 1990 1290
# 05ba 07c6 050a
# i 28
# pwm0,pwm1,pwm2 1444 1987 1287
# angel0,A1,angel2 94 27 70
# mangel0,mangle1,mangle2 94 27 70
# ZJ point (470, 540)
# zrect ((478, 508), (68, 10), 104)
# m01 zcenter is (486, 474)
# ZJ point (486, 474)
# zrect ((488, 463), (24, 10), 104)
# ZJ point (490, 451)
# zrect ((499, 415), (75, 10), 104)
# 1444 1987 1287
# 05a4 07c3 0507
# i 29
# pwm0,pwm1,pwm2 1422 1983 1283
# angel0,A1,angel2 97 27 70
# mangel0,mangle1,mangle2 97 27 70
# ZJ point (470, 540)
# zrect ((479, 508), (68, 10), 107)
# m01 zcenter is (488, 475)
# ZJ point (488, 475)
# zrect ((491, 464), (24, 10), 107)
# ZJ point (494, 452)
# zrect ((504, 417), (75, 10), 107)
# 1422 1983 1283
# 058e 07bf 0503
# i 30
# pwm0,pwm1,pwm2 1400 1978 1278
# angel0,A1,angel2 98 27 70
# mangel0,mangle1,mangle2 98 27 70
# ZJ point (470, 540)
# zrect ((480, 508), (68, 10), 108)
# m01 zcenter is (490, 475)
# ZJ point (490, 475)
# zrect ((493, 464), (24, 10), 108)
# ZJ point (496, 452)
# zrect ((507, 417), (75, 10), 108)
# 1400 1978 1278
# 0578 07ba 04fe
# i 31
# pwm0,pwm1,pwm2 1379 1973 1273
# angel0,A1,angel2 101 29 69
# mangel0,mangle1,mangle2 101 29 69
# ZJ point (470, 540)
# zrect ((482, 508), (70, 10), 111)
# m01 zcenter is (494, 475)
# ZJ point (494, 475)
# zrect ((498, 463), (26, 10), 111)
# ZJ point (502, 450)
# zrect ((515, 415), (75, 10), 111)
# 1379 1973 1273
# 0563 07b5 04f9
# i 32
# pwm0,pwm1,pwm2 1359 1966 1266
# angel0,A1,angel2 104 31 68
# mangel0,mangle1,mangle2 104 31 68
# ZJ point (470, 540)
# zrect ((485, 507), (74, 10), 114)
# m01 zcenter is (499, 473)
# ZJ point (499, 473)
# zrect ((505, 460), (30, 10), 114)
# ZJ point (510, 446)
# zrect ((525, 412), (75, 10), 114)
# 1359 1966 1266
# 054f 07ae 04f2
# i 33
# pwm0,pwm1,pwm2 1340 1959 1259
# angel0,A1,angel2 107 31 68
# mangel0,mangle1,mangle2 107 31 68
# ZJ point (470, 540)
# zrect ((486, 508), (74, 10), 117)
# m01 zcenter is (502, 474)
# ZJ point (502, 474)
# zrect ((508, 461), (30, 10), 117)
# ZJ point (514, 447)
# zrect ((531, 414), (75, 10), 117)
# 1340 1959 1259
# 053c 07a7 04eb
# i 34
# pwm0,pwm1,pwm2 1321 1951 1251
# angel0,A1,angel2 110 33 67
# mangel0,mangle1,mangle2 110 33 67
# ZJ point (470, 540)
# zrect ((489, 507), (78, 10), 120)
# m01 zcenter is (508, 472)
# ZJ point (508, 472)
# zrect ((516, 458), (34, 10), 120)
# ZJ point (524, 442)
# zrect ((542, 410), (75, 10), 120)
# 1321 1951 1251
# 0529 079f 04e3
# i 35
# pwm0,pwm1,pwm2 1304 1943 1243
# angel0,A1,angel2 112 35 66
# mangel0,mangle1,mangle2 112 35 66
# ZJ point (470, 540)
# zrect ((491, 507), (80, 10), 122)
# m01 zcenter is (511, 472)
# ZJ point (511, 472)
# zrect ((521, 456), (38, 10), 122)
# ZJ point (530, 439)
# zrect ((549, 408), (75, 10), 122)
# 1304 1943 1243
# 0518 0797 04db
# i 36
# pwm0,pwm1,pwm2 1287 1934 1234
# angel0,A1,angel2 115 35 66
# mangel0,mangle1,mangle2 115 35 66
# ZJ point (470, 540)
# zrect ((492, 508), (80, 10), 125)
# m01 zcenter is (514, 475)
# ZJ point (514, 475)
# zrect ((524, 460), (38, 10), 125)
# ZJ point (534, 444)
# zrect ((555, 414), (75, 10), 125)
# 1287 1934 1234
# 0507 078e 04d2
# i 37
# pwm0,pwm1,pwm2 1271 1924 1224
# angel0,A1,angel2 116 37 65
# mangel0,mangle1,mangle2 116 37 65
# ZJ point (470, 540)
# zrect ((494, 507), (84, 10), 126)
# m01 zcenter is (518, 472)
# ZJ point (518, 472)
# zrect ((529, 456), (40, 10), 126)
# ZJ point (540, 439)
# zrect ((562, 409), (75, 10), 126)
# 1271 1924 1224
# 04f7 0784 04c8
# i 38
# pwm0,pwm1,pwm2 1256 1914 1214
# angel0,A1,angel2 118 39 64
# mangel0,mangle1,mangle2 118 39 64
# ZJ point (470, 540)
# zrect ((496, 507), (86, 10), 128)
# m01 zcenter is (522, 473)
# ZJ point (522, 473)
# zrect ((535, 456), (44, 10), 128)
# ZJ point (548, 438)
# zrect ((571, 409), (75, 10), 128)
# 1256 1914 1214
# 04e8 077a 04be
# i 39
# pwm0,pwm1,pwm2 1242 1903 1203
# angel0,A1,angel2 121 41 63
# mangel0,mangle1,mangle2 121 41 63
# ZJ point (470, 540)
# zrect ((499, 507), (90, 10), 131)
# m01 zcenter is (528, 472)
# ZJ point (528, 472)
# zrect ((543, 454), (48, 10), 131)
# ZJ point (558, 435)
# zrect ((582, 407), (75, 10), 131)
# 1242 1903 1203
# 04da 076f 04b3
# i 40
# pwm0,pwm1,pwm2 1228 1892 1192
# angel0,A1,angel2 122 43 62
# mangel0,mangle1,mangle2 122 43 62
# ZJ point (470, 540)
# zrect ((500, 506), (92, 10), 132)
# m01 zcenter is (530, 471)
# ZJ point (530, 471)
# zrect ((546, 453), (50, 10), 132)
# ZJ point (562, 434)
# zrect ((587, 407), (75, 10), 132)
# 1228 1892 1192
# 04cc 0764 04a8
# i 41
# pwm0,pwm1,pwm2 1215 1880 1180
# angel0,A1,angel2 124 45 61
# mangel0,mangle1,mangle2 124 45 61
# ZJ point (470, 540)
# zrect ((503, 506), (96, 10), 134)
# m01 zcenter is (535, 470)
# ZJ point (535, 470)
# zrect ((553, 451), (54, 10), 134)
# ZJ point (571, 431)
# zrect ((597, 405), (75, 10), 134)
# 1215 1880 1180
# 04bf 0758 049c
# i 42
# pwm0,pwm1,pwm2 1203 1868 1168
# angel0,A1,angel2 125 47 60
# mangel0,mangle1,mangle2 125 47 60
# ZJ point (470, 540)
# zrect ((505, 505), (100, 10), 135)
# m01 zcenter is (539, 469)
# ZJ point (539, 469)
# zrect ((559, 449), (58, 10), 135)
# ZJ point (579, 428)
# zrect ((605, 402), (75, 10), 135)
# 1203 1868 1168
# 04b3 074c 0490
# i 43
# pwm0,pwm1,pwm2 1192 1855 1155
# angel0,A1,angel2 127 51 58
# mangel0,mangle1,mangle2 127 51 58
# ZJ point (470, 540)
# zrect ((508, 505), (104, 10), 137)
# m01 zcenter is (545, 469)
# ZJ point (545, 469)
# zrect ((568, 448), (64, 10), 137)
# ZJ point (590, 425)
# zrect ((617, 400), (75, 10), 137)
# 1192 1855 1155
# 04a8 073f 0483
# i 44
# pwm0,pwm1,pwm2 1181 1842 1142
# angel0,A1,angel2 128 53 57
# mangel0,mangle1,mangle2 128 53 57
# ZJ point (470, 540)
# zrect ((510, 504), (108, 10), 138)
# m01 zcenter is (549, 467)
# ZJ point (549, 467)
# zrect ((574, 445), (68, 10), 138)
# ZJ point (598, 421)
# zrect ((625, 396), (75, 10), 138)
# 1181 1842 1142
# 049d 0732 0476
# i 45
# pwm0,pwm1,pwm2 1171 1828 1128
# angel0,A1,angel2 130 55 56
# mangel0,mangle1,mangle2 130 55 56
# ZJ point (470, 540)
# zrect ((512, 505), (110, 10), 140)
# m01 zcenter is (553, 469)
# ZJ point (553, 469)
# zrect ((579, 447), (70, 10), 140)
# ZJ point (605, 424)
# zrect ((633, 400), (75, 10), 140)
# 1171 1828 1128
# 0493 0724 0468
# i 46
# pwm0,pwm1,pwm2 1161 1814 1114
# angel0,A1,angel2 131 57 55
# mangel0,mangle1,mangle2 131 57 55
# ZJ point (470, 540)
# zrect ((514, 505), (114, 10), 141)
# m01 zcenter is (558, 469)
# ZJ point (558, 469)
# zrect ((586, 446), (74, 10), 141)
# ZJ point (614, 422)
# zrect ((643, 399), (75, 10), 141)
# 1161 1814 1114
# 0489 0716 045a
# i 47
# pwm0,pwm1,pwm2 1152 1799 1099
# angel0,A1,angel2 133 61 53
# mangel0,mangle1,mangle2 133 61 53
# ZJ point (470, 540)
# zrect ((517, 504), (120, 10), 143)
# m01 zcenter is (564, 467)
# ZJ point (564, 467)
# zrect ((595, 443), (80, 10), 143)
# ZJ point (626, 418)
# zrect ((655, 396), (75, 10), 143)
# 1152 1799 1099
# 0480 0707 044b
# i 0
# pwm0,pwm1,pwm2 1537 2155 1455
# angel0,A1,angel2 80 -3 85
# mangel0,mangle1,mangle2 80 -3 85
# ZJ point (470, 540)
# zrect ((470, 532), (16, 10), 90)
# m01 zcenter is (470, 524)
# ZJ point (470, 524)
# zrect ((470, 532), (-16, 10), 90)
# ZJ point (470, 540)
# zrect ((470, 503), (75, 10), 90)
# 1537 2155 1455
# 0601 086b 05af
# i 1
# pwm0,pwm1,pwm2 1537 2139 1439
# angel0,A1,angel2 80 -1 84
# mangel0,mangle1,mangle2 80 -1 84
# ZJ point (470, 540)
# zrect ((470, 530), (20, 10), 90)
# m01 zcenter is (470, 520)
# ZJ point (470, 520)
# zrect ((470, 530), (-20, 10), 90)
# ZJ point (470, 540)
# zrect ((470, 503), (75, 10), 90)
# 1537 2139 1439
# 0601 085b 059f
# i 2
# pwm0,pwm1,pwm2 1537 2123 1423
# angel0,A1,angel2 80 1 83
# mangel0,mangle1,mangle2 80 1 83
# ZJ point (470, 540)
# zrect ((470, 528), (24, 10), 90)
# m01 zcenter is (470, 516)
# ZJ point (470, 516)
# zrect ((470, 526), (-20, 10), 90)
# ZJ point (470, 536)
# zrect ((470, 499), (75, 10), 90)
# 1537 2123 1423
# 0601 084b 058f
# i 3
# pwm0,pwm1,pwm2 1537 2107 1407
# angel0,A1,angel2 80 5 81
# mangel0,mangle1,mangle2 80 5 81
# ZJ point (470, 540)
# zrect ((470, 525), (30, 10), 90)
# m01 zcenter is (470, 510)
# ZJ point (470, 510)
# zrect ((470, 516), (-12, 10), 90)
# ZJ point (470, 522)
# zrect ((470, 485), (75, 10), 90)
# 1537 2107 1407
# 0601 083b 057f
# i 4
# pwm0,pwm1,pwm2 1537 2091 1391
# angel0,A1,angel2 80 7 80
# mangel0,mangle1,mangle2 80 7 80
# ZJ point (470, 540)
# zrect ((470, 523), (34, 10), 90)
# m01 zcenter is (470, 506)
# ZJ point (470, 506)
# zrect ((470, 511), (-10, 10), 90)
# ZJ point (470, 516)
# zrect ((470, 479), (75, 10), 90)
# 1537 2091 1391
# 0601 082b 056f
# i 5
# pwm0,pwm1,pwm2 1537 2075 1375
# angel0,A1,angel2 80 11 78
# mangel0,mangle1,mangle2 80 11 78
# ZJ point (470, 540)
# zrect ((470, 520), (40, 10), 90)
# m01 zcenter is (470, 500)
# ZJ point (470, 500)
# zrect ((470, 501), (-2, 10), 90)
# ZJ point (470, 502)
# zrect ((470, 465), (75, 10), 90)
# 1537 2075 1375
# 0601 081b 055f
# i 6
# pwm0,pwm1,pwm2 1537 2059 1359
# angel0,A1,angel2 80 13 77
# mangel0,mangle1,mangle2 80 13 77
# ZJ point (470, 540)
# zrect ((470, 518), (44, 10), 90)
# m01 zcenter is (470, 496)
# ZJ point (470, 496)
# zrect ((470, 459), (75, 10), 90)
# ZJ point (470, 421)
# zrect ((470, 384), (75, 10), 90)
# 1537 2059 1359
# 0601 080b 054f
# i 7
# pwm0,pwm1,pwm2 1537 2043 1343
# angel0,A1,angel2 80 17 75
# mangel0,mangle1,mangle2 80 17 75
# ZJ point (470, 540)
# zrect ((470, 515), (50, 10), 90)
# m01 zcenter is (470, 490)
# ZJ point (470, 490)
# zrect ((470, 487), (6, 10), 90)
# ZJ point (470, 484)
# zrect ((470, 447), (75, 10), 90)
# 1537 2043 1343
# 0601 07fb 053f
# i 8
# pwm0,pwm1,pwm2 1537 2027 1327
# angel0,A1,angel2 80 19 74
# mangel0,mangle1,mangle2 80 19 74
# ZJ point (470, 540)
# zrect ((470, 513), (54, 10), 90)
# m01 zcenter is (470, 486)
# ZJ point (470, 486)
# zrect ((470, 481), (10, 10), 90)
# ZJ point (470, 476)
# zrect ((470, 439), (75, 10), 90)
# 1537 2027 1327
# 0601 07eb 052f
# i 9
# pwm0,pwm1,pwm2 1537 2011 1311
# angel0,A1,angel2 80 23 72
# mangel0,mangle1,mangle2 80 23 72
# ZJ point (470, 540)
# zrect ((470, 510), (60, 10), 90)
# m01 zcenter is (470, 480)
# ZJ point (470, 480)
# zrect ((470, 472), (16, 10), 90)
# ZJ point (470, 464)
# zrect ((470, 427), (75, 10), 90)
# 1537 2011 1311
# 0601 07db 051f
# i 10
# pwm0,pwm1,pwm2 1537 1994 1294
# angel0,A1,angel2 80 25 71
# mangel0,mangle1,mangle2 80 25 71
# ZJ point (470, 540)
# zrect ((470, 508), (64, 10), 90)
# m01 zcenter is (470, 476)
# ZJ point (470, 476)
# zrect ((470, 466), (20, 10), 90)
# ZJ point (470, 456)
# zrect ((470, 419), (75, 10), 90)
# 1537 1994 1294
# 0601 07ca 050e
# i 11
# pwm0,pwm1,pwm2 1537 1978 1278
# angel0,A1,angel2 80 27 70
# mangel0,mangle1,mangle2 80 27 70
# ZJ point (470, 540)
# zrect ((470, 506), (68, 10), 90)
# m01 zcenter is (470, 472)
# ZJ point (470, 472)
# zrect ((470, 460), (24, 10), 90)
# ZJ point (470, 448)
# zrect ((470, 411), (75, 10), 90)
# 1537 1978 1278
# 0601 07ba 04fe
# i 12
# pwm0,pwm1,pwm2 1537 1961 1261
# angel0,A1,angel2 80 31 68
# mangel0,mangle1,mangle2 80 31 68
# ZJ point (470, 540)
# zrect ((470, 503), (74, 10), 90)
# m01 zcenter is (470, 466)
# ZJ point (470, 466)
# zrect ((470, 451), (30, 10), 90)
# ZJ point (470, 436)
# zrect ((470, 399), (75, 10), 90)
# 1537 1961 1261
# 0601 07a9 04ed
# i 13
# pwm0,pwm1,pwm2 1537 1944 1244
# angel0,A1,angel2 80 35 66
# mangel0,mangle1,mangle2 80 35 66
# ZJ point (470, 540)
# zrect ((470, 500), (80, 10), 90)
# m01 zcenter is (470, 460)
# ZJ point (470, 460)
# zrect ((470, 441), (38, 10), 90)
# ZJ point (470, 422)
# zrect ((470, 385), (75, 10), 90)
# 1537 1944 1244
# 0601 0798 04dc
# i 14
# pwm0,pwm1,pwm2 1537 1927 1227
# angel0,A1,angel2 80 37 65
# mangel0,mangle1,mangle2 80 37 65
# ZJ point (470, 540)
# zrect ((470, 498), (84, 10), 90)
# m01 zcenter is (470, 456)
# ZJ point (470, 456)
# zrect ((470, 436), (40, 10), 90)
# ZJ point (470, 416)
# zrect ((470, 379), (75, 10), 90)
# 1537 1927 1227
# 0601 0787 04cb
# i 15
# pwm0,pwm1,pwm2 1537 1910 1210
# angel0,A1,angel2 80 41 63
# mangel0,mangle1,mangle2 80 41 63
# ZJ point (470, 540)
# zrect ((470, 495), (90, 10), 90)
# m01 zcenter is (470, 450)
# ZJ point (470, 450)
# zrect ((470, 426), (48, 10), 90)
# ZJ point (470, 402)
# zrect ((470, 365), (75, 10), 90)
# 1537 1910 1210
# 0601 0776 04ba
# i 16
# pwm0,pwm1,pwm2 1537 1893 1193
# angel0,A1,angel2 80 43 62
# mangel0,mangle1,mangle2 80 43 62
# ZJ point (470, 540)
# zrect ((470, 494), (92, 10), 90)
# m01 zcenter is (470, 448)
# ZJ point (470, 448)
# zrect ((470, 423), (50, 10), 90)
# ZJ point (470, 398)
# zrect ((470, 361), (75, 10), 90)
# 1537 1893 1193
# 0601 0765 04a9
# i 17
# pwm0,pwm1,pwm2 1537 1876 1176
# angel0,A1,angel2 80 47 60
# mangel0,mangle1,mangle2 80 47 60
# ZJ point (470, 540)
# zrect ((470, 490), (100, 10), 90)
# m01 zcenter is (470, 440)
# ZJ point (470, 440)
# zrect ((470, 411), (58, 10), 90)
# ZJ point (470, 382)
# zrect ((470, 345), (75, 10), 90)
# 1537 1876 1176
# 0601 0754 0498
# i 18
# pwm0,pwm1,pwm2 1537 1858 1158
# angel0,A1,angel2 80 49 59
# mangel0,mangle1,mangle2 80 49 59
# ZJ point (470, 540)
# zrect ((470, 489), (102, 10), 90)
# m01 zcenter is (470, 438)
# ZJ point (470, 438)
# zrect ((470, 408), (60, 10), 90)
# ZJ point (470, 378)
# zrect ((470, 341), (75, 10), 90)
# 1537 1858 1158
# 0601 0742 0486
# i 19
# pwm0,pwm1,pwm2 1537 1840 1140
# angel0,A1,angel2 80 53 57
# mangel0,mangle1,mangle2 80 53 57
# ZJ point (470, 540)
# zrect ((470, 486), (108, 10), 90)
# m01 zcenter is (470, 432)
# ZJ point (470, 432)
# zrect ((470, 398), (68, 10), 90)
# ZJ point (470, 364)
# zrect ((470, 327), (75, 10), 90)
# 1537 1840 1140
# 0601 0730 0474
# i 20
# pwm0,pwm1,pwm2 1537 1822 1122
# angel0,A1,angel2 80 57 55
# mangel0,mangle1,mangle2 80 57 55
# ZJ point (470, 540)
# zrect ((470, 483), (114, 10), 90)
# m01 zcenter is (470, 426)
# ZJ point (470, 426)
# zrect ((470, 389), (74, 10), 90)
# ZJ point (470, 352)
# zrect ((470, 315), (75, 10), 90)
# 1537 1822 1122
# 0601 071e 0462
# i 21
# pwm0,pwm1,pwm2 1537 1803 1103
# angel0,A1,angel2 80 59 54
# mangel0,mangle1,mangle2 80 59 54
# ZJ point (470, 540)
# zrect ((470, 482), (116, 10), 90)
# m01 zcenter is (470, 424)
# ZJ point (470, 424)
# zrect ((470, 385), (78, 10), 90)
# ZJ point (470, 346)
# zrect ((470, 309), (75, 10), 90)
# 1537 1803 1103
# 0601 070b 044f
# i 22
# pwm0,pwm1,pwm2 1537 1784 1084
# angel0,A1,angel2 80 63 52
# mangel0,mangle1,mangle2 80 63 52
# ZJ point (470, 540)
# zrect ((470, 479), (122, 10), 90)
# m01 zcenter is (470, 418)
# ZJ point (470, 418)
# zrect ((470, 376), (84, 10), 90)
# ZJ point (470, 334)
# zrect ((470, 297), (75, 10), 90)
# 1537 1784 1084
# 0601 06f8 043c
# i 23
# pwm0,pwm1,pwm2 1537 1765 1065
# angel0,A1,angel2 80 67 50
# mangel0,mangle1,mangle2 80 67 50
# ZJ point (470, 540)
# zrect ((470, 476), (128, 10), 90)
# m01 zcenter is (470, 412)
# ZJ point (470, 412)
# zrect ((470, 367), (90, 10), 90)
# ZJ point (470, 322)
# zrect ((470, 285), (75, 10), 90)
# 1537 1765 1065
# 0601 06e5 0429
# i 24
# pwm0,pwm1,pwm2 1537 1745 1045
# angel0,A1,angel2 80 69 49
# mangel0,mangle1,mangle2 80 69 49
# ZJ point (470, 540)
# zrect ((470, 475), (130, 10), 90)
# m01 zcenter is (470, 410)
# ZJ point (470, 410)
# zrect ((470, 364), (92, 10), 90)
# ZJ point (470, 318)
# zrect ((470, 281), (75, 10), 90)
# 1537 1745 1045
# 0601 06d1 0415
# i 25
# pwm0,pwm1,pwm2 1537 1725 1025
# angel0,A1,angel2 80 73 47
# mangel0,mangle1,mangle2 80 73 47
# ZJ point (470, 540)
# zrect ((470, 472), (136, 10), 90)
# m01 zcenter is (470, 404)
# ZJ point (470, 404)
# zrect ((470, 354), (100, 10), 90)
# ZJ point (470, 304)
# zrect ((470, 267), (75, 10), 90)
# 1537 1725 1025
# 0601 06bd 0401
# i 26
# pwm0,pwm1,pwm2 1537 1705 1005
# angel0,A1,angel2 80 77 45
# mangel0,mangle1,mangle2 80 77 45
# ZJ point (470, 540)
# zrect ((470, 470), (140, 10), 90)
# m01 zcenter is (470, 400)
# ZJ point (470, 400)
# zrect ((470, 348), (104, 10), 90)
# ZJ point (470, 296)
# zrect ((470, 259), (75, 10), 90)
# 1537 1705 1005
# 0601 06a9 03ed
# i 27
# pwm0,pwm1,pwm2 1537 1683 983
# angel0,A1,angel2 80 81 43
# mangel0,mangle1,mangle2 80 81 43
# ZJ point (470, 540)
# zrect ((470, 467), (146, 10), 90)
# m01 zcenter is (470, 394)
# ZJ point (470, 394)
# zrect ((470, 339), (110, 10), 90)
# ZJ point (470, 284)
# zrect ((470, 247), (75, 10), 90)
# 1537 1683 983
# 0601 0693 03d7
# i 28
# pwm0,pwm1,pwm2 1537 1661 961
# angel0,A1,angel2 80 85 41
# mangel0,mangle1,mangle2 80 85 41
# ZJ point (470, 540)
# zrect ((470, 465), (150, 10), 90)
# m01 zcenter is (470, 390)
# ZJ point (470, 390)
# zrect ((470, 332), (116, 10), 90)
# ZJ point (470, 274)
# zrect ((470, 237), (75, 10), 90)
# 1537 1661 961
# 0601 067d 03c1
# i 29
# pwm0,pwm1,pwm2 1537 1639 939
# angel0,A1,angel2 80 89 39
# mangel0,mangle1,mangle2 80 89 39
# ZJ point (470, 540)
# zrect ((470, 463), (154, 10), 90)
# m01 zcenter is (470, 386)
# ZJ point (470, 386)
# zrect ((470, 325), (122, 10), 90)
# ZJ point (470, 264)
# zrect ((470, 227), (75, 10), 90)
# 1537 1639 939
# 0601 0667 03ab
# i 30
# pwm0,pwm1,pwm2 1537 1615 915
# angel0,A1,angel2 80 93 37
# mangel0,mangle1,mangle2 80 93 37
# ZJ point (470, 540)
# zrect ((470, 461), (158, 10), 90)
# m01 zcenter is (470, 382)
# ZJ point (470, 382)
# zrect ((470, 318), (128, 10), 90)
# ZJ point (470, 254)
# zrect ((470, 217), (75, 10), 90)
# 1537 1615 915
# 0601 064f 0393
# i 31
# pwm0,pwm1,pwm2 1537 1591 891
# angel0,A1,angel2 80 97 35
# mangel0,mangle1,mangle2 80 97 35
# ZJ point (470, 540)
# zrect ((470, 459), (162, 10), 90)
# m01 zcenter is (470, 378)
# ZJ point (470, 378)
# zrect ((470, 312), (132, 10), 90)
# ZJ point (470, 246)
# zrect ((470, 209), (75, 10), 90)
# 1537 1591 891
# 0601 0637 037b
# i 32
# pwm0,pwm1,pwm2 1537 1565 865
# angel0,A1,angel2 80 103 32
# mangel0,mangle1,mangle2 80 103 32
# ZJ point (470, 540)
# zrect ((470, 456), (168, 10), 90)
# m01 zcenter is (470, 372)
# ZJ point (470, 372)
# zrect ((470, 302), (140, 10), 90)
# ZJ point (470, 232)
# zrect ((470, 195), (75, 10), 90)
# 1537 1565 865
# 0601 061d 0361
# i 33
# pwm0,pwm1,pwm2 1537 1537 837
# angel0,A1,angel2 80 107 30
# mangel0,mangle1,mangle2 80 107 30
# ZJ point (470, 540)
# zrect ((470, 454), (172, 10), 90)
# m01 zcenter is (470, 368)
# ZJ point (470, 368)
# zrect ((470, 295), (146, 10), 90)
# ZJ point (470, 222)
# zrect ((470, 185), (75, 10), 90)
# 1537 1537 837
# 0601 0601 0345
# i 34
# pwm0,pwm1,pwm2 1537 1508 808
# angel0,A1,angel2 80 113 27
# mangel0,mangle1,mangle2 80 113 27
# ZJ point (470, 540)
# zrect ((470, 451), (178, 10), 90)
# m01 zcenter is (470, 362)
# ZJ point (470, 362)
# zrect ((470, 286), (152, 10), 90)
# ZJ point (470, 210)
# zrect ((470, 173), (75, 10), 90)
# 1537 1508 808
# 0601 05e4 0328
# pwm0,pwm1,pwm2 1537 2075 1375
# angel0,A1,angel2 80 11 78
# mangel0,mangle1,mangle2 80 11 78
# ZJ point (470, 540)
# zrect ((470, 520), (40, 10), 90)
# m01 zcenter is (470, 500)
# ZJ point (470, 500)
# zrect ((470, 501), (-2, 10), 90)
# ZJ point (470, 502)
# zrect ((470, 465), (75, 10), 90)
# 1537 2075 1375
# 0601 081b 055f
# pwm0,pwm1,pwm2 1815 2020 1320
# angel0,A1,angel2 43 21 73
# mangel0,mangle1,mangle2 43 21 73
# ZJ point (470, 540)
# zrect ((453, 517), (58, 10), 53)
# m01 zcenter is (435, 493)
# ZJ point (435, 493)
# zrect ((432, 489), (12, 10), 53)
# ZJ point (428, 484)
# zrect ((406, 455), (75, 10), 53)
# 1815 2020 1320
# 0717 07e4 0528
# pwm0,pwm1,pwm2 1695 1833 1133
# angel0,A1,angel2 59 55 56
# mangel0,mangle1,mangle2 59 55 56
# ZJ point (470, 540)
# zrect ((451, 489), (110, 10), 69)
# m01 zcenter is (430, 437)
# ZJ point (430, 437)
# zrect ((418, 405), (70, 10), 69)
# ZJ point (405, 372)
# zrect ((392, 337), (75, 10), 69)
# 1695 1833 1133
# 069f 0729 046d
# pwm0,pwm1,pwm2 1646 1583 883
# angel0,A1,angel2 65 99 34
# mangel0,mangle1,mangle2 65 99 34
# ZJ point (470, 540)
# zrect ((449, 461), (164, 10), 75)
# m01 zcenter is (427, 381)
# ZJ point (427, 381)
# zrect ((410, 316), (136, 10), 75)
# ZJ point (392, 250)
# zrect ((383, 214), (75, 10), 75)
# 1646 1583 883
# 066e 062f 0373
# pwm0,pwm1,pwm2 1537 1725 1025
# angel0,A1,angel2 80 73 47
# mangel0,mangle1,mangle2 80 73 47
# ZJ point (470, 540)
# zrect ((470, 472), (136, 10), 90)
# m01 zcenter is (470, 404)
# ZJ point (470, 404)
# zrect ((470, 354), (100, 10), 90)
# ZJ point (470, 304)
# zrect ((470, 267), (75, 10), 90)
# 1537 1725 1025
# 0601 06bd 0401
# pwm0,pwm1,pwm2 1412 1694 994
# angel0,A1,angel2 97 79 44
# mangel0,mangle1,mangle2 97 79 44
# ZJ point (470, 540)
# zrect ((490, 473), (142, 10), 107)
# m01 zcenter is (510, 404)
# ZJ point (510, 404)
# zrect ((525, 353), (108, 10), 107)
# ZJ point (540, 300)
# zrect ((550, 265), (75, 10), 107)
# 1412 1694 994
# 0584 069e 03e2
# pwm0,pwm1,pwm2 1362 1874 1174
# angel0,A1,angel2 104 47 60
# mangel0,mangle1,mangle2 104 47 60
# ZJ point (470, 540)
# zrect ((490, 495), (100, 10), 114)
# m01 zcenter is (509, 449)
# ZJ point (509, 449)
# zrect ((520, 423), (58, 10), 114)
# ZJ point (531, 396)
# zrect ((546, 362), (75, 10), 114)
# 1362 1874 1174
# 0552 0752 0496
# pwm0,pwm1,pwm2 1258 2020 1320
# angel0,A1,angel2 118 21 73
# mangel0,mangle1,mangle2 118 21 73
# ZJ point (470, 540)
# zrect ((487, 518), (58, 10), 128)
# m01 zcenter is (504, 495)
# ZJ point (504, 495)
# zrect ((507, 491), (12, 10), 128)
# ZJ point (510, 486)
# zrect ((533, 457), (75, 10), 128)
# 1258 2020 1320
# 04ea 07e4 0528
# pwm0,pwm1,pwm2 1537 2075 1375
# angel0,A1,angel2 80 11 78
# mangel0,mangle1,mangle2 80 11 78
# ZJ point (470, 540)
# zrect ((470, 520), (40, 10), 90)
# m01 zcenter is (470, 500)
# ZJ point (470, 500)
# zrect ((470, 501), (-2, 10), 90)
# ZJ point (470, 502)
# zrect ((470, 465), (75, 10), 90)
# 1537 2075 1375
# 0601 081b 055f
