# %% [markdown]
# # 用Python对 码垛机器人运动学建模

# %% [markdown]
# ## 机器人照片如下

# %% [markdown]
# ![](marm.jpg)

# %% [markdown]
# # 先用OpenCV在图上标出各个零部件的尺寸，以像素为单位

# %% [markdown]
# ## 为此，先学习一下如何画倾斜的矩形，利用OpenCV中的画轮廓

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")
center=(200,100)
width=200
height=100
angle=10
rect=(center, (width, height), angle)
box = cv2.boxPoints(rect).astype(np.int0)
print(box)
cv2.drawContours(img,[box],0,(255,0,0),3)
cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()
type(box[2])

# %% [markdown]
# # 画一个以左端为基准点同样角度的矩形

# %%
import cv2
import numpy as np
import math as m
img=cv2.imread("marm.jpg")
leftbuttom=(92,131)
width=200
height=100
angle=10
print(m.sin(angle))
print(m.cos(angle))

x=int(m.sin(angle/180*m.pi)*width/2)
y=int(m.cos(angle/188*m.pi)*width/2)
center=leftbuttom+np.array([y,x])
rect=(center, (width, height), angle)
box = cv2.boxPoints(rect).astype(np.int0)
print(box)
cv2.drawContours(img,[box],0,(255,0,0),3)
cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 封装成函数

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#中心点，长度，角度
def drawlever(center,width,angle):
    height=100
    rect=(center, (width, height), angle)
    box = cv2.boxPoints(rect).astype(np.int0)
    cv2.drawContours(img,[box],0,(255,0,0),3)
    cv2.imshow("marm",img)

drawlever((630,250),800,3)    
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 封装成对象

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

# 臂模型
class mlever():
    def __init__(self,center,width,angle):
        self.center=center
        self.width=width
        self.angle=angle

    def drawlever(self):
        center=self.center
        width=self.width
        angle=self.angle
        height=100
        rect=(center, (width, height), angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
        
    def setlever(self,center,width,angle):
        self.center=center
        self.width=width
        self.angle=angle

        
ml01=mlever((315,120),400,3)    
ml02=mlever((380,245),340,140)
ml01.drawlever()
ml02.drawlever()

cv2.imshow("marm",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 电机模型，先画出来圆形和长型

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

angle=0
circlecenter=(260,360)
color=(0,255,0)
r=30
cv2.circle(img,circlecenter,r,color,5)
rect=(circlecenter,(2*r,4),angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)

angle=30
circlecenter=(260,360)
color=(0,255,0)
r=30
cv2.circle(img,circlecenter,r,color,5)
rect=(circlecenter,(2*r,4),angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)

angle=90
circlecenter=(260,360)
color=(0,255,0)
r=30
cv2.circle(img,circlecenter,r,color,5)
rect=(circlecenter,(2*r,4),angle)
box = cv2.boxPoints(rect).astype(np.int0)
cv2.drawContours(img,[box],0,(255,0,0),3)



cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 封装成函数

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

def drawmotor(center,angle):
    color=(0,255,0)
    r=30
    cv2.circle(img,circlecenter,r,color,5)
    rect=(circlecenter,(2*r,4),angle)
    box = cv2.boxPoints(rect).astype(np.int0)
    cv2.drawContours(img,[box],0,(255,0,0),3)

center=(260,360)
drawmotor(center,0)
drawmotor(center,30)
drawmotor(center,60)
drawmotor(center,90)

cv2.imshow("img",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# # 封装成对象

# %%
import cv2
import numpy as np

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

class mmotor():
    def __init__(self,center,angle,fixangle):
        self.center=center
        self.angle=angle
        self.fixangle=fixangle
        
    def setfixangle(fixangle):
        self.fixangle=fixangle
        
    def setcenter(center):
        self.center=center
        
    def draw(self,angle):
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle+self.fixangle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)

m02=mmotor((260,360),0,0)
m01=mmotor((500,150),0,-30)
for i in range(10):
    m02.draw(i*10)
    m01.draw(i*10)
    cv2.imshow("img",img)
    cv2.waitKey(1000)

cv2.destroyAllWindows()

# %% [markdown]
# # 给杠杆添加联动点以及相对旋转角度

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
imgcon=img.copy()
print(img.shape)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("caculate center")
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            print(w,h)
            self.center=self.jointpoint-np.array([w,h])
            print(self.center)    
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjoitpoint(self,jointpoint):
        self.jointpoint=jointpoint
        
ml02=mlever((380,245),100,10,0)
ml02.setjoitpoint((270,370))

for i in range(12):
    ml02.setangle(i*30)
    ml02.draw()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()
cv2.destroyAllWindows()

# %% [markdown]
# # 一个电机与杆同时动

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,fixangle):
        self.center=center
        self.angle=angle
        self.fixangle=fixangle
        
    def setfixangle(self,fixangle):
        self.fixangle=fixangle
        ,
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle+self.fixangle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(0,0)
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("caculate center")
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=self.jointpoint-np.array([w,h])
            self.rightend=self.center-np.array([w,h])
            print(self.center)    
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjoitpoint(self,jointpoint):
        self.jointpoint=jointpoint
        
m02=mmotor((260,360),0,0)
ml02=mlever((0,0),340,20,0)
ml02.setjoitpoint((260,360))
for i in range(18):
    angle=i*10
    m02.draw(angle)
    ml02.setangle(angle)
    ml02.draw()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %%
import numpy as np

a=[1,1]
print(a)
b=(1,1)
print(b)
c=b
print(c)
d=np.array(a)
type(c)
print(d)
type(a)

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)        
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)
        

m01=mmotor((500,140),0,0)
ml01=mlever((0,0),340,20,0)
ml01.setjointpoint((460,260))
m02=mmotor((260,360),0,0)
ml02=mlever((0,0),340,20,0)
ml02.setjointpoint((260,360))

for i in range(18):
    angle=i*10
    #电机02
    m02.drawrelative(angle)
    #杆02
    ml02.setangle(angle)
    ml02.draw()
    #电机01放在杆02的右端
    m01.setcenter(ml02.rightend)
    m01.startangle=180+m02.angle
    #电机01目前保持30度不变
    m01.drawrelative(30)
    #杆01固定在电机01中心，角度与电机01一样
    ml01.setjointpoint(m01.center)
    ml01.setangle(m01.angle)
    ml01.draw()
    ml01.drawrightend()
    cv2.imshow("marm",img)
    cv2.waitKey(1000)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 封装机械臂代码xy方向

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)        
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,ml01,ml02):
        self.m01=m01
        self.m02=m02
        self.ml01=ml01
        self.ml02=ml02
        self.angle1=0
        self.angle2=0
        ml02.setjointpoint(m02.center)
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        
m02=mmotor((260,360),0,0)
m01=mmotor((0,0),0,0)
ml01=mlever((0,0),340,20,0)
ml02=mlever((0,0),340,20,0)
marm=Marm(m01,m02,ml01,ml02)

for i in range(36):
    angle=i*5
    angle1=180-angle*2
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(500)
    #恢复背景
    img=imgcon.copy()

for i in range(36):
    angle=180-i*5
    angle1=45
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(500)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 调整机械臂参数，和实际吻合

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")

#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
print(W,H)
img=cv2.resize(img,(W,H))
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        rect=(self.center, (self.width,self.height), self.angle)
        box = cv2.boxPoints(rect).astype(np.int0)        
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,ml01,ml02):
        self.m01=m01
        self.m02=m02
        self.ml01=ml01
        self.ml02=ml02
        self.angle1=0
        self.angle2=0
        ml02.setjointpoint(m02.center)
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        
m02=mmotor((260,360),0,0)
m01=mmotor((0,0),0,0)
ml01=mlever((0,0),350,20,0)
ml02=mlever((0,0),340,20,0)
marm=Marm(m01,m02,ml01,ml02)

for i in range(36):
    angle=i*5
    angle1=180-angle*2
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(500)
    #恢复背景
    img=imgcon.copy()

for i in range(36):
    angle=180-i*5
    angle1=45
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(500)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 添加吸盘模型，永远垂直

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml02=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        ml02.setjointpoint(m02.center)
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        ml03.setangle(90)
        L=int(ml03.width/2)
        ml03.center=np.add(ml01.rightend,(0,L))
        ml03.draw()
        ml03.drawrightend()
        

m02=mmotor((260+400,360),0,0)
m01=mmotor((0,0),0,0)
m03=mmotor((0,0),0,0)
ml01=mlever((0,0),350,20,0)
ml02=mlever((0,0),340,20,0)
ml03=mlever((0,0),100,20,0)
marm=Marm(m01,m02,m03,ml01,ml02,ml03)

for i in range(30):
    angle=i*5
    angle1=180-angle*2+10
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

for i in range(15):
    angle=150-i*5
    angle1=45
    marm.draw(angle1,angle)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 用解析法解逆向运动方程

# %% [markdown]
# ![](marmreverse.png)

# %% [markdown]
# im# 已知x，y坐标，为机械臂欲到达的坐标，L1，L2为机械臂长，求电机的角度Q1，Q2=Q4+Q5

# %%
import math as mt

x=500
y=100
L1=350
L2=340

# %% [markdown]
# # 这样可以算出L3

# %%
L3=mt.sqrt(y*y+x*x)
L3

# %% [markdown]
# # 根据海伦公式可以知道L1，L2，L3 组成的三角形面积

# %%
p=(L1+L2+L3)/2
S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
S

# %% [markdown]
# # 求出三角形在L3上的高 0.5*L3*h=s

# %%
h=S*2/L3
h

# %% [markdown]
# # 得出Q5并转换为角度

# %%
Q5=mt.asin(h/L2)/mt.pi*180
Q5

# %% [markdown]
# # 计算出Q4

# %%
Q4=mt.asin(y/L3)/mt.pi*180
Q4

# %% [markdown]
# # 计算出Q7

# %%
Q7=mt.asin(h/L1)/mt.pi*180
Q7

# %% [markdown]
# # 终于，得到了Q1，Q2

# %%
Q1=180-Q5-Q7
Q2=Q5+Q4
print("Q1,Q2",Q1,Q2)

# %% [markdown]
# # 整合为函数

# %%
def xytoq(x,y):
    L1=350
    L2=340
    L3=mt.sqrt(y*y+x*x)
    p=(L1+L2+L3)/2
    S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
    h=S*2/L3
    Q5=mt.asin(h/L2)/mt.pi*180
    Q4=mt.asin(y/L3)/mt.pi*180
    Q7=mt.asin(h/L1)/mt.pi*180
    Q1=180-Q5-Q7
    Q2=Q5+Q4
    #print("Q1,Q2",Q1,Q2)
    return Q1,Q2

print(xytoq(500,100))

# %% [markdown]
# # 整合到对象中

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        self.angle=self.startangle+relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml02=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        ml02.setjointpoint(m02.center)
    def xytoq(self,x,y):
        L1=ml01.width
        L2=ml02.width
        L3=mt.sqrt(y*y+x*x)
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    def draw(self,angle1,angle2):
        #电机02
        m02.drawrelative(angle2)
        #杆02
        ml02.setangle(angle2)
        ml02.draw()
        #电机01放在杆02的右端
        m01.setcenter(ml02.rightend)
        m01.startangle=180+m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        ml01.setjointpoint(m01.center)
        ml01.setangle(m01.angle)
        ml01.draw()
        ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        ml03.setangle(90)
        L=int(ml03.width/2)
        ml03.center=np.add(ml01.rightend,(0,L))
        ml03.draw()
        ml03.drawrightend()
        

m02=mmotor((260+400,360),0,0)
m01=mmotor((0,0),0,0)
m03=mmotor((0,0),0,0)
ml01=mlever((0,0),350,20,0)
ml02=mlever((0,0),340,20,0)
ml03=mlever((0,0),100,20,0)
marm=Marm(m01,m02,m03,ml01,ml02,ml03)

for i in range(60):
    x=i*10+10
    y=0
    angle1,angle2=marm.xytoq(x,y)
    marm.draw(angle1,angle2)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

for i in range(60):
    x=650-i*10
    y=0
    angle1,angle2=marm.xytoq(x,y)
    marm.draw(angle1,angle2)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

    
    
cv2.destroyAllWindows()

# %% [markdown]
# # 将计算电机控制的PWM值，500~2500

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        self.ml02.setjointpoint(self.m02.center)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        print("angle1disp,angle2disp,angle1,angle2",angle1disp,angle2disp,  angel1,angel2)
        self.robodraw(angel1,angel2)

mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,90)
#mM01.facetome=True
mM03=mmotor((0,0),0,0,180)
mMl01=mlever((0,0),350,20,0)
mMl02=mlever((0,0),350,20,0)
mMl03=mlever((0,0),100,20,0)
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(50):
    x=i*10-100
    y=-40
    angle1,angle2=marm.xytoq(x,y)
    marm.scrdraw(angle1,angle2)
    cv2.imshow("marm",img)
    cv2.waitKey(200)
    #恢复背景
    img=imgcon.copy()

for i in range(50):
    x=400-i*10
    y=-40
    angle1,angle2=marm.xytoq(x,y)
    marm.scrdraw(angle1,angle2)
    cv2.imshow("marm",img)
    cv2.waitKey(200)
    #恢复背景
    img=imgcon.copy()
# [117,54],[126,68],[133,77]
pwmtable=[[0x708,0x44c],[0x76c,0x4e7],[0x7b9,0x54b]]

for j in range(10):
    for i in range(3):
        pwm=pwmtable[i]
        print("pwm",pwm)
        marm.drawpwm(pwm[0],pwm[1])
        cv2.imshow("marm",img)
        cv2.waitKey(1000)
        #恢复背景
        img=imgcon.copy()
cv2.destroyAllWindows()

# %% [markdown]
# # 仿真手工测量的棋盘3个格子的运动pwm命令

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        self.ml02.setjointpoint(self.m02.center)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        #电机01目前保持30度不变
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,angle1,angle2,A2",angle1disp,angle2disp,angel1,angel2)
        self.robodraw(A1,angel2)

mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,180)
#mM01.facetome=True
mM03=mmotor((0,0),0,0,180)
mMl01=mlever((0,0),350,20,0)
mMl02=mlever((0,0),350,20,0)
mMl03=mlever((0,0),100,20,0)
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

# [117,54],[126,68],[133,77]
pwmtable=[[0x708,0x44c],[0x76c,0x4e7],[0x7b9,0x54b]]

i=0
while True:
    pwm=pwmtable[i%3]
    i+=1
    print("pwm",pwm)
    marm.drawpwm(pwm[0],pwm[1])
    cv2.imshow("marm",img)
    if cv2.waitKey(0)&0xff == 27:
        break
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 位置xy通过PWM参数仿真运行

# %%
import cv2
import numpy as np
import math  as mt

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        #将梁2固定在电机2的中心
        self.ml02.setjointpoint(self.m02.center)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,A1,%x,%x,"%(pwm1,pwm2),angle1disp,angle2disp,A1)
        self.robodraw(A1,angel2)
    def xytopwm(self,x,y):
        q1,q2=self.xytoq(x,y)
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        return pwm1,pwm2
    
    def serwrite(self,pwm1,pwm2):
        print("TBD,serialwrite %x %x"%(pwm1,pwm2))
        return
    
    def robotTwin(self,x,y):
        pwm1,pwm2=self.xytopwm(x,y)
        self.drawpwm(pwm1,pwm2)
        self.serwrite(pwm1,pwm2)
        
#配置零件舵机
mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,180)
mM03=mmotor((0,0),0,0,180)
#配置零件梁
mMl01=mlever((0,0),300,20,0)
mMl02=mlever((0,0),300,20,0)
mMl03=mlever((0,0),100,20,0)
#组装成机械臂
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(50):
    x=i*10+100
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

for i in range(50):
    x=600-i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    cv2.waitKey(300)
    #恢复背景
    img=imgcon.copy()

cv2.destroyAllWindows()

# %% [markdown]
# # 添加串口控制机械臂

# %%
import cv2
import numpy as np
import math  as mt
import serial
import serial.tools.list_ports
import string
import binascii
import time


img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/2)
W=int(shape[1]/2)
BW=int(W*1.5)+1
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,0,0,400,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
print(img.shape)

#电机模型
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        self.startangle=startangle
        self.maxangle=maxangle
        self.relaangle=0
        self.pwm=500
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.pwm=500+self.relaangle*180/self.maxangle*(2500-500)/180
        self.draw(self.angle)
        

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)          
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        self.ser=None
        #将梁2固定在电机2的中心
        self.ml02.setjointpoint(self.m02.center)
        #打开串口
        ports = list(serial.tools.list_ports.comports())
        print (ports)
        #便利 寻找串口
        for p in ports:
            print (p[1])
            if "serial" in p[1] or "CH340" in p[1]:
                self.ser=serial.Serial(port=p[0])
                if self.ser is not None:
                    print(self.ser)
                    print("serial conected")
                else:
                    print("serial not connected")
                    return
            else:
                print ("No CH340 Device was found connected to the computer")
                return
        self.robotinit()
    def robotinit(self):
        if self.ser is None:
            return
        m0=bytes.fromhex('ff 01 00 08 00')# 舵机0速度为 72
        m1=bytes.fromhex('ff 01 01 08 00')# 舵机1速度为 72
        m2=bytes.fromhex('ff 01 02 08 00')# 舵机2速度为 72
        mo0=bytes.fromhex('ff 02 00 dc 05')#设置初始舵机0位置
        mo1=bytes.fromhex('ff 02 01 82 07')#设置初始舵机1的位置
        mo2 = bytes.fromhex('ff 02 02 dc 05')#设置初始舵机2的位置
        mo3 = bytes.fromhex('ff 02 03 dc 05')#设置初始舵机3的位置
        self.ser.write(m0)
        self.ser.write(m1)
        self.ser.write(m2)
        self.ser.write(mo0)
        self.ser.write(mo1)
        self.ser.write(mo2)
        self.ser.write(mo3)
    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)+0.01
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        if self.ser is not None:
            cv2.circle(img,(50,50),10,(0,255,0),3)
        else:
            cv2.circle(img,(50,50),10,(0,0,255),3)
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,A1,%x,%x,"%(pwm1,pwm2),angle1disp,angle2disp,A1)
        self.robodraw(A1,angel2)
    def xytopwm(self,x,y):
        q1,q2=self.xytoq(x,y)
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        return pwm1,pwm2
    
    def serwrite(self,pwm1,pwm2):
        if self.ser is None:
            return
        print(pwm1,pwm2)
        pw1str="%04x"%pwm1
        pw2str="%04x"%pwm2
        print(pw1str,pw2str)
        mo1hexstr="ff 02 01"+" "+pw1str[2:4]+" "+pw1str[0:2]
        mo2hexstr="ff 02 02"+" "+pw2str[2:4]+" "+pw2str[0:2]
        self.ser.write(bytes.fromhex(mo1hexstr))
        self.ser.write(bytes.fromhex(mo2hexstr))
        return
    
    def robotTwin(self,x,y):
        pwm1,pwm2=self.xytopwm(x,y)
        self.drawpwm(pwm1,pwm2)
        self.serwrite(pwm1,pwm2)
        
#配置零件舵机
mM02=mmotor((260+400,360),0,0,180)
mM01=mmotor((0,0),0,0,180)
mM03=mmotor((0,0),0,0,180)
#配置零件梁
mMl01=mlever((0,0),300,20,0)
mMl02=mlever((0,0),300,20,0)
mMl03=mlever((0,0),100,20,0)
#组装成机械臂
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(60):
    x=i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()

for i in range(60):
    x=600-i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()
    
marm.ser.close()
cv2.destroyAllWindows()

# %% [markdown]
# # 添加Z方向上的另一个视图

# %%
import cv2
import numpy as np
import math  as mt
import serial
import serial.tools.list_ports
import string
import binascii
import time

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/3)
W=int(shape[1]/3)
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,300,0,300,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()
zcenter=(470,300)

#电机模型,
class mmotor():
    def __init__(self,center,angle,startangle,maxangle):
        self.center=center
        self.angle=angle
        #电机中心点随杠杆旋转时电机0位与水平线的夹角
        self.startangle=startangle
        #电机中点为90度，顺时针方向为正，最小点和最大点角度
        self.maxangle=maxangle
        #self.minangle=minangle
        self.relaangle=0
        self.facetome=False
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        color=(0,255,0)
        r=30
        cv2.circle(img,self.center,r,color,-1)
        rect=(self.center,(2*r,4),angle)
        box = cv2.boxPoints(rect).astype(np.int0)
        cv2.drawContours(img,[box],0,(255,0,0),3)
        #画z方向
        cv2.circle(img,zcenter,3,(255,0,0),-1)
        
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.rightend=(width,0)
        self.rightendr=10
        self.zcenter=0
        self.zwidth=0
        self.zheight=20
        self.zangle=90
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(255,0,0),3)
        #画Z轴的投影
        self.zcenter=self.center
        self.zcenter=(zcenter[0],self.zcenter[0])
        self.zwidth=self.width*mt.cos(self.angle/180*mt.pi)
        self.zangle=90
        zrect=(self.zcenter, (self.zwidth,self.zheight), self.zangle)
        zbox = cv2.boxPoints(zrect).astype(np.int0)
        cv2.drawContours(img,[zbox],0,(0,255,0),3)
        
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)

class Marm():
    def __init__(self,m01,m02,m03,ml01,ml02,ml03):
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.angle1=0
        self.angle2=0
        self.angle3=0
        self.ser=None
        self.img=None
        self.imgcon=None
        #将梁2固定在电机2的中心
        self.ml02.setjointpoint(self.m02.center)
        #模拟器初始化
        self.simuinit()
        #串口及机械臂位置初始化
        self.robotinit()
        
    def robotinit(self):
        #打开串口
        ports = list(serial.tools.list_ports.comports())
        print (ports)
        #便利 寻找串口
        for p in ports:
            print (p[1])
            if "serial" in p[1] or "CH340" in p[1]:
                self.ser=serial.Serial(port=p[0])
                if self.ser is not None:
                    print(self.ser)
                    print("serial conected")
                else:
                    print("serial not connected")
                    return
            else:
                print ("No CH340 Device was found connected to the computer")
                return
        if self.ser is None:
            return
        m0=bytes.fromhex('ff 01 00 08 00')# 舵机0速度为 72
        m1=bytes.fromhex('ff 01 01 08 00')# 舵机1速度为 72
        m2=bytes.fromhex('ff 01 02 08 00')# 舵机2速度为 72
        mo0=bytes.fromhex('ff 02 00 dc 05')#设置初始舵机0位置
        mo1=bytes.fromhex('ff 02 01 82 07')#设置初始舵机1的位置
        mo2 = bytes.fromhex('ff 02 02 dc 05')#设置初始舵机2的位置
        mo3 = bytes.fromhex('ff 02 03 dc 05')#设置初始舵机3的位置
        self.ser.write(m0)
        self.ser.write(m1)
        self.ser.write(m2)
        self.ser.write(mo0)
        self.ser.write(mo1)
        self.ser.write(mo2)
        self.ser.write(mo3)
        
    def simuinit(self):
        return

    def xytoq(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)+0.01
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置
    def scrdraw(self,angle1,angle2):
        #电机02
        self.m02.drawrelative(angle2)
        #杆02
        self.ml02.setangle(angle2)
        self.ml02.draw()
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.draw()
        self.ml03.drawrightend()
        if self.ser is not None:
            cv2.circle(img,(50,50),10,(0,255,0),3)
        else:
            cv2.circle(img,(50,50),10,(0,0,255),3)
        
    #输入角度考虑电机是否对面装配，然后画在图上   
    def robodraw(self,angle1,angle2):
        mangle1=angle1
        mangle2=angle2
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            mangle2=slef.m02.maxangle-angle2
        print("mangle1,mangle2",mangle1,mangle2)
        self.scrdraw(mangle1,mangle2)
        
    def drawpwm(self,pwm1,pwm2):
        angle1disp=int((pwm1-500)/2000*180)
        angle2disp=int((pwm2-500)/2000*180)
        angel1=int(angle1disp*self.m01.maxangle/180)
        angel2=int(angle2disp*self.m02.maxangle/180)
        
        A1=180+50-(angel1+angel2)
        print("angle1disp,angle2disp,A1,%x,%x,"%(pwm1,pwm2),angle1disp,angle2disp,A1)
        self.robodraw(A1,angel2)
    def xytopwm(self,x,y):
        q1,q2=self.xytoq(x,y)
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        return pwm1,pwm2
    
    def serwrite(self,pwm1,pwm2):
        if self.ser is None:
            return
        print(pwm1,pwm2)
        pw1str="%04x"%pwm1
        pw2str="%04x"%pwm2
        print(pw1str,pw2str)
        mo1hexstr="ff 02 01"+" "+pw1str[2:4]+" "+pw1str[0:2]
        mo2hexstr="ff 02 02"+" "+pw2str[2:4]+" "+pw2str[0:2]
        self.ser.write(bytes.fromhex(mo1hexstr))
        self.ser.write(bytes.fromhex(mo2hexstr))
        return
    
    def robotTwin(self,x,y):
        pwm1,pwm2=self.xytopwm(x,y)
        self.drawpwm(pwm1,pwm2)
        self.serwrite(pwm1,pwm2)
    
    def destroy(self):
        if self.ser is not None:
            self.ser.close()
        cv2.destroyAllWindows()
        
#配置零件舵机
mM02=mmotor((170+300,240+300),0,0,180)
mM01=mmotor((0,0),0,0,180)
mM03=mmotor((0,0),0,0,180)
#配置零件梁
mMl01=mlever((0,0),200,10,0)
mMl02=mlever((0,0),200,10,0)
mMl03=mlever((0,0),60,10,0)
#组装成机械臂
marm=Marm(mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(60):
    x=i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()

for i in range(60):
    x=600-i*10
    y=0
    marm.robotTwin(x,y)
    cv2.imshow("marm",img)
    if cv2.waitKey(100)&0xff == 27:
        break
    #恢复背景
    img=imgcon.copy()
    
time.sleep(3)
marm.destroy()
# Out:
# (1080, 1440, 3)
# 480 360
# []
# angle1disp,angle2disp,A1,807,5db, 139 89 2
# mangle1,mangle2 2 89
# angle1disp,angle2disp,A1,7f7,5cc, 138 88 4
# mangle1,mangle2 4 88
# angle1disp,angle2disp,A1,7e7,5bc, 137 87 6
# mangle1,mangle2 6 87
# angle1disp,angle2disp,A1,7d7,5ac, 135 85 10
# mangle1,mangle2 10 85
# angle1disp,angle2disp,A1,7c7,59c, 134 84 12
# mangle1,mangle2 12 84
# angle1disp,angle2disp,A1,7b7,58c, 132 82 16
# mangle1,mangle2 16 82
# angle1disp,angle2disp,A1,7a7,57c, 131 81 18
# mangle1,mangle2 18 81
# angle1disp,angle2disp,A1,797,56b, 129 79 22
# mangle1,mangle2 22 79
# angle1disp,angle2disp,A1,787,55b, 128 78 24
# mangle1,mangle2 24 78
# angle1disp,angle2disp,A1,777,54b, 126 76 28
# mangle1,mangle2 28 76
# angle1disp,angle2disp,A1,766,53b, 125 75 30
# mangle1,mangle2 30 75
# angle1disp,angle2disp,A1,756,52a, 124 73 33
# mangle1,mangle2 33 73
# angle1disp,angle2disp,A1,745,51a, 122 72 36
# mangle1,mangle2 36 72
# angle1disp,angle2disp,A1,734,509, 120 71 39
# mangle1,mangle2 39 71
# angle1disp,angle2disp,A1,723,4f8, 119 69 42
# mangle1,mangle2 42 69
# angle1disp,angle2disp,A1,712,4e7, 117 67 46
# mangle1,mangle2 46 67
# angle1disp,angle2disp,A1,701,4d6, 116 66 48
# mangle1,mangle2 48 66
# angle1disp,angle2disp,A1,6f0,4c4, 114 64 52
# mangle1,mangle2 52 64
# angle1disp,angle2disp,A1,6de,4b2, 113 63 54
# mangle1,mangle2 54 63
# angle1disp,angle2disp,A1,6cc,4a0, 111 61 58
# mangle1,mangle2 58 61
# angle1disp,angle2disp,A1,6ba,48e, 109 59 62
# mangle1,mangle2 62 59
# angle1disp,angle2disp,A1,6a7,47c, 108 58 64
# mangle1,mangle2 64 58
# angle1disp,angle2disp,A1,694,469, 106 56 68
# mangle1,mangle2 68 56
# angle1disp,angle2disp,A1,681,455, 104 54 72
# mangle1,mangle2 72 54
# angle1disp,angle2disp,A1,66d,442, 103 53 74
# mangle1,mangle2 74 53
# angle1disp,angle2disp,A1,659,42e, 101 51 78
# mangle1,mangle2 78 51
# angle1disp,angle2disp,A1,645,419, 99 49 82
# mangle1,mangle2 82 49
# angle1disp,angle2disp,A1,62f,404, 97 47 86
# mangle1,mangle2 86 47
# angle1disp,angle2disp,A1,619,3ee, 95 45 90
# mangle1,mangle2 90 45
# angle1disp,angle2disp,A1,603,3d7, 93 43 94
# mangle1,mangle2 94 43
# angle1disp,angle2disp,A1,5eb,3c0, 91 41 98
# mangle1,mangle2 98 41
# angle1disp,angle2disp,A1,5d3,3a7, 89 39 102
# mangle1,mangle2 102 39
# angle1disp,angle2disp,A1,5b9,38d, 86 36 108
# mangle1,mangle2 108 36
# angle1disp,angle2disp,A1,59d,372, 84 34 112
# mangle1,mangle2 112 34
# angle1disp,angle2disp,A1,580,355, 81 31 118
# mangle1,mangle2 118 31
# angle1disp,angle2disp,A1,561,335, 78 28 124
# mangle1,mangle2 124 28
# angle1disp,angle2disp,A1,53e,313, 75 25 130
# mangle1,mangle2 130 25
# angle1disp,angle2disp,A1,517,2ec, 72 22 136
# mangle1,mangle2 136 22
# angle1disp,angle2disp,A1,4e9,2be, 68 18 144
# mangle1,mangle2 144 18
# angle1disp,angle2disp,A1,4ae,282, 62 12 156
# mangle1,mangle2 156 12
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,479,24e, 58 8 164
# mangle1,mangle2 164 8
# angle1disp,angle2disp,A1,4ae,282, 62 12 156
# mangle1,mangle2 156 12
# angle1disp,angle2disp,A1,4e9,2be, 68 18 144
# mangle1,mangle2 144 18
# angle1disp,angle2disp,A1,517,2ec, 72 22 136
# mangle1,mangle2 136 22
# angle1disp,angle2disp,A1,53e,313, 75 25 130
# mangle1,mangle2 130 25
# angle1disp,angle2disp,A1,561,335, 78 28 124
# mangle1,mangle2 124 28
# angle1disp,angle2disp,A1,580,355, 81 31 118
# mangle1,mangle2 118 31
# angle1disp,angle2disp,A1,59d,372, 84 34 112
# mangle1,mangle2 112 34
# angle1disp,angle2disp,A1,5b9,38d, 86 36 108
# mangle1,mangle2 108 36
# angle1disp,angle2disp,A1,5d3,3a7, 89 39 102
# mangle1,mangle2 102 39
# angle1disp,angle2disp,A1,5eb,3c0, 91 41 98
# mangle1,mangle2 98 41
# angle1disp,angle2disp,A1,603,3d7, 93 43 94
# mangle1,mangle2 94 43
# angle1disp,angle2disp,A1,619,3ee, 95 45 90
# mangle1,mangle2 90 45
# angle1disp,angle2disp,A1,62f,404, 97 47 86
# mangle1,mangle2 86 47
# angle1disp,angle2disp,A1,645,419, 99 49 82
# mangle1,mangle2 82 49
# angle1disp,angle2disp,A1,659,42e, 101 51 78
# mangle1,mangle2 78 51
# angle1disp,angle2disp,A1,66d,442, 103 53 74
# mangle1,mangle2 74 53
# angle1disp,angle2disp,A1,681,455, 104 54 72
# mangle1,mangle2 72 54
# angle1disp,angle2disp,A1,694,469, 106 56 68
# mangle1,mangle2 68 56
# angle1disp,angle2disp,A1,6a7,47c, 108 58 64
# mangle1,mangle2 64 58
# angle1disp,angle2disp,A1,6ba,48e, 109 59 62
# mangle1,mangle2 62 59
# angle1disp,angle2disp,A1,6cc,4a0, 111 61 58
# mangle1,mangle2 58 61
# angle1disp,angle2disp,A1,6de,4b2, 113 63 54
# mangle1,mangle2 54 63
# angle1disp,angle2disp,A1,6f0,4c4, 114 64 52
# mangle1,mangle2 52 64
# angle1disp,angle2disp,A1,701,4d6, 116 66 48
# mangle1,mangle2 48 66
# angle1disp,angle2disp,A1,712,4e7, 117 67 46
# mangle1,mangle2 46 67
# angle1disp,angle2disp,A1,723,4f8, 119 69 42
# mangle1,mangle2 42 69
# angle1disp,angle2disp,A1,734,509, 120 71 39
# mangle1,mangle2 39 71
# angle1disp,angle2disp,A1,745,51a, 122 72 36
# mangle1,mangle2 36 72
# angle1disp,angle2disp,A1,756,52a, 124 73 33
# mangle1,mangle2 33 73
# angle1disp,angle2disp,A1,766,53b, 125 75 30
# mangle1,mangle2 30 75
# angle1disp,angle2disp,A1,777,54b, 126 76 28
# mangle1,mangle2 28 76
# angle1disp,angle2disp,A1,787,55b, 128 78 24
# mangle1,mangle2 24 78
# angle1disp,angle2disp,A1,797,56b, 129 79 22
# mangle1,mangle2 22 79
# angle1disp,angle2disp,A1,7a7,57c, 131 81 18
# mangle1,mangle2 18 81
# angle1disp,angle2disp,A1,7b7,58c, 132 82 16
# mangle1,mangle2 16 82
# angle1disp,angle2disp,A1,7c7,59c, 134 84 12
# mangle1,mangle2 12 84
# angle1disp,angle2disp,A1,7d7,5ac, 135 85 10
# mangle1,mangle2 10 85
# angle1disp,angle2disp,A1,7e7,5bc, 137 87 6
# mangle1,mangle2 6 87
# angle1disp,angle2disp,A1,7f7,5cc, 138 88 4
# mangle1,mangle2 4 88

# %% [markdown]
# # 让电机0旋转，角度为60度，正向运动模型生成

# %%
import cv2
import numpy as np
import math  as mt
import serial
import serial.tools.list_ports
import string
import binascii
import time

img=cv2.imread("marm.jpg")
#图像缩一半便于屏幕显示处理
shape=img.shape
print(shape)
H=int(shape[0]/3)
W=int(shape[1]/3)
print(W,H)
img=cv2.resize(img,(W,H))
img= cv2.copyMakeBorder(img,300,0,300,0,cv2.BORDER_CONSTANT,value=(100,100,0))
imgcon=img.copy()

#顶视图平面中点
zcenter=(470,300)

#电机模型,
class mmotor():
    def __init__(self,center,angle,startangle,minangle,maxangle):
        self.center=center
        self.angle=angle
        #电机中心点随杠杆旋转时电机0位与水平线的夹角
        self.startangle=startangle
        #电机中点为90度，顺时针方向为正，最小点和最大点角度
        self.maxangle=maxangle
        self.minangle=minangle
        self.relaangle=0
        self.facetome=False
        self.zcenter=(0,0)
        
    def setcenter(self,center):
        self.center=center
        
    def draw(self,angle):
        self.angle=angle
        #通过舵机角度270判断是否为底座舵机，画图时大一些
        if self.maxangle-self.startangle >200:
            r=50
            color=(0,255,0)
            cv2.circle(img,self.center,r,color,3)
            rect=(self.center,(2*r,4),angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            cv2.drawContours(img,[box],0,color,3)
        else:
            r=20
            color=(155,0,0)
            cv2.circle(img,self.center,r,color,3)
            rect=(self.center,(2*r,4),angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            cv2.drawContours(img,[box],0,color,3)
      
    def drawrelative(self,relaangle):
        if relaangle >self.maxangle:
            relaangle=self.maxangle
        self.relaangle=relaangle
        self.angle=self.startangle+self.relaangle
        self.draw(self.angle)

# 臂模型
class mlever():
    def __init__(self,center,width,high,angle):
        self.center=center
        self.width=width
        self.angle=angle
        self.height=high
        self.jointpoint=(0,0)
        self.zjointpoint=(0,0)
        self.rightend=(width,0)
        self.zrightend=(0,0)
        self.rightendr=10
        self.zcenter=(0,0)
        self.zwidth=100
        self.zheight=10
        self.zangle=60
    
    def draw(self):
        global img,imgcon
        height=100
        # 没有连接点，以中心为轴旋转
        if self.jointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转 w,h为中心点相对坐标
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            h=int(self.width/2*mt.sin(self.angle/180*mt.pi))
            #z轴的投影长度为中心点坐标的一倍
            self.zwidth=2*w
            self.center=(self.jointpoint[0]-w,self.jointpoint[1]-h)
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(self.jointpoint[0]-w*2,self.jointpoint[1]-h*2)
        else:
            w=int(self.width/2*mt.cos(self.angle/180*mt.pi))
            #z轴的投影长度为中心点坐标的一倍
            self.zwidth=2*w
            rect=(self.center, (self.width,self.height), self.angle)
            box = cv2.boxPoints(rect).astype(np.int0)
            self.rightend=(int((box[2][0]+box[3][0])/2),int((box[2][1]+box[3][1])/2))
        cv2.drawContours(img,[box],0,(155,0,0),3)
        #画Z轴的投影
        if self.zjointpoint != (0,0):
            # 有连接点，则重新确定中心，绕连接点转
            print("ZJ point",self.zjointpoint)
            w=int(self.zwidth/2*mt.cos(self.zangle/180*mt.pi))
            h=int(self.zwidth/2*mt.sin(self.zangle/180*mt.pi))
            self.zcenter=(self.zjointpoint[0]-w,self.zjointpoint[1]-h)
        else:
            self.zcenter=zcenter
            pass
        zrect=(self.zcenter, (self.zwidth,self.zheight), self.zangle)
        print("zrect",zrect)
        zbox = cv2.boxPoints(zrect).astype(np.int0)
        self.zrightend=(int((zbox[0][0]+zbox[1][0])/2),int((zbox[0][1]+zbox[1][1])/2))
        cv2.drawContours(img,[zbox],0,(0,255,0),3)
        
    def setl(self,center,angle):
        self.center=center
        self.angle=angle
    def setangle(self,angle):
        self.angle=angle    
    def setjointpoint(self,jointpoint):
        self.jointpoint=jointpoint
    def setzjointpoint(self,jointpoint):
        self.zjointpoint=jointpoint
    def setzangle(self,angle):
        self.zangle=angle
    def drawrightend(self):
        cv2.circle(img,self.rightend,self.rightendr,(0,0,255),3)
        cv2.circle(img,self.zrightend,self.rightendr,(0,255,0),3)

class Marm():
    def __init__(self,m00,m01,m02,m03,ml01,ml02,ml03):
        self.m00=m00
        self.m01=m01
        self.m02=m02
        self.m03=m03        
        self.ml01=ml01
        self.ml02=ml02
        self.ml03=ml03 
        self.ser=None
        self.img=None
        self.imgcon=None
        

        #模拟器初始化
        self.simuinit()
        #串口及机械臂位置初始化
        self.robotinit()
        
    def robotinit(self):
        #打开串口
        ports = list(serial.tools.list_ports.comports())
        print (ports)
        #便利 寻找串口
        for p in ports:
            print (p[1])
            if "serial" in p[1] or "CH340" in p[1]:
                self.ser=serial.Serial(port=p[0])
                if self.ser is not None:
                    print(self.ser)
                    print("serial conected")
                else:
                    print("serial not connected")
                    return
            else:
                print ("No CH340 Device was found connected to the computer")
                return
        if self.ser is None:
            return
        m0=bytes.fromhex('ff 01 00 08 00')# 舵机0速度为 72
        m1=bytes.fromhex('ff 01 01 08 00')# 舵机1速度为 72
        m2=bytes.fromhex('ff 01 02 08 00')# 舵机2速度为 72
        mo0=bytes.fromhex('ff 02 00 dc 05')#设置初始舵机0位置
        mo1=bytes.fromhex('ff 02 01 82 07')#设置初始舵机1的位置
        mo2 = bytes.fromhex('ff 02 02 dc 05')#设置初始舵机2的位置
        mo3 = bytes.fromhex('ff 02 03 dc 05')#设置初始舵机3的位置
        self.ser.write(m0)
        self.ser.write(m1)
        self.ser.write(m2)
        self.ser.write(mo0)
        self.ser.write(mo1)
        self.ser.write(mo2)
        self.ser.write(mo3)
        
    def simuinit(self):
        return
    
    def xztoq0(self,x,z):
        r=mt.sqrt(x*x+z*z)
        if z >=0:
            q0=180-mt.acos(z/r)/mt.pi*180
        else:
            q0=mt.acos(abs(z)/r)/mt.pi*180
        return q0
    
    def xytoq12(self,x,y):
        L1=self.ml01.width
        L2=self.ml02.width
        L3=mt.sqrt(y*y+x*x)+0.01
        #L3最长不超过两臂之和
        if L3>L1+L2:
            L3=L1+L2-4
        #L3最短不少于两臂之差
        if L3<abs(L1-L2):
            L3=abs(L1-L2)+4
        p=(L1+L2+L3)/2
        S=mt.sqrt(p*(p-L1)*(p-L2)*(p-L3))
        h=S*2/L3
        Q5=mt.asin(h/L2)/mt.pi*180
        Q4=mt.asin(y/L3)/mt.pi*180
        Q7=mt.asin(h/L1)/mt.pi*180
        Q1=180-Q5-Q7
        Q2=Q5+Q4
        #print("Q1,Q2",Q1,Q2)
        return Q1,Q2
    
    #输入参数为屏幕角度，不考虑电机面对面放置,考虑杆的移动相对位置
    def scrdraw(self,angle0,angle1,angle2):
        #电机0在底盘
        self.m00.drawrelative(angle0)
        #杆02与电机0中心在z轴方向相连
        self.ml02.setzjointpoint(self.m00.center)
        self.ml02.setzangle(angle0)
        #电机02
        self.m02.drawrelative(angle2)
         #杆02,与m02的圆心相连
        self.ml02.setangle(angle2)
        self.ml02.draw()
        self.ml02.setjointpoint(self.m02.center)
        #电机01放在杆02的右端
        self.m01.setcenter(self.ml02.rightend)
        self.m01.zcenter=self.ml02.zrightend
        print("m01 zcenter is",self.m01.zcenter)
        self.m01.startangle=180+self.m02.angle
        if angle1<=0:
            angle1=0
        self.m01.drawrelative(angle1)
        #杆01固定在电机01中心，角度与电机01一样
        self.ml01.setjointpoint(self.m01.center)
        self.ml01.setangle(self.m01.angle)
        self.ml01.setzjointpoint(self.m01.zcenter)
        self.ml01.setzangle(angle0)
        self.ml01.draw()
        self.ml01.drawrightend()
        #杆03永远保持垂直，中心点位于杆01右端下方
        self.ml03.setangle(90)
        L=int(self.ml03.width/2)
        self.ml03.center=np.add(self.ml01.rightend,(0,L))
        self.ml03.setzjointpoint(self.ml01.zrightend)
        self.ml03.setzangle(angle0)
        self.ml03.draw()
        self.ml03.drawrightend()
        #显示串口连接状态红未连接绿连接
        if self.ser is not None:
            cv2.circle(img,(50,50),10,(0,255,0),3)
        else:
            cv2.circle(img,(50,50),10,(0,0,255),3)
        
    #输入角度考虑电机是否对面装配，从而是逆时针旋转，然后画在图上   
    def robodraw(self,angle0,angle1,angle2):
        mangle0=angle0
        mangle1=angle1
        mangle2=angle2
        if self.m00.facetome == True:
            print("facetome")
            mangle0=self.m00.maxangle-angle0
        if self.m01.facetome == True:
            print("facetome")
            mangle1=self.m01.maxangle-angle1
        if self.m02.facetome == True:
            print("facetome")
            mangle2=slef.m02.maxangle-angle2
        print("mangel0,mangle1,mangle2",mangle0,mangle1,mangle2)
        self.scrdraw(mangle0,mangle1,mangle2)
    
    #输入PWM值画机械臂。对于非180度舵机实施缩放处理。对零位非0度的情况进行处理
    def drawpwm(self,pwm0,pwm1,pwm2):
        angle0pc=int((pwm0-500)/2000*180) 
        angle1pc=int((pwm1-500)/2000*180)
        angle2pc=int((pwm2-500)/2000*180)
        angel0=int(angle0pc*(self.m00.maxangle-self.m00.minangle)/180)+self.m00.minangle
        angel1=int(angle1pc*(self.m01.maxangle-self.m01.minangle)/180)+self.m01.minangle
        angel2=int(angle2pc*(self.m02.maxangle-self.m02.minangle)/180)+self.m02.minangle
        A1=180+50-(angel1+angel2)
        print("angel0,A1,angel2",angel0,A1,angel2)
        self.robodraw(angel0,A1,angel2)
        
    def xytopwm(self,x,y,z):
        r=mt.sqrt(x*x+z*z)
        q1,q2=self.xytoq12(r,y)
        # q1=180+50-(q2+pwmq1)
        pwmq1=180+50-(q1+q2)
        pwmq2=q2
        pwm1=int(pwmq1/180*2000+500)
        pwm2=int(pwmq2/180*2000+500)
        
        q0=self.xztoq0(x,z)
        qq0=q0-self.m00.minangle
        pwmq0=qq0/(self.m00.maxangle-self.m00.minangle)*180
        pwm0=int(pwmq0/180*2000+500)
        print("pwm0,pwm1,pwm2",pwm0,pwm1,pwm2)
        return pwm0,pwm1,pwm2
    
    def serwrite(self,pwm0,pwm1,pwm2):
        if self.ser is None:
            return
        print(pwm0,pwm1,pwm2)
        pw0str="%04x"%pwm0
        pw1str="%04x"%pwm1
        pw2str="%04x"%pwm2
        print(pw0str,pw1str,pw2str)
        mo0hexstr="ff 02 00"+" "+pw0str[2:4]+" "+pw0str[0:2]
        mo1hexstr="ff 02 01"+" "+pw1str[2:4]+" "+pw1str[0:2]
        mo2hexstr="ff 02 02"+" "+pw2str[2:4]+" "+pw2str[0:2]
        self.ser.write(bytes.fromhex(mo0hexstr))
        self.ser.write(bytes.fromhex(mo1hexstr))
        self.ser.write(bytes.fromhex(mo2hexstr))
        return
    
    def robotTwin(self,x,y,z):
        pwm0,pwm1,pwm2=self.xytopwm(x,y,z)
        self.drawpwm(pwm0,pwm1,pwm2)
        self.serwrite(pwm0,pwm1,pwm2)
    def show(self):
        global img
        cv2.imshow("marm",img)
        cv2.waitKey(300)
        #恢复背景
        img=imgcon.copy()
    
    def destroy(self):
        if self.ser is not None:
            self.ser.close()
        cv2.destroyAllWindows()
        
#配置零件舵机
mM00=mmotor((170+300,240+300),0,0,-45,225)
mM02=mmotor((170+300,240+300),0,0,0,180)
mM01=mmotor((0,0),0,0,0,180)
mM03=mmotor((0,0),0,0,0,180)
#配置零件梁
mMl01=mlever((0,0),200,10,0)
mMl02=mlever((0,0),200,10,0)
mMl03=mlever((0,0),60,10,0)
#组装成机械臂
marm=Marm(mM00,mM01,mM02,mM03,mMl01,mMl02,mMl03)

for i in range(-30,30):
    marm.robotTwin(100,0,i*10)
    marm.show()    
marm.destroy()
# Out:
# (1080, 1440, 3)
# 480 360
# []
# pwm0,pwm1,pwm2 969 1475 919
# angel0,A1,angel2 18 106 37
# mangel0,mangle1,mangle2 18 106 37
# ZJ point (470, 540)
# zrect ((395, 516), (158, 10), 18)
# m01 zcenter is (319, 491)
# ZJ point (319, 491)
# zrect ((244, 467), (158, 10), 18)
# ZJ point (168, 442)
# zrect ((168, 442), (0, 10), 18)
# pwm0,pwm1,pwm2 974 1499 943
# angel0,A1,angel2 18 102 39
# mangel0,mangle1,mangle2 18 102 39
# ZJ point (470, 540)
# zrect ((397, 517), (154, 10), 18)
# m01 zcenter is (323, 492)
# ZJ point (323, 492)
# zrect ((250, 469), (154, 10), 18)
# ZJ point (176, 444)
# zrect ((176, 444), (0, 10), 18)
# pwm0,pwm1,pwm2 978 1522 966
# angel0,A1,angel2 19 98 41
# mangel0,mangle1,mangle2 19 98 41
# ZJ point (470, 540)
# zrect ((400, 516), (150, 10), 19)
# m01 zcenter is (328, 491)
# ZJ point (328, 491)
# zrect ((258, 467), (150, 10), 19)
# ZJ point (186, 442)
# zrect ((186, 442), (0, 10), 19)
# pwm0,pwm1,pwm2 983 1543 988
# angel0,A1,angel2 19 94 43
# mangel0,mangle1,mangle2 19 94 43
# ZJ point (470, 540)
# zrect ((401, 517), (146, 10), 19)
# m01 zcenter is (331, 492)
# ZJ point (331, 492)
# zrect ((262, 469), (146, 10), 19)
# ZJ point (192, 444)
# zrect ((192, 444), (0, 10), 19)
# pwm0,pwm1,pwm2 989 1565 1009
# angel0,A1,angel2 21 90 45
# mangel0,mangle1,mangle2 21 90 45
# ZJ point (470, 540)
# zrect ((405, 515), (140, 10), 21)
# m01 zcenter is (339, 489)
# ZJ point (339, 489)
# zrect ((274, 464), (140, 10), 21)
# ZJ point (208, 438)
# zrect ((208, 438), (0, 10), 21)
# pwm0,pwm1,pwm2 994 1585 1029
# angel0,A1,angel2 21 86 47
# mangel0,mangle1,mangle2 21 86 47
# ZJ point (470, 540)
# zrect ((407, 516), (136, 10), 21)
# m01 zcenter is (343, 491)
# ZJ point (343, 491)
# zrect ((280, 467), (136, 10), 21)
# ZJ point (216, 442)
# zrect ((216, 442), (0, 10), 21)
# pwm0,pwm1,pwm2 1000 1605 1049
# angel0,A1,angel2 22 82 49
# mangel0,mangle1,mangle2 22 82 49
# ZJ point (470, 540)
# zrect ((410, 516), (130, 10), 22)
# m01 zcenter is (349, 491)
# ZJ point (349, 491)
# zrect ((289, 467), (130, 10), 22)
# ZJ point (228, 442)
# zrect ((228, 442), (0, 10), 22)
# pwm0,pwm1,pwm2 1007 1624 1068
# angel0,A1,angel2 22 78 51
# mangel0,mangle1,mangle2 22 78 51
# ZJ point (470, 540)
# zrect ((413, 517), (124, 10), 22)
# m01 zcenter is (355, 493)
# ZJ point (355, 493)
# zrect ((298, 470), (124, 10), 22)
# ZJ point (240, 446)
# zrect ((240, 446), (0, 10), 22)
# pwm0,pwm1,pwm2 1014 1642 1087
# angel0,A1,angel2 24 76 52
# mangel0,mangle1,mangle2 24 76 52
# ZJ point (470, 540)
# zrect ((415, 516), (122, 10), 24)
# m01 zcenter is (359, 490)
# ZJ point (359, 490)
# zrect ((304, 466), (122, 10), 24)
# ZJ point (248, 440)
# zrect ((248, 440), (0, 10), 24)
# pwm0,pwm1,pwm2 1021 1660 1104
# angel0,A1,angel2 24 72 54
# mangel0,mangle1,mangle2 24 72 54
# ZJ point (470, 540)
# zrect ((418, 517), (116, 10), 24)
# m01 zcenter is (364, 492)
# ZJ point (364, 492)
# zrect ((312, 469), (116, 10), 24)
# ZJ point (258, 444)
# zrect ((258, 444), (0, 10), 24)
# pwm0,pwm1,pwm2 1030 1677 1122
# angel0,A1,angel2 25 70 55
# mangel0,mangle1,mangle2 25 70 55
# ZJ point (470, 540)
# zrect ((419, 516), (114, 10), 25)
# m01 zcenter is (367, 491)
# ZJ point (367, 491)
# zrect ((316, 467), (114, 10), 25)
# ZJ point (264, 442)
# zrect ((264, 442), (0, 10), 25)
# pwm0,pwm1,pwm2 1038 1694 1139
# angel0,A1,angel2 27 66 57
# mangel0,mangle1,mangle2 27 66 57
# ZJ point (470, 540)
# zrect ((422, 516), (108, 10), 27)
# m01 zcenter is (373, 491)
# ZJ point (373, 491)
# zrect ((325, 467), (108, 10), 27)
# ZJ point (276, 442)
# zrect ((276, 442), (0, 10), 27)
# pwm0,pwm1,pwm2 1048 1711 1155
# angel0,A1,angel2 28 64 58
# mangel0,mangle1,mangle2 28 64 58
# ZJ point (470, 540)
# zrect ((425, 516), (104, 10), 28)
# m01 zcenter is (378, 491)
# ZJ point (378, 491)
# zrect ((333, 467), (104, 10), 28)
# ZJ point (286, 442)
# zrect ((286, 442), (0, 10), 28)
# pwm0,pwm1,pwm2 1059 1727 1171
# angel0,A1,angel2 30 60 60
# mangel0,mangle1,mangle2 30 60 60
# ZJ point (470, 540)
# zrect ((427, 516), (100, 10), 30)
# m01 zcenter is (383, 490)
# ZJ point (383, 490)
# zrect ((340, 466), (100, 10), 30)
# ZJ point (296, 440)
# zrect ((296, 440), (0, 10), 30)
# pwm0,pwm1,pwm2 1070 1742 1187
# angel0,A1,angel2 31 58 61
# mangel0,mangle1,mangle2 31 58 61
# ZJ point (470, 540)
# zrect ((429, 516), (96, 10), 31)
# m01 zcenter is (387, 490)
# ZJ point (387, 490)
# zrect ((346, 466), (96, 10), 31)
# ZJ point (304, 440)
# zrect ((304, 440), (0, 10), 31)
# pwm0,pwm1,pwm2 1082 1757 1202
# angel0,A1,angel2 33 54 63
# mangel0,mangle1,mangle2 33 54 63
# ZJ point (470, 540)
# zrect ((433, 516), (90, 10), 33)
# m01 zcenter is (394, 491)
# ZJ point (394, 491)
# zrect ((357, 467), (90, 10), 33)
# ZJ point (318, 442)
# zrect ((318, 442), (0, 10), 33)
# pwm0,pwm1,pwm2 1096 1772 1216
# angel0,A1,angel2 34 52 64
# mangel0,mangle1,mangle2 34 52 64
# ZJ point (470, 540)
# zrect ((435, 516), (86, 10), 34)
# m01 zcenter is (399, 491)
# ZJ point (399, 491)
# zrect ((364, 467), (86, 10), 34)
# ZJ point (328, 442)
# zrect ((328, 442), (0, 10), 34)
# pwm0,pwm1,pwm2 1111 1786 1231
# angel0,A1,angel2 36 50 65
# mangel0,mangle1,mangle2 36 50 65
# ZJ point (470, 540)
# zrect ((437, 516), (84, 10), 36)
# m01 zcenter is (402, 491)
# ZJ point (402, 491)
# zrect ((369, 467), (84, 10), 36)
# ZJ point (334, 442)
# zrect ((334, 442), (0, 10), 36)
# pwm0,pwm1,pwm2 1128 1800 1244
# angel0,A1,angel2 39 47 66
# mangel0,mangle1,mangle2 39 47 66
# ZJ point (470, 540)
# zrect ((439, 515), (80, 10), 39)
# m01 zcenter is (407, 489)
# ZJ point (407, 489)
# zrect ((377, 465), (78, 10), 39)
# ZJ point (346, 440)
# zrect ((346, 440), (0, 10), 39)
# pwm0,pwm1,pwm2 1146 1813 1257
# angel0,A1,angel2 42 44 68
# mangel0,mangle1,mangle2 42 44 68
# ZJ point (470, 540)
# zrect ((443, 516), (74, 10), 42)
# m01 zcenter is (415, 490)
# ZJ point (415, 490)
# zrect ((388, 466), (74, 10), 42)
# ZJ point (360, 440)
# zrect ((360, 440), (0, 10), 42)
# pwm0,pwm1,pwm2 1166 1825 1269
# angel0,A1,angel2 43 42 69
# mangel0,mangle1,mangle2 43 42 69
# ZJ point (470, 540)
# zrect ((445, 517), (70, 10), 43)
# m01 zcenter is (418, 492)
# ZJ point (418, 492)
# zrect ((393, 469), (70, 10), 43)
# ZJ point (366, 444)
# zrect ((366, 444), (0, 10), 43)
# pwm0,pwm1,pwm2 1188 1837 1281
# angel0,A1,angel2 46 40 70
# mangel0,mangle1,mangle2 46 40 70
# ZJ point (470, 540)
# zrect ((447, 516), (68, 10), 46)
# m01 zcenter is (422, 491)
# ZJ point (422, 491)
# zrect ((399, 467), (68, 10), 46)
# ZJ point (374, 442)
# zrect ((374, 442), (0, 10), 46)
# pwm0,pwm1,pwm2 1213 1848 1292
# angel0,A1,angel2 51 38 71
# mangel0,mangle1,mangle2 51 38 71
# ZJ point (470, 540)
# zrect ((450, 516), (64, 10), 51)
# m01 zcenter is (429, 490)
# ZJ point (429, 490)
# zrect ((409, 466), (64, 10), 51)
# ZJ point (388, 440)
# zrect ((388, 440), (0, 10), 51)
# pwm0,pwm1,pwm2 1240 1858 1302
# angel0,A1,angel2 54 36 72
# mangel0,mangle1,mangle2 54 36 72
# ZJ point (470, 540)
# zrect ((453, 516), (60, 10), 54)
# m01 zcenter is (435, 491)
# ZJ point (435, 491)
# zrect ((418, 467), (60, 10), 54)
# ZJ point (400, 442)
# zrect ((400, 442), (0, 10), 54)
# pwm0,pwm1,pwm2 1270 1867 1311
# angel0,A1,angel2 58 35 72
# mangel0,mangle1,mangle2 58 35 72
# ZJ point (470, 540)
# zrect ((455, 515), (60, 10), 58)
# m01 zcenter is (438, 489)
# ZJ point (438, 489)
# zrect ((423, 465), (58, 10), 58)
# ZJ point (407, 440)
# zrect ((407, 440), (0, 10), 58)
# pwm0,pwm1,pwm2 1303 1875 1319
# angel0,A1,angel2 63 34 73
# mangel0,mangle1,mangle2 63 34 73
# ZJ point (470, 540)
# zrect ((457, 515), (58, 10), 63)
# m01 zcenter is (443, 488)
# ZJ point (443, 488)
# zrect ((430, 463), (58, 10), 63)
# ZJ point (416, 436)
# zrect ((416, 436), (0, 10), 63)
# pwm0,pwm1,pwm2 1338 1881 1326
# angel0,A1,angel2 67 32 74
# mangel0,mangle1,mangle2 67 32 74
# ZJ point (470, 540)
# zrect ((460, 516), (54, 10), 67)
# m01 zcenter is (449, 491)
# ZJ point (449, 491)
# zrect ((439, 467), (54, 10), 67)
# ZJ point (428, 442)
# zrect ((428, 442), (0, 10), 67)
# pwm0,pwm1,pwm2 1376 1887 1331
# angel0,A1,angel2 72 32 74
# mangel0,mangle1,mangle2 72 32 74
# ZJ point (470, 540)
# zrect ((462, 515), (54, 10), 72)
# m01 zcenter is (453, 488)
# ZJ point (453, 488)
# zrect ((445, 463), (54, 10), 72)
# ZJ point (436, 436)
# zrect ((436, 436), (0, 10), 72)
# pwm0,pwm1,pwm2 1416 1891 1335
# angel0,A1,angel2 78 30 75
# mangel0,mangle1,mangle2 78 30 75
# ZJ point (470, 540)
# zrect ((465, 516), (50, 10), 78)
# m01 zcenter is (459, 491)
# ZJ point (459, 491)
# zrect ((454, 467), (50, 10), 78)
# ZJ point (448, 442)
# zrect ((448, 442), (0, 10), 78)
# pwm0,pwm1,pwm2 1457 1893 1338
# angel0,A1,angel2 84 30 75
# mangel0,mangle1,mangle2 84 30 75
# ZJ point (470, 540)
# zrect ((468, 516), (50, 10), 84)
# m01 zcenter is (465, 490)
# ZJ point (465, 490)
# zrect ((463, 466), (50, 10), 84)
# ZJ point (460, 440)
# zrect ((460, 440), (0, 10), 84)
# pwm0,pwm1,pwm2 1500 1894 1339
# angel0,A1,angel2 90 30 75
# mangel0,mangle1,mangle2 90 30 75
# ZJ point (470, 540)
# zrect ((470, 515), (50, 10), 90)
# m01 zcenter is (470, 490)
# ZJ point (470, 490)
# zrect ((470, 465), (50, 10), 90)
# ZJ point (470, 440)
# zrect ((470, 440), (0, 10), 90)
# pwm0,pwm1,pwm2 1542 1893 1338
# angel0,A1,angel2 94 30 75
# mangel0,mangle1,mangle2 94 30 75
# ZJ point (470, 540)
# zrect ((471, 516), (50, 10), 94)
# m01 zcenter is (472, 490)
# ZJ point (472, 490)
# zrect ((473, 466), (50, 10), 94)
# ZJ point (474, 440)
# zrect ((474, 440), (0, 10), 94)
# pwm0,pwm1,pwm2 1583 1891 1335
# angel0,A1,angel2 100 30 75
# mangel0,mangle1,mangle2 100 30 75
# ZJ point (470, 540)
# zrect ((474, 516), (50, 10), 100)
# m01 zcenter is (478, 491)
# ZJ point (478, 491)
# zrect ((482, 467), (50, 10), 100)
# ZJ point (486, 442)
# zrect ((486, 442), (0, 10), 100)
# pwm0,pwm1,pwm2 1623 1887 1331
# angel0,A1,angel2 106 32 74
# mangel0,mangle1,mangle2 106 32 74
# ZJ point (470, 540)
# zrect ((477, 515), (54, 10), 106)
# m01 zcenter is (484, 488)
# ZJ point (484, 488)
# zrect ((491, 463), (54, 10), 106)
# ZJ point (498, 436)
# zrect ((498, 436), (0, 10), 106)
# pwm0,pwm1,pwm2 1661 1881 1326
# angel0,A1,angel2 111 32 74
# mangel0,mangle1,mangle2 111 32 74
# ZJ point (470, 540)
# zrect ((479, 515), (54, 10), 111)
# m01 zcenter is (488, 489)
# ZJ point (488, 489)
# zrect ((497, 464), (54, 10), 111)
# ZJ point (506, 438)
# zrect ((506, 438), (0, 10), 111)
# pwm0,pwm1,pwm2 1696 1875 1319
# angel0,A1,angel2 115 34 73
# mangel0,mangle1,mangle2 115 34 73
# ZJ point (470, 540)
# zrect ((482, 514), (58, 10), 115)
# m01 zcenter is (493, 487)
# ZJ point (493, 487)
# zrect ((505, 461), (58, 10), 115)
# ZJ point (516, 434)
# zrect ((516, 434), (0, 10), 115)
# pwm0,pwm1,pwm2 1729 1867 1311
# angel0,A1,angel2 120 35 72
# mangel0,mangle1,mangle2 120 35 72
# ZJ point (470, 540)
# zrect ((484, 515), (60, 10), 120)
# m01 zcenter is (498, 488)
# ZJ point (498, 488)
# zrect ((512, 463), (58, 10), 120)
# ZJ point (526, 437)
# zrect ((526, 437), (0, 10), 120)
# pwm0,pwm1,pwm2 1759 1858 1302
# angel0,A1,angel2 124 36 72
# mangel0,mangle1,mangle2 124 36 72
# ZJ point (470, 540)
# zrect ((486, 516), (60, 10), 124)
# m01 zcenter is (502, 490)
# ZJ point (502, 490)
# zrect ((518, 466), (60, 10), 124)
# ZJ point (534, 440)
# zrect ((534, 440), (0, 10), 124)
# pwm0,pwm1,pwm2 1786 1848 1292
# angel0,A1,angel2 127 38 71
# mangel0,mangle1,mangle2 127 38 71
# ZJ point (470, 540)
# zrect ((489, 515), (64, 10), 127)
# m01 zcenter is (508, 489)
# ZJ point (508, 489)
# zrect ((527, 464), (64, 10), 127)
# ZJ point (546, 438)
# zrect ((546, 438), (0, 10), 127)
# pwm0,pwm1,pwm2 1811 1837 1281
# angel0,A1,angel2 130 40 70
# mangel0,mangle1,mangle2 130 40 70
# ZJ point (470, 540)
# zrect ((491, 514), (68, 10), 130)
# m01 zcenter is (512, 487)
# ZJ point (512, 487)
# zrect ((533, 461), (68, 10), 130)
# ZJ point (554, 434)
# zrect ((554, 434), (0, 10), 130)
# pwm0,pwm1,pwm2 1833 1825 1269
# angel0,A1,angel2 133 42 69
# mangel0,mangle1,mangle2 133 42 69
# ZJ point (470, 540)
# zrect ((493, 515), (70, 10), 133)
# m01 zcenter is (516, 488)
# ZJ point (516, 488)
# zrect ((539, 463), (70, 10), 133)
# ZJ point (562, 436)
# zrect ((562, 436), (0, 10), 133)
# pwm0,pwm1,pwm2 1853 1813 1257
# angel0,A1,angel2 136 44 68
# mangel0,mangle1,mangle2 136 44 68
# ZJ point (470, 540)
# zrect ((496, 515), (74, 10), 136)
# m01 zcenter is (522, 488)
# ZJ point (522, 488)
# zrect ((548, 463), (74, 10), 136)
# ZJ point (574, 436)
# zrect ((574, 436), (0, 10), 136)
# pwm0,pwm1,pwm2 1871 1800 1244
# angel0,A1,angel2 139 47 66
# mangel0,mangle1,mangle2 139 47 66
# ZJ point (470, 540)
# zrect ((500, 514), (80, 10), 139)
# m01 zcenter is (529, 487)
# ZJ point (529, 487)
# zrect ((558, 462), (78, 10), 139)
# ZJ point (587, 436)
# zrect ((587, 436), (0, 10), 139)
# pwm0,pwm1,pwm2 1888 1786 1231
# angel0,A1,angel2 141 50 65
# mangel0,mangle1,mangle2 141 50 65
# ZJ point (470, 540)
# zrect ((502, 514), (84, 10), 141)
# m01 zcenter is (534, 487)
# ZJ point (534, 487)
# zrect ((566, 461), (84, 10), 141)
# ZJ point (598, 434)
# zrect ((598, 434), (0, 10), 141)
# pwm0,pwm1,pwm2 1903 1772 1216
# angel0,A1,angel2 144 52 64
# mangel0,mangle1,mangle2 144 52 64
# ZJ point (470, 540)
# zrect ((504, 515), (86, 10), 144)
# m01 zcenter is (538, 489)
# ZJ point (538, 489)
# zrect ((572, 464), (86, 10), 144)
# ZJ point (606, 438)
# zrect ((606, 438), (0, 10), 144)
# pwm0,pwm1,pwm2 1917 1757 1202
# angel0,A1,angel2 145 54 63
# mangel0,mangle1,mangle2 145 54 63
# ZJ point (470, 540)
# zrect ((506, 515), (90, 10), 145)
# m01 zcenter is (542, 489)
# ZJ point (542, 489)
# zrect ((578, 464), (90, 10), 145)
# ZJ point (614, 438)
# zrect ((614, 438), (0, 10), 145)
# pwm0,pwm1,pwm2 1929 1742 1187
# angel0,A1,angel2 147 58 61
# mangel0,mangle1,mangle2 147 58 61
# ZJ point (470, 540)
# zrect ((510, 514), (96, 10), 147)
# m01 zcenter is (549, 487)
# ZJ point (549, 487)
# zrect ((589, 461), (96, 10), 147)
# ZJ point (628, 434)
# zrect ((628, 434), (0, 10), 147)
# pwm0,pwm1,pwm2 1940 1727 1171
# angel0,A1,angel2 148 60 60
# mangel0,mangle1,mangle2 148 60 60
# ZJ point (470, 540)
# zrect ((512, 514), (100, 10), 148)
# m01 zcenter is (554, 487)
# ZJ point (554, 487)
# zrect ((596, 461), (100, 10), 148)
# ZJ point (638, 434)
# zrect ((638, 434), (0, 10), 148)
# pwm0,pwm1,pwm2 1951 1711 1155
# angel0,A1,angel2 150 64 58
# mangel0,mangle1,mangle2 150 64 58
# ZJ point (470, 540)
# zrect ((515, 515), (104, 10), 150)
# m01 zcenter is (559, 488)
# ZJ point (559, 488)
# zrect ((604, 463), (104, 10), 150)
# ZJ point (648, 436)
# zrect ((648, 436), (0, 10), 150)
# pwm0,pwm1,pwm2 1961 1694 1139
# angel0,A1,angel2 151 66 57
# mangel0,mangle1,mangle2 151 66 57
# ZJ point (470, 540)
# zrect ((517, 514), (108, 10), 151)
# m01 zcenter is (563, 487)
# ZJ point (563, 487)
# zrect ((610, 461), (108, 10), 151)
# ZJ point (656, 434)
# zrect ((656, 434), (0, 10), 151)
# pwm0,pwm1,pwm2 1969 1677 1122
# angel0,A1,angel2 153 70 55
# mangel0,mangle1,mangle2 153 70 55
# ZJ point (470, 540)
# zrect ((520, 515), (114, 10), 153)
# m01 zcenter is (570, 488)
# ZJ point (570, 488)
# zrect ((620, 463), (114, 10), 153)
# ZJ point (670, 436)
# zrect ((670, 436), (0, 10), 153)
# pwm0,pwm1,pwm2 1978 1660 1104
# angel0,A1,angel2 154 72 54
# mangel0,mangle1,mangle2 154 72 54
# ZJ point (470, 540)
# zrect ((522, 515), (116, 10), 154)
# m01 zcenter is (573, 489)
# ZJ point (573, 489)
# zrect ((625, 464), (116, 10), 154)
# ZJ point (676, 438)
# zrect ((676, 438), (0, 10), 154)
# pwm0,pwm1,pwm2 1985 1642 1087
# angel0,A1,angel2 154 76 52
# mangel0,mangle1,mangle2 154 76 52
# ZJ point (470, 540)
# zrect ((524, 514), (122, 10), 154)
# m01 zcenter is (578, 486)
# ZJ point (578, 486)
# zrect ((632, 460), (122, 10), 154)
# ZJ point (686, 432)
# zrect ((686, 432), (0, 10), 154)
# pwm0,pwm1,pwm2 1992 1624 1068
# angel0,A1,angel2 156 78 51
# mangel0,mangle1,mangle2 156 78 51
# ZJ point (470, 540)
# zrect ((526, 515), (124, 10), 156)
# m01 zcenter is (582, 489)
# ZJ point (582, 489)
# zrect ((638, 464), (124, 10), 156)
# ZJ point (694, 438)
# zrect ((694, 438), (0, 10), 156)
# pwm0,pwm1,pwm2 1999 1605 1049
# angel0,A1,angel2 156 82 49
# mangel0,mangle1,mangle2 156 82 49
# ZJ point (470, 540)
# zrect ((529, 514), (130, 10), 156)
# m01 zcenter is (588, 487)
# ZJ point (588, 487)
# zrect ((647, 461), (130, 10), 156)
# ZJ point (706, 434)
# zrect ((706, 434), (0, 10), 156)
# pwm0,pwm1,pwm2 2005 1585 1029
# angel0,A1,angel2 157 86 47
# mangel0,mangle1,mangle2 157 86 47
# ZJ point (470, 540)
# zrect ((532, 514), (136, 10), 157)
# m01 zcenter is (594, 487)
# ZJ point (594, 487)
# zrect ((656, 461), (136, 10), 157)
# ZJ point (718, 434)
# zrect ((718, 434), (0, 10), 157)
# pwm0,pwm1,pwm2 2010 1565 1009
# angel0,A1,angel2 157 90 45
# mangel0,mangle1,mangle2 157 90 45
# ZJ point (470, 540)
# zrect ((534, 513), (140, 10), 157)
# m01 zcenter is (598, 485)
# ZJ point (598, 485)
# zrect ((662, 458), (140, 10), 157)
# ZJ point (726, 430)
# zrect ((726, 430), (0, 10), 157)
# pwm0,pwm1,pwm2 2016 1543 988
# angel0,A1,angel2 159 94 43
# mangel0,mangle1,mangle2 159 94 43
# ZJ point (470, 540)
# zrect ((538, 514), (146, 10), 159)
# m01 zcenter is (605, 487)
# ZJ point (605, 487)
# zrect ((673, 461), (146, 10), 159)
# ZJ point (740, 434)
# zrect ((740, 434), (0, 10), 159)
# pwm0,pwm1,pwm2 2021 1522 966
# angel0,A1,angel2 159 98 41
# mangel0,mangle1,mangle2 159 98 41
# ZJ point (470, 540)
# zrect ((540, 514), (150, 10), 159)
# m01 zcenter is (609, 486)
# ZJ point (609, 486)
# zrect ((679, 460), (150, 10), 159)
# ZJ point (748, 432)
# zrect ((748, 432), (0, 10), 159)
# pwm0,pwm1,pwm2 2025 1499 943
# angel0,A1,angel2 160 102 39
# mangel0,mangle1,mangle2 160 102 39
# ZJ point (470, 540)
# zrect ((542, 514), (154, 10), 160)
# m01 zcenter is (614, 487)
# ZJ point (614, 487)
# zrect ((686, 461), (154, 10), 160)
# ZJ point (758, 434)
# zrect ((758, 434), (0, 10), 160)
